# %%
# last_order == "buy"
# Nifty options order for buy call and put - updates as on 15-10-2023
#Change Value " sb , sr, ex, -STOCK,EXCODE,psp,csp,exp, order_type, get_instrument_by_token, quantity, price", ---ICICI direct stock
# STOCK="NIFTY"; EXCODE="NFO";psp="17700"; csp="17600"; qt="100"; exp="2023-04-20T06:00:00.000Z"; vdate="2023-04-15T06:00:00.000Z" # broker stock code   ##import os; import urllib;
from tradingview_ta import TA_Handler, Interval, Exchange; import time; import datetime; import pandas as pd;  from breeze_connect import BreezeConnect
#sb="NIFTY";sr="cfd"; ex="NSE"; #  trading View exchange code
sb="BANKNIFTY"; sr="india"; ex="NSE" #  trading View exchange code
#sb="CNXFINANCE"; sr="india"; ex="NSE" #  trading View exchange code
# sb="BTCUSD"; sr="crypto" ; ex="BINANCE";
#sb="USOIL"; sr="cfd" ; ex="FX"; #Tok_A = 425903; ex='MCX'; qt = 1; #  trading View exchange code Crude oil
#symbols = ['CNXFINANCE','BANKNIFTY','NIFTY','TCS','NIFTYJR', 'WIPRO']
import time; import datetime; import pandas as pd; import winsound; from gtts import gTTS; import os; import urllib
mytext1 = 'Buy nifty signal buy CALL OPTION  executed'; mytext2 = 'Sell nifty signal buy PUT OPTION executed'
language = 'en'; myobj1 = gTTS(text=mytext1, lang=language, slow=False); myobj2 = gTTS(text=mytext2, lang=language, slow=False); frequency = 7000; duration = 500; myobj1.save("buyCallNB.mp3"); myobj2.save("buyPutNB.mp3")

symbols = ['NIFTY','BANKNIFTY','CNXFINANCE','ADANIENT','ADANIPORTS','APOLLOHOSP','ASIANPAINT','AXISBANK','BAJAJ_AUTO','BAJAJFINSV','BAJFINANCE','BHARTIARTL','BPCL','BRITANNIA','CIPLA','COALINDIA','DIVISLAB','DRREDDY', 'EICHERMOT','GRASIM','HCLTECH','HDFCBANK','HDFCLIFE','HEROMOTOCO','HINDALCO','HINDUNILVR','ICICIBANK','INDUSINDBK','INFY','ITC','JSWSTEEL','KOTAKBANK','LT','LTIM','M_M','MARUTI','NESTLEIND','NIFTY','NTPC','ONGC','POWERGRID','RELIANCE','SBILIFE','SBIN', 'SHRIRAMFIN', 'SUNPHARMA','TATACONSUM','TATAMOTORS','TATASTEEL','TCS','TECHM','TITAN','ULTRACEMCO','WIPRO']

try:
    def get_recomm(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return output.get_analysis().summary['RECOMMENDATION']

    def get_recomm_rsi(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["RSI"])

    def get_recomm_CP(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["close"])

    def get_recomm_R1(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.R1"])

    def get_recomm_S1(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.S1"])

    def get_recomm_R2(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.R2"])

    def get_recomm_S2(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.S2"])

    def get_recomm_PV(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.Middle"])

    def get_recomm_ema5(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA5"])

    def get_recomm_ema10(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA10"])

    def get_recomm_ema20(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA20"])

    def get_recomm_SK(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["Stoch.K"])

    def get_recomm_SD(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["Stoch.D"])        
    def get_recomm_MACD_m(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["MACD.macd"])

    def get_recomm_MACD_s(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["MACD.signal"])

   # def get_recomm_MACD_s(symbols):
   #     output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
   #     return float(output.get_analysis().indicators["MACD.signal"])

    def get_recomm_trec(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return output.get_analysis().time

# MACD_m=round(float(handler.get_analysis().indicators["MACD.macd"]),2); MACD_s= round(float(handler.get_analysis().indicators["MACD.signal"]),2)

except Exception as error:
          print('Place Order API Error!<---BreezeAPI-->', error)

#trec = handler.get_analysis().time

# recomm = get_recomm(data['symbols'])
last_buy = False
last_sell = False
loop_counter = 0
#while  loop_counter < 2:
while True:
    print("------------while loop started ------------------------5 signal used ------------------------------------------------------------")
    for iteam in symbols:
        try:
            #print("<-b/s->",iteam,"<-", get_recomm(iteam), "(RSI>50)", 50 < get_recomm_rsi(iteam), "(CP)", round(get_recomm_CP(iteam),2), "(RSI)", round(get_recomm_rsi(iteam),2),"<CP>R1>", get_recomm_CP(iteam) > get_recomm_R1(iteam),"<CP>PV>", get_recomm_CP(iteam) > get_recomm_PV(iteam),"<CP<S1>", get_recomm_CP(iteam) < get_recomm_S1(iteam),"(R1)", round(get_recomm_R1(iteam),2), "(S1)", round(get_recomm_S1(iteam),2),"(R2)", round(get_recomm_R2(iteam),2), "(S2)", round(get_recomm_S2(iteam),2),
            #        "<PV>", round(get_recomm_PV(iteam),2), "<MACD_M>", round(get_recomm_MACD_m(iteam),2), "<MACD_S>", round(get_recomm_MACD_s(iteam),2),  "<SK>", round(get_recomm_SK(iteam),2), "<SD>", round(get_recomm_SD(iteam),2), get_recomm_trec(iteam) )
            # if "BUY" in get_recomm(iteam) and 50 < get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R1(iteam):# and get_recomm_ema10(iteam) > get_recomm_ema20(iteam): # and not last_buy:
            if "BUY" in get_recomm(iteam) and 50 < get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R1(iteam): # and get_recomm_SK(iteam)>get_recomm_SD(iteam) and  get_recomm_ema10(iteam) > get_recomm_ema20(iteam) and get_recomm_MACD_m(iteam) > get_recomm_MACD_s(iteam)  :# and get_recomm_ema10(iteam) > get_recomm_ema20(iteam): # and not last_buy:
                    print ("----->>>>>",iteam, "<<<<<<-----","tradingview rec", get_recomm(iteam)); winsound.Beep(frequency, duration); str1= iteam; mytext1 = str1 + 'Buy buy signal R1 above r1 only' +str1;  myobj1 = gTTS(text=mytext1, lang=language, slow=False); myobj1.save("buyNIFTY.mp3"); os.system("start buyNIFTY.mp3")
                    print("->B<-",iteam,"->", "(CP>R1)", get_recomm_CP(iteam) > get_recomm_R1(iteam),"(RSI>50)",50 < get_recomm_rsi(iteam), "(SK>SD)", get_recomm_SK(iteam)>get_recomm_SD(iteam),"EMACROSS", get_recomm_ema10(iteam) > get_recomm_ema20(iteam), "(MACD_m>MACD_s)", get_recomm_MACD_m(iteam) > get_recomm_MACD_s(iteam),"T", get_recomm_trec(iteam))
                    with open('l_buy_(50)_f_o(7-12-915-r1).csv', 'a') as f:
                          text_to_write = f"{str(iteam)} , {get_recomm(iteam)}, 'CP', {str(get_recomm_CP(iteam))}, 'RSI>50', {str(50 < get_recomm_rsi(iteam))}, {str(round(get_recomm_rsi(iteam),1))},'CP>R1', {str(get_recomm_CP(iteam) > get_recomm_R1(iteam))} , 'R1', {str(round(get_recomm_R1(iteam),2))},'R2', {str(round(get_recomm_R2(iteam),2))}, 'CP<S1', {str(get_recomm_CP(iteam) < get_recomm_S1(iteam))},'S1', {str(round(get_recomm_S1(iteam),2))} ,S2', {str(round(get_recomm_S2(iteam),2))} {str(get_recomm_trec(iteam))}\n"
                          #text_to_write = f"{get_recomm(iteam)} {str(iteam)} {str(get_recomm_CP(iteam))} {str(get_recomm_rsi(iteam))} {str(get_recomm_R1(iteam))} {str(get_recomm_R2(iteam))} {str(get_recomm_S1(iteam))} {str(get_recomm_S2(iteam))} {str(get_recomm_trec(iteam))}\n"
                          f.write(text_to_write)
                    print("---------------->>>>>>>>---------------")
                    #last_buy = True
                    #last_sell = False

            if "SELL" in get_recomm(iteam) and 50 > get_recomm_rsi(iteam) and get_recomm_CP(iteam) < get_recomm_S1(iteam): # and get_recomm_SK(iteam)<get_recomm_SD(iteam) and  get_recomm_ema10(iteam) < get_recomm_ema20(iteam) and get_recomm_MACD_m(iteam) < get_recomm_MACD_s(iteam) : # and get_recomm_ema10(iteam) < get_recomm_ema20(iteam):# and not last_sell:
                    print ("----->>>>>",iteam, "<<<<<<-----",iteam, "tradingview rec", get_recomm(iteam)); winsound.Beep(frequency, duration);str1= iteam; mytext2 = str1 + 'Sell Sell signal S1 bellow S1 only' +str1;  myobj2 = gTTS(text=mytext2, lang=language, slow=False); myobj2.save("sellNIFTY.mp3"); os.system("start sellNIFTY.mp3")
                    print("->S<-",iteam,"->" , "CP<S1", get_recomm_CP(iteam) < get_recomm_S1(iteam), "(RSI<50)",50 > get_recomm_rsi(iteam), "(SK<SD)", get_recomm_SK(iteam)<get_recomm_SD(iteam),"EMA**", get_recomm_ema10(iteam) < get_recomm_ema20(iteam), "(MACD_m<MACD_s)", get_recomm_MACD_m(iteam) < get_recomm_MACD_s(iteam),"T", get_recomm_trec(iteam)) 
                    with open('l_sell_(50)_f_o(7-12-915-s1).csv', 'a') as f:
                        text_to_write = f"{str(iteam)} , {get_recomm(iteam)},'CP', {str(get_recomm_CP(iteam))}, 'RSI>50', {str(50 < get_recomm_rsi(iteam))}, {str(round(get_recomm_rsi(iteam),1))},'CP>R1', {str(get_recomm_CP(iteam) > get_recomm_R1(iteam))} , 'R1', {str(round(get_recomm_R1(iteam),2))},'R2', {str(round(get_recomm_R2(iteam),2))}, 'CP<S1', {str(get_recomm_CP(iteam) < get_recomm_S1(iteam))},'S1', {str(round(get_recomm_S1(iteam),2))} ,S2', {str(round(get_recomm_S2(iteam),2))} {str(get_recomm_trec(iteam))}\n"
                        #text_to_write = f"{get_recomm(iteam)} {str(iteam)} {str(get_recomm_CP(iteam))} {str(get_recomm_rsi(iteam))} {str(get_recomm_R1(iteam))} {str(get_recomm_R2(iteam))} {str(get_recomm_S1(iteam))} {str(get_recomm_S2(iteam))} {str(get_recomm_trec(iteam))}\n"
                        f.write(text_to_write)
                    print("---------------->>>>>>>>---------------")
                    #last_buy = False
                    #last_sell = True
            #else: # 45 > get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R(iteam):
                    #print("----->>>>Stoploss<<<<<---- order exec", iteam)
                    #if 48 > get_recomm_rsi(iteam): # and get_recomm_CP(iteam) < get_recomm_R1(iteam):
                        #print("---------------------------->>>>Stoploss<<<<<---- order exec", iteam, get_recomm_CP(iteam) < get_recomm_R1(iteam))
        #loop_counter += 1 # break
        #break

        except Exception as error:
          print('Place Order API Error!<---BreezeAPI--><----WhileLoop--->', error)
    print("------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------")
    #break
# Out:
# C:\Users\murug\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\murug\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:19:11.519700
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:19:20.471034
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:19:38.999181
# ---------------->>>>>>>>---------------
# ----->>>>> HEROMOTOCO <<<<<<----- tradingview rec BUY
# ->B<- HEROMOTOCO -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:19:56.362863
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:20:10.479458
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:20:24.469112
# ---------------->>>>>>>>---------------
# ----->>>>> SHRIRAMFIN <<<<<<----- tradingview rec BUY
# ->B<- SHRIRAMFIN -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS False (MACD_m>MACD_s) True T 2024-07-12 10:20:44.723752
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:21:00.564841
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec STRONG_BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:21:10.085129
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:21:29.608887
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:21:38.639933
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) False EMA** False (MACD_m<MACD_s) True T 2024-07-12 10:22:00.106251
# ---------------->>>>>>>>---------------
# ----->>>>> HEROMOTOCO <<<<<<----- tradingview rec BUY
# ->B<- HEROMOTOCO -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:22:16.811453
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:22:30.652746
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:23:02.860277
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:23:12.599166
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:23:33.578473
# ---------------->>>>>>>>---------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec STRONG_SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:23:45.668938
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:23:54.568785
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:24:13.942127
# ---------------->>>>>>>>---------------
# ----->>>>> HEROMOTOCO <<<<<<----- tradingview rec BUY
# ->B<- HEROMOTOCO -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:24:30.936068
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:24:53.288936
# ---------------->>>>>>>>---------------
# ----->>>>> MARUTI <<<<<<----- MARUTI tradingview rec SELL
# ->S<- MARUTI -> CP<S1 True (RSI<50) True (SK<SD) False EMA** False (MACD_m<MACD_s) False T 2024-07-12 10:25:04.301397
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:25:43.690544
# ---------------->>>>>>>>---------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:25:53.333133
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:26:02.306658
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:26:38.581825
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:26:53.840354
# ---------------->>>>>>>>---------------
# ----->>>>> MARUTI <<<<<<----- MARUTI tradingview rec SELL
# ->S<- MARUTI -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:27:03.869511
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:27:29.800237
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:27:49.331301
# ---------------->>>>>>>>---------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:27:58.347999
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec STRONG_BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:28:07.140984
# ---------------->>>>>>>>---------------
# ----->>>>> BHARTIARTL <<<<<<----- BHARTIARTL tradingview rec SELL
# ->S<- BHARTIARTL -> CP<S1 True (RSI<50) True (SK<SD) False EMA** False (MACD_m<MACD_s) True T 2024-07-12 10:28:20.559247
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec STRONG_BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:28:51.069826
# ---------------->>>>>>>>---------------
# ----->>>>> MARUTI <<<<<<----- MARUTI tradingview rec SELL
# ->S<- MARUTI -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:29:08.659326
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:29:35.751676
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:29:56.110314
# ---------------->>>>>>>>---------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:30:05.755635
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:30:14.628232
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:30:45.881924
# ---------------->>>>>>>>---------------
# ----->>>>> MARUTI <<<<<<----- MARUTI tradingview rec STRONG_SELL
# ->S<- MARUTI -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:31:03.218531
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:31:29.783617
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:31:49.112146
# ---------------->>>>>>>>---------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:31:58.657681
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:32:07.654734
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) False EMA** False (MACD_m<MACD_s) True T 2024-07-12 10:32:28.700279
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:32:50.497654
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:33:07.281239
# ---------------->>>>>>>>---------------
# ----->>>>> MARUTI <<<<<<----- MARUTI tradingview rec SELL
# ->S<- MARUTI -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:33:19.102266
# ---------------->>>>>>>>---------------
# ----->>>>> ONGC <<<<<<----- tradingview rec BUY
# ->B<- ONGC -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:33:32.299704
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec STRONG_BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:33:54.155299
# ---------------->>>>>>>>---------------
# ----->>>>> WIPRO <<<<<<----- tradingview rec BUY
# ->B<- WIPRO -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS False (MACD_m>MACD_s) False T 2024-07-12 10:34:08.223231
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec STRONG_SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:34:23.839942
# ---------------->>>>>>>>---------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:34:32.915661
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:34:41.752830
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:35:03.357801
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:35:25.905289
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec STRONG_BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:35:42.159378
# ---------------->>>>>>>>---------------
# ----->>>>> MARUTI <<<<<<----- MARUTI tradingview rec SELL
# ->S<- MARUTI -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:35:53.169577
# ---------------->>>>>>>>---------------
# ----->>>>> ONGC <<<<<<----- tradingview rec STRONG_BUY
# ->B<- ONGC -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:36:06.634122
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:36:28.287482
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:36:47.753286
# ---------------->>>>>>>>---------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:36:56.662151
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:37:05.499836
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:37:26.439694
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec STRONG_BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:37:50.006638
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS False (MACD_m>MACD_s) False T 2024-07-12 10:37:59.078675
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:38:13.897170
# ---------------->>>>>>>>---------------
# ----->>>>> MARUTI <<<<<<----- MARUTI tradingview rec SELL
# ->S<- MARUTI -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:38:25.059403
# ---------------->>>>>>>>---------------
# ----->>>>> ONGC <<<<<<----- tradingview rec BUY
# ->B<- ONGC -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:38:39.151092
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:38:59.125253
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:39:20.746167
# ---------------->>>>>>>>---------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:39:30.606695
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:39:39.891823
# ---------------->>>>>>>>---------------
# ----->>>>> BHARTIARTL <<<<<<----- BHARTIARTL tradingview rec SELL
# ->S<- BHARTIARTL -> CP<S1 True (RSI<50) True (SK<SD) False EMA** False (MACD_m<MACD_s) True T 2024-07-12 10:39:53.338120
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec STRONG_SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:40:07.046660
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:40:30.020727
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:40:39.164836
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec STRONG_BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:40:53.977801
# ---------------->>>>>>>>---------------
# ----->>>>> MARUTI <<<<<<----- MARUTI tradingview rec SELL
# ->S<- MARUTI -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:41:05.378681
# ---------------->>>>>>>>---------------
# ----->>>>> ONGC <<<<<<----- tradingview rec BUY
# ->B<- ONGC -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:41:19.675399
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:41:42.797833
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec STRONG_BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:41:53.014422
# ---------------->>>>>>>>---------------
# ----->>>>> WIPRO <<<<<<----- tradingview rec BUY
# ->B<- WIPRO -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:42:05.331029
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:42:22.460167
# ---------------->>>>>>>>---------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:42:31.035910
# ---------------->>>>>>>>---------------
# ----->>>>> BHARTIARTL <<<<<<----- BHARTIARTL tradingview rec SELL
# ->S<- BHARTIARTL -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:42:43.604047
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec STRONG_SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:42:56.689032
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:43:09.643667
# ---------------->>>>>>>>---------------
# ----->>>>> HEROMOTOCO <<<<<<----- tradingview rec BUY
# ->B<- HEROMOTOCO -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS False (MACD_m>MACD_s) False T 2024-07-12 10:43:21.907590
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:43:35.843626
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:43:44.812058
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:44:00.779141
# ---------------->>>>>>>>---------------
# ----->>>>> MARUTI <<<<<<----- MARUTI tradingview rec SELL
# ->S<- MARUTI -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:44:13.923707
# ---------------->>>>>>>>---------------
# ----->>>>> ONGC <<<<<<----- tradingview rec BUY
# ->B<- ONGC -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:44:27.007610
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:44:47.687332
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:44:58.392860
# ---------------->>>>>>>>---------------
# ----->>>>> WIPRO <<<<<<----- tradingview rec BUY
# ->B<- WIPRO -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:45:10.115326
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:45:25.927741
# ---------------->>>>>>>>---------------
# ----->>>>> BHARTIARTL <<<<<<----- BHARTIARTL tradingview rec SELL
# ->S<- BHARTIARTL -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:45:41.449884
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:45:57.346647
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:46:09.784797
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:46:26.422577
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:46:35.773856
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:46:50.059456
# ---------------->>>>>>>>---------------
# ----->>>>> MARUTI <<<<<<----- MARUTI tradingview rec SELL
# ->S<- MARUTI -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:47:01.229802
# ---------------->>>>>>>>---------------
# ----->>>>> ONGC <<<<<<----- tradingview rec BUY
# ->B<- ONGC -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:47:14.772230
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:47:35.812990
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:47:47.192576
# ---------------->>>>>>>>---------------
# ----->>>>> WIPRO <<<<<<----- tradingview rec STRONG_BUY
# ->B<- WIPRO -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:48:00.387330
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec STRONG_SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:48:19.209397
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:48:42.092336
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec STRONG_BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:48:55.425792
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:49:10.892349
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:49:20.510635
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:49:35.005707
# ---------------->>>>>>>>---------------
# ----->>>>> MARUTI <<<<<<----- MARUTI tradingview rec SELL
# ->S<- MARUTI -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:49:45.703588
# ---------------->>>>>>>>---------------
# ----->>>>> ONGC <<<<<<----- tradingview rec BUY
# ->B<- ONGC -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:49:59.243357
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec STRONG_BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:50:21.690968
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:50:32.710522
# ---------------->>>>>>>>---------------
# ----->>>>> WIPRO <<<<<<----- tradingview rec BUY
# ->B<- WIPRO -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:50:45.457877
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec STRONG_SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:51:02.156957
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:51:23.303226
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:51:37.005143
# ---------------->>>>>>>>---------------
# ----->>>>> HEROMOTOCO <<<<<<----- tradingview rec BUY
# ->B<- HEROMOTOCO -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS False (MACD_m>MACD_s) False T 2024-07-12 10:51:49.234390
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec STRONG_BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:52:03.634511
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:52:14.213117
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:52:29.832868
# ---------------->>>>>>>>---------------
# ----->>>>> MARUTI <<<<<<----- MARUTI tradingview rec SELL
# ->S<- MARUTI -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:52:41.773245
# ---------------->>>>>>>>---------------
# ----->>>>> SHRIRAMFIN <<<<<<----- tradingview rec BUY
# ->B<- SHRIRAMFIN -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS False (MACD_m>MACD_s) False T 2024-07-12 10:53:01.746914
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:53:15.715087
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:53:24.821302
# ---------------->>>>>>>>---------------
# ----->>>>> WIPRO <<<<<<----- tradingview rec BUY
# ->B<- WIPRO -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:53:36.529827
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> NIFTY <<<<<<----- tradingview rec STRONG_BUY
# ->B<- NIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:53:45.786937
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:54:02.734592
# ---------------->>>>>>>>---------------
# ----->>>>> BAJAJFINSV <<<<<<----- tradingview rec STRONG_BUY
# ->B<- BAJAJFINSV -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS False (MACD_m>MACD_s) True T 2024-07-12 10:54:14.001957
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec STRONG_SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:54:32.392786
# ---------------->>>>>>>>---------------
# ----->>>>> GRASIM <<<<<<----- tradingview rec BUY
# ->B<- GRASIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:54:44.512892
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:54:54.038114
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec STRONG_BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:55:11.339096
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:55:20.502032
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:55:34.979766
# ---------------->>>>>>>>---------------
# ----->>>>> NIFTY <<<<<<----- tradingview rec STRONG_BUY
# ->B<- NIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:55:48.611654
# ---------------->>>>>>>>---------------
# ----->>>>> SBIN <<<<<<----- tradingview rec STRONG_BUY
# ->B<- SBIN -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:56:05.701913
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:56:20.937699
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:56:30.455229
# ---------------->>>>>>>>---------------
# ----->>>>> WIPRO <<<<<<----- tradingview rec BUY
# ->B<- WIPRO -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:56:43.193305
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> NIFTY <<<<<<----- tradingview rec BUY
# ->B<- NIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:56:52.511102
# ---------------->>>>>>>>---------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec STRONG_SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:57:08.937237
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:57:19.264495
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) False T 2024-07-12 10:57:39.313117
# ---------------->>>>>>>>---------------
# ----->>>>> GRASIM <<<<<<----- tradingview rec BUY
# ->B<- GRASIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:57:52.196714
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:58:01.475011
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:58:18.931331
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:58:28.140137
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:58:42.909927
# ---------------->>>>>>>>---------------
# ----->>>>> NIFTY <<<<<<----- tradingview rec BUY
# ->B<- NIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:58:56.060342
# ---------------->>>>>>>>---------------
# ----->>>>> SBIN <<<<<<----- tradingview rec BUY
# ->B<- SBIN -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:59:12.018323
# ---------------->>>>>>>>---------------
# ----->>>>> SHRIRAMFIN <<<<<<----- tradingview rec BUY
# ->B<- SHRIRAMFIN -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:59:21.264460
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:59:37.296837
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec STRONG_BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:59:47.003603
# ---------------->>>>>>>>---------------
# ----->>>>> WIPRO <<<<<<----- tradingview rec STRONG_BUY
# ->B<- WIPRO -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:59:59.291823
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> NIFTY <<<<<<----- tradingview rec STRONG_BUY
# ->B<- NIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:00:08.573528
# ---------------->>>>>>>>---------------
# ----->>>>> BANKNIFTY <<<<<<----- tradingview rec STRONG_BUY
# ->B<- BANKNIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:00:18.116239
# ---------------->>>>>>>>---------------
# ----->>>>> CNXFINANCE <<<<<<----- tradingview rec STRONG_BUY
# ->B<- CNXFINANCE -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:00:28.017634
# ---------------->>>>>>>>---------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) False (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 11:00:41.589031
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:00:50.939036
# ---------------->>>>>>>>---------------
# ----->>>>> BAJAJFINSV <<<<<<----- tradingview rec BUY
# ->B<- BAJAJFINSV -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:01:01.517974
# ---------------->>>>>>>>---------------
# ----->>>>> DIVISLAB <<<<<<----- DIVISLAB tradingview rec SELL
# ->S<- DIVISLAB -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) False T 2024-07-12 11:01:18.075532
# ---------------->>>>>>>>---------------
# ----->>>>> GRASIM <<<<<<----- tradingview rec BUY
# ->B<- GRASIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:01:30.401149
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:01:40.021216
# ---------------->>>>>>>>---------------
# ----->>>>> HINDUNILVR <<<<<<----- tradingview rec BUY
# ->B<- HINDUNILVR -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:01:55.389473
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:02:06.690250
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:02:17.394058
# ---------------->>>>>>>>---------------
# ----->>>>> ITC <<<<<<----- tradingview rec BUY
# ->B<- ITC -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:02:28.766587
# ---------------->>>>>>>>---------------
# ----->>>>> JSWSTEEL <<<<<<----- tradingview rec BUY
# ->B<- JSWSTEEL -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:02:38.502803
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:02:50.296120
# ---------------->>>>>>>>---------------
# ----->>>>> NIFTY <<<<<<----- tradingview rec STRONG_BUY
# ->B<- NIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:03:04.898830
# ---------------->>>>>>>>---------------
# ----->>>>> SBIN <<<<<<----- tradingview rec BUY
# ->B<- SBIN -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:03:21.095757
# ---------------->>>>>>>>---------------
# ----->>>>> SHRIRAMFIN <<<<<<----- tradingview rec BUY
# ->B<- SHRIRAMFIN -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 11:03:31.258090
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:03:45.789239
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:03:54.893547
# ---------------->>>>>>>>---------------
# ----->>>>> TITAN <<<<<<----- tradingview rec BUY
# ->B<- TITAN -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:04:05.238612
# ---------------->>>>>>>>---------------
# ----->>>>> ULTRACEMCO <<<<<<----- tradingview rec BUY
# ->B<- ULTRACEMCO -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:04:16.453628
# ---------------->>>>>>>>---------------
# ----->>>>> WIPRO <<<<<<----- tradingview rec STRONG_BUY
# ->B<- WIPRO -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 11:04:25.973790
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> NIFTY <<<<<<----- tradingview rec BUY
# ->B<- NIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:04:35.306168
# ---------------->>>>>>>>---------------
# ----->>>>> BANKNIFTY <<<<<<----- tradingview rec BUY
# ->B<- BANKNIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:04:45.313689
# ---------------->>>>>>>>---------------
# ----->>>>> CNXFINANCE <<<<<<----- tradingview rec BUY
# ->B<- CNXFINANCE -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:04:54.668410
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:05:09.935818
# ---------------->>>>>>>>---------------
# ----->>>>> BAJAJFINSV <<<<<<----- tradingview rec BUY
# ->B<- BAJAJFINSV -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:05:19.573019
# ---------------->>>>>>>>---------------
# ----->>>>> GRASIM <<<<<<----- tradingview rec STRONG_BUY
# ->B<- GRASIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:05:43.333855
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:05:52.562640
# ---------------->>>>>>>>---------------
# ----->>>>> HINDUNILVR <<<<<<----- tradingview rec BUY
# ->B<- HINDUNILVR -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:06:08.050624
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:06:18.664192
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ...
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302400>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302AC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302580>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302640>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D1043021C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302460>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302A00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D1043023D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302700>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302280>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302430>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302370>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D1043027F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302760>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302400>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302AC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302580>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302640>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D1043021C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302460>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302A00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D1043023D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302700>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302280>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302370>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302400>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302580>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302640>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302AC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D1043021C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302280>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302760>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302700>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D104302430>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D1043024F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D1043029D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D1043023D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# ----->>>>> LTIM <<<<<<----- tradingview rec STRONG_BUY
# ->B<- LTIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 11:51:18.654424
# ---------------->>>>>>>>---------------
# ----->>>>> NIFTY <<<<<<----- tradingview rec BUY
# ->B<- NIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 11:51:33.243882
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:51:57.284704
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 11:52:06.765821
# ---------------->>>>>>>>---------------
# ----->>>>> WIPRO <<<<<<----- tradingview rec BUY
# ->B<- WIPRO -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:52:19.788535
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used ----------------------------------------------------------------------------------------------------
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS False (MACD_m>MACD_s) True T 2024-07-12 18:15:48.602943
# ---------------->>>>>>>>---------------
# ----->>>>> BAJAJFINSV <<<<<<----- tradingview rec BUY
# ->B<- BAJAJFINSV -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS False (MACD_m>MACD_s) False T 2024-07-12 18:16:01.498448
# ---------------->>>>>>>>---------------
# ----->>>>> DRREDDY <<<<<<----- tradingview rec STRONG_BUY
# ->B<- DRREDDY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 18:16:22.093828
# ---------------->>>>>>>>---------------
# ----->>>>> GRASIM <<<<<<----- tradingview rec BUY
# ->B<- GRASIM -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS False (MACD_m>MACD_s) True T 2024-07-12 18:16:37.396328
# ---------------->>>>>>>>---------------
# ----->>>>> HINDUNILVR <<<<<<----- tradingview rec BUY
# ->B<- HINDUNILVR -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS False (MACD_m>MACD_s) False T 2024-07-12 18:16:56.539607
# ---------------->>>>>>>>---------------
# ----->>>>> JSWSTEEL <<<<<<----- tradingview rec STRONG_BUY
# ->B<- JSWSTEEL -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS False (MACD_m>MACD_s) False T 2024-07-12 18:17:10.911448
# ---------------->>>>>>>>---------------
