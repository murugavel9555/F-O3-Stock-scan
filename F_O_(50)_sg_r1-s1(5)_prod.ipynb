# %%
# last_order == "buy"
# Nifty options order for buy call and put - updates as on 15-10-2023
#Change Value " sb , sr, ex, -STOCK,EXCODE,psp,csp,exp, order_type, get_instrument_by_token, quantity, price", ---ICICI direct stock
# STOCK="NIFTY"; EXCODE="NFO";psp="17700"; csp="17600"; qt="100"; exp="2023-04-20T06:00:00.000Z"; vdate="2023-04-15T06:00:00.000Z" # broker stock code   ##import os; import urllib;
from tradingview_ta import TA_Handler, Interval, Exchange; import time; import datetime; import pandas as pd;  from breeze_connect import BreezeConnect
#sb="NIFTY";sr="cfd"; ex="NSE"; #  trading View exchange code
sb="BANKNIFTY"; sr="india"; ex="NSE" #  trading View exchange code
#sb="CNXFINANCE"; sr="india"; ex="NSE" #  trading View exchange code
# sb="BTCUSD"; sr="crypto" ; ex="BINANCE";
#sb="USOIL"; sr="cfd" ; ex="FX"; #Tok_A = 425903; ex='MCX'; qt = 1; #  trading View exchange code Crude oil
#symbols = ['CNXFINANCE','BANKNIFTY','NIFTY','TCS','NIFTYJR', 'WIPRO']
import time; import datetime; import pandas as pd; import winsound; from gtts import gTTS; import os; import urllib
mytext1 = 'Buy nifty signal buy CALL OPTION  executed'; mytext2 = 'Sell nifty signal buy PUT OPTION executed'
language = 'en'; myobj1 = gTTS(text=mytext1, lang=language, slow=False); myobj2 = gTTS(text=mytext2, lang=language, slow=False); frequency = 7000; duration = 500; myobj1.save("buyCallNB.mp3"); myobj2.save("buyPutNB.mp3")

symbols = ['NIFTY','BANKNIFTY','CNXFINANCE','ADANIENT','ADANIPORTS','APOLLOHOSP','ASIANPAINT','AXISBANK','BAJAJ_AUTO','BAJAJFINSV','BAJFINANCE','BHARTIARTL','BPCL','BRITANNIA','CIPLA','COALINDIA','DIVISLAB','DRREDDY', 'EICHERMOT','GRASIM','HCLTECH','HDFCBANK','HDFCLIFE','HEROMOTOCO','HINDALCO','HINDUNILVR','ICICIBANK','INDUSINDBK','INFY','ITC','JSWSTEEL','KOTAKBANK','LT','LTIM','M_M','MARUTI','NESTLEIND','NIFTY','NTPC','ONGC','POWERGRID','RELIANCE','SBILIFE','SBIN', 'SHRIRAMFIN', 'SUNPHARMA','TATACONSUM','TATAMOTORS','TATASTEEL','TCS','TECHM','TITAN','ULTRACEMCO','WIPRO']

try:
    def get_recomm(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return output.get_analysis().summary['RECOMMENDATION']

    def get_recomm_rsi(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["RSI"])

    def get_recomm_CP(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["close"])

    def get_recomm_R1(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.R1"])

    def get_recomm_S1(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.S1"])

    def get_recomm_R2(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.R2"])

    def get_recomm_S2(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.S2"])

    def get_recomm_PV(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.Middle"])

    def get_recomm_ema5(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA5"])

    def get_recomm_ema10(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA10"])

    def get_recomm_ema20(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA20"])

    def get_recomm_SK(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["Stoch.K"])

    def get_recomm_SD(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["Stoch.D"])        
    def get_recomm_MACD_m(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["MACD.macd"])

    def get_recomm_MACD_s(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["MACD.signal"])

   # def get_recomm_MACD_s(symbols):
   #     output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
   #     return float(output.get_analysis().indicators["MACD.signal"])

    def get_recomm_trec(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return output.get_analysis().time

# MACD_m=round(float(handler.get_analysis().indicators["MACD.macd"]),2); MACD_s= round(float(handler.get_analysis().indicators["MACD.signal"]),2)

except Exception as error:
          print('Place Order API Error!<---BreezeAPI-->', error)

#trec = handler.get_analysis().time

# recomm = get_recomm(data['symbols'])
last_buy = False
last_sell = False
loop_counter = 0
#while  loop_counter < 2:
while True:
    print("------------while loop started ------------------------5 signal used ------------------------------------------------------------")
    for iteam in symbols:
        try:
            #print("<-b/s->",iteam,"<-", get_recomm(iteam), "(RSI>50)", 50 < get_recomm_rsi(iteam), "(CP)", round(get_recomm_CP(iteam),2), "(RSI)", round(get_recomm_rsi(iteam),2),"<CP>R1>", get_recomm_CP(iteam) > get_recomm_R1(iteam),"<CP>PV>", get_recomm_CP(iteam) > get_recomm_PV(iteam),"<CP<S1>", get_recomm_CP(iteam) < get_recomm_S1(iteam),"(R1)", round(get_recomm_R1(iteam),2), "(S1)", round(get_recomm_S1(iteam),2),"(R2)", round(get_recomm_R2(iteam),2), "(S2)", round(get_recomm_S2(iteam),2),
                    #"<PV>", round(get_recomm_PV(iteam),2), "<MACD_M>", round(get_recomm_MACD_m(iteam),2), "<MACD_S>", round(get_recomm_MACD_s(iteam),2),  "<SK>", round(get_recomm_SK(iteam),2), "<SD>", round(get_recomm_SD(iteam),2), get_recomm_trec(iteam) )
            # if "BUY" in get_recomm(iteam) and 50 < get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R1(iteam):# and get_recomm_ema10(iteam) > get_recomm_ema20(iteam): # and not last_buy:
            if "BUY" in get_recomm(iteam) and 50 < get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R1(iteam) and get_recomm_SK(iteam)>get_recomm_SD(iteam) and  get_recomm_ema10(iteam) > get_recomm_ema20(iteam) and get_recomm_MACD_m(iteam) > get_recomm_MACD_s(iteam)  :# and get_recomm_ema10(iteam) > get_recomm_ema20(iteam): # and not last_buy:
                    print ("----->>>>>",iteam, "<<<<<<-----","tradingview rec", get_recomm(iteam)); winsound.Beep(frequency, duration); str1= iteam; mytext1 = str1 + 'Buy buy 5 signal R1 5 signal above' +str1;  myobj1 = gTTS(text=mytext1, lang=language, slow=False); myobj1.save("buyNIFTY.mp3"); os.system("start buyNIFTY.mp3")
                    print("->B<-",iteam,"->", "(CP>R1)", get_recomm_CP(iteam) > get_recomm_R1(iteam),"(RSI>50)",50 < get_recomm_rsi(iteam), "(SK>SD)", get_recomm_SK(iteam)>get_recomm_SD(iteam),"EMACROSS", get_recomm_ema10(iteam) > get_recomm_ema20(iteam), "(MACD_m>MACD_s)", get_recomm_MACD_m(iteam) > get_recomm_MACD_s(iteam),"T", get_recomm_trec(iteam))
                    with open('l_b_(50)_f_o(7-12-915-(5)r1).csv', 'a') as f:
                          text_to_write = f"{str(iteam)} , {get_recomm(iteam)}, 'CP', {str(get_recomm_CP(iteam))}, 'RSI>50', {str(50 < get_recomm_rsi(iteam))}, {str(round(get_recomm_rsi(iteam),1))},'CP>R1', {str(get_recomm_CP(iteam) > get_recomm_R1(iteam))} , 'R1', {str(round(get_recomm_R1(iteam),2))},'R2', {str(round(get_recomm_R2(iteam),2))}, 'CP<S1', {str(get_recomm_CP(iteam) < get_recomm_S1(iteam))},'S1', {str(round(get_recomm_S1(iteam),2))} ,S2', {str(round(get_recomm_S2(iteam),2))} {str(get_recomm_trec(iteam))}\n"
                          #text_to_write = f"{get_recomm(iteam)} {str(iteam)} {str(get_recomm_CP(iteam))} {str(get_recomm_rsi(iteam))} {str(get_recomm_R1(iteam))} {str(get_recomm_R2(iteam))} {str(get_recomm_S1(iteam))} {str(get_recomm_S2(iteam))} {str(get_recomm_trec(iteam))}\n"
                          f.write(text_to_write)
                    print("---------------->>>>>>>>---------------")
                    #last_buy = True
                    #last_sell = False

            if "SELL" in get_recomm(iteam) and 50 > get_recomm_rsi(iteam) and get_recomm_CP(iteam) < get_recomm_S1(iteam) and get_recomm_SK(iteam)<get_recomm_SD(iteam) and  get_recomm_ema10(iteam) < get_recomm_ema20(iteam) and get_recomm_MACD_m(iteam) < get_recomm_MACD_s(iteam) : # and get_recomm_ema10(iteam) < get_recomm_ema20(iteam):# and not last_sell:
                    print ("----->>>>>",iteam, "<<<<<<-----",iteam, "tradingview rec", get_recomm(iteam)); winsound.Beep(frequency, duration);str1= iteam; mytext2 = str1 + 'Sell Sell 5 signal S1 5 signal bellow' +str1;  myobj2 = gTTS(text=mytext2, lang=language, slow=False); myobj2.save("sellNIFTY.mp3"); os.system("start sellNIFTY.mp3")
                    print("->S<-",iteam,"->" , "CP<S1", get_recomm_CP(iteam) < get_recomm_S1(iteam), "(RSI<50)",50 > get_recomm_rsi(iteam), "(SK<SD)", get_recomm_SK(iteam)<get_recomm_SD(iteam),"EMA**", get_recomm_ema10(iteam) < get_recomm_ema20(iteam), "(MACD_m<MACD_s)", get_recomm_MACD_m(iteam) < get_recomm_MACD_s(iteam),"T", get_recomm_trec(iteam)) 
                    with open('l_s_(50)_f_o(7-12-915(5)s1).csv', 'a') as f:
                        text_to_write = f"{str(iteam)} , {get_recomm(iteam)},'CP', {str(get_recomm_CP(iteam))}, 'RSI>50', {str(50 < get_recomm_rsi(iteam))}, {str(round(get_recomm_rsi(iteam),1))},'CP>R1', {str(get_recomm_CP(iteam) > get_recomm_R1(iteam))} , 'R1', {str(round(get_recomm_R1(iteam),2))},'R2', {str(round(get_recomm_R2(iteam),2))}, 'CP<S1', {str(get_recomm_CP(iteam) < get_recomm_S1(iteam))},'S1', {str(round(get_recomm_S1(iteam),2))} ,S2', {str(round(get_recomm_S2(iteam),2))} {str(get_recomm_trec(iteam))}\n"
                        #text_to_write = f"{get_recomm(iteam)} {str(iteam)} {str(get_recomm_CP(iteam))} {str(get_recomm_rsi(iteam))} {str(get_recomm_R1(iteam))} {str(get_recomm_R2(iteam))} {str(get_recomm_S1(iteam))} {str(get_recomm_S2(iteam))} {str(get_recomm_trec(iteam))}\n"
                        f.write(text_to_write)
                    print("---------------->>>>>>>>---------------")
                    #last_buy = False
                    #last_sell = True
            #else: # 45 > get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R(iteam):
                    #print("----->>>>Stoploss<<<<<---- order exec", iteam)
                    #if 48 > get_recomm_rsi(iteam): # and get_recomm_CP(iteam) < get_recomm_R1(iteam):
                        #print("---------------------------->>>>Stoploss<<<<<---- order exec", iteam, get_recomm_CP(iteam) < get_recomm_R1(iteam))
        #loop_counter += 1 # break
        #break

        except Exception as error:
          print('Place Order API Error!<---BreezeAPI--><----WhileLoop--->', error)
    print("------------Loop completed------------------------------------5 signal used --------------------------------------------------------------", get_recomm_trec(iteam))
    #break
# Out:
# C:\Users\murug\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\murug\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:17:57.136044
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec STRONG_BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:18:08.204596
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec STRONG_BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:18:45.880352
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:19:26.727132
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 10:19:35.190652
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:19:50.943932
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec STRONG_BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:20:02.547495
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:20:37.381585
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:21:20.447084
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 10:21:27.610069
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:21:43.642234
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:22:22.013601
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:22:59.324147
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:23:10.798495
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 10:23:19.308121
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:23:32.894097
# ---------------->>>>>>>>---------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec STRONG_SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:23:45.286225
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:23:56.477707
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 10:25:02.864234
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:25:21.875714
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 10:26:31.374411
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:26:49.163209
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 10:27:48.957885
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> APOLLOHOSP <<<<<<----- APOLLOHOSP tradingview rec STRONG_SELL
# ->S<- APOLLOHOSP -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:28:02.519791
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec STRONG_BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:28:15.938994
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 10:29:23.729232
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:29:41.621220
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) False T 2024-07-12 10:30:14.528788
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 10:30:49.478666
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:31:05.684737
# ---------------->>>>>>>>---------------
# ----->>>>> ONGC <<<<<<----- tradingview rec STRONG_BUY
# ->B<- ONGC -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:31:58.059072
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 10:32:20.288962
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> ASIANPAINT <<<<<<----- ASIANPAINT tradingview rec SELL
# ->S<- ASIANPAINT -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 10:32:36.193609
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec STRONG_BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10
------
# ----->>>>> GRASIM <<<<<<----- tradingview rec BUY
# ->B<- GRASIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:59:26.040317
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec STRONG_BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:59:38.137215
# ---------------->>>>>>>>---------------
# ----->>>>> HINDUNILVR <<<<<<----- tradingview rec STRONG_BUY
# ->B<- HINDUNILVR -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 10:59:55.433339
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec STRONG_BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:00:07.958116
# ---------------->>>>>>>>---------------
# ----->>>>> JSWSTEEL <<<<<<----- tradingview rec BUY
# ->B<- JSWSTEEL -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:00:23.733938
# ---------------->>>>>>>>---------------
# ----->>>>> NIFTY <<<<<<----- tradingview rec BUY
# ->B<- NIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:00:44.488723
# ---------------->>>>>>>>---------------
# ----->>>>> SBIN <<<<<<----- tradingview rec STRONG_BUY
# ->B<- SBIN -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:01:00.774702
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 11:01:22.030311
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> NIFTY <<<<<<----- tradingview rec BUY
# ->B<- NIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:01:29.410359
# ---------------->>>>>>>>---------------
# ----->>>>> BANKNIFTY <<<<<<----- tradingview rec BUY
# ->B<- BANKNIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:01:40.449127
# ---------------->>>>>>>>---------------
# ----->>>>> CNXFINANCE <<<<<<----- tradingview rec STRONG_BUY
# ->B<- CNXFINANCE -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:01:52.282688
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec STRONG_BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:02:09.821813
# ---------------->>>>>>>>---------------
# ----->>>>> BAJAJFINSV <<<<<<----- tradingview rec BUY
# ->B<- BAJAJFINSV -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:02:23.853233
# ---------------->>>>>>>>---------------
# ----->>>>> GRASIM <<<<<<----- tradingview rec BUY
# ->B<- GRASIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:02:49.156362
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec STRONG_BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:03:00.026935
# ---------------->>>>>>>>---------------
# ----->>>>> HINDUNILVR <<<<<<----- tradingview rec BUY
# ->B<- HINDUNILVR -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:03:17.576442
# ---------------->>>>>>>>---------------
# ----->>>>> INDUSINDBK <<<<<<----- tradingview rec BUY
# ->B<- INDUSINDBK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:03:29.512906
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:03:40.902788
# ---------------->>>>>>>>---------------
# ----->>>>> JSWSTEEL <<<<<<----- tradingview rec BUY
# ->B<- JSWSTEEL -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:03:54.152545
# ---------------->>>>>>>>---------------
# ----->>>>> NIFTY <<<<<<----- tradingview rec BUY
# ->B<- NIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:04:15.150367
# ---------------->>>>>>>>---------------
# ----->>>>> SBIN <<<<<<----- tradingview rec BUY
# ->B<- SBIN -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:04:33.898422
# ---------------->>>>>>>>---------------
# ----->>>>> TITAN <<<<<<----- tradingview rec BUY
# ->B<- TITAN -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:04:58.827754
# ---------------->>>>>>>>---------------
# ----->>>>> ULTRACEMCO <<<<<<----- tradingview rec BUY
# ->B<- ULTRACEMCO -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:05:10.682438
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 11:05:17.675033
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> NIFTY <<<<<<----- tradingview rec BUY
# ->B<- NIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:05:24.359984
# ---------------->>>>>>>>---------------
# ----->>>>> BANKNIFTY <<<<<<----- tradingview rec BUY
# ->B<- BANKNIFTY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:05:35.026818
# ---------------->>>>>>>>---------------
# ----->>>>> CNXFINANCE <<<<<<----- tradingview rec BUY
# ->B<- CNXFINANCE -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:05:46.165616
# ---------------->>>>>>>>---------------
# ----->>>>> AXISBANK <<<<<<----- tradingview rec BUY
# ->B<- AXISBANK -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:06:02.963169
# ---------------->>>>>>>>---------------
# ----->>>>> GRASIM <<<<<<----- tradingview rec STRONG_BUY
# ->B<- GRASIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:06:29.073089
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:06:40.097756
# ---------------->>>>>>>>---------------
# ----->>>>> HINDUNILVR <<<<<<----- tradingview rec BUY
# ->B<- HINDUNILVR -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:06:56.773848
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11
> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 11:40:40.687520
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:41:03.438280
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:42:03.076220
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 11:42:18.449288
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> GRASIM <<<<<<----- tradingview rec BUY
# ->B<- GRASIM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:43:05.463268
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:43:21.022647
# ---------------->>>>>>>>---------------
# ----->>>>> HINDALCO <<<<<<----- HINDALCO tradingview rec SELL
# ->S<- HINDALCO -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-12 11:43:43.714440
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:44:03.609849
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:45:01.575380
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 11:45:18.142203
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec STRONG_BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:46:10.157499
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:46:38.277725
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:47:36.585058
# ---------------->>>>>>>>---------------
# ----->>>>> TECHM <<<<<<----- tradingview rec BUY
# ->B<- TECHM -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:47:51.628733
# ---------------->>>>>>>>---------------
# ------------Loop completed------------------------------------5 signal used -------------------------------------------------------------- 2024-07-12 11:48:07.123817
# ------------while loop started ------------------------5 signal used ------------------------------------------------------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-12 11:48:58.209817
# ---------------->>>>>>>>---------------
# Place Order API Error!<---BreezeAPI--><----WhileLoop---> ('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File c:\ProgramData\Anaconda3\lib\socket.py:954, in getaddrinfo(host, port, family, type, proto, flags)
#     953 addrlist = []
# --> 954 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File c:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#
# File c:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File c:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000001631BB37070>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#
# File c:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001631BB37070>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 135
#     133     except Exception as error:
#     134       print('Place Order API Error!<---BreezeAPI--><----WhileLoop--->', error)
# --> 135 print("------------Loop completed------------------------------------5 signal used --------------------------------------------------------------", get_recomm_trec(iteam))
#     136 #break
#
# Cell In[1], line 84, in get_recomm_trec(symbols)
#      82 def get_recomm_trec(symbols):
#      83     output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
# ---> 84     return output.get_analysis().time
#
# File c:\ProgramData\Anaconda3\lib\site-packages\tradingview_ta\main.py:387, in TA_Handler.get_analysis(self)
#     380 def get_analysis(self):
#     381     """Get analysis from TradingView and compute it.
#     382
#     383     Returns:
#     384         Analysis: Contains information about the analysis.
#     385     """
# --> 387     return calculate(indicators=self.get_indicators(), indicators_key=self.indicators, screener=self.screener, symbol=self.symbol, exchange=self.exchange, interval=self.interval)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\tradingview_ta\main.py:353, in TA_Handler.get_indicators(self, indicators)
#     351 scan_url = f"{TradingView.scan_url}{self.screener.lower()}/scan"
#     352 headers = {"User-Agent": "tradingview_ta/{}".format(__version__)}
# --> 353 response = requests.post(
#     354     scan_url, json=data, headers=headers, timeout=self.timeout, proxies=self.proxies)
#     356 # Return False if can't get data
#     357 if response.status_code != 200:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\adapters.py:622, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     618     if isinstance(e.reason, _SSLError):
#     619         # This branch is for urllib3 v1.22 and later.
#     620         raise SSLError(e, request=request)
# --> 622     raise ConnectionError(e, request=request)
#     624 except ClosedPoolError as e:
#     625     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='scanner.tradingview.com', port=443): Max retries exceeded with url: /india/scan (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001631BB37070>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
