# %%
# This function installs Breeze library
def install():
    python = sys.executable
    subprocess.check_call([python, '-m', 'pip', 'install', 'breeze_connect'], stdout=subprocess.DEVNULL)
    print('Successfully installed Breeze !!')
    subprocess.check_call([python, '-m', 'pip', 'install', 'tradingview_ta'], stdout=subprocess.DEVNULL)
    print('Successfully installed tradingView !!')
    subprocess.check_call([python, '-m', 'pip', 'install', 'timedelta'], stdout=subprocess.DEVNULL)
    print('Successfully installed timedelta !!')
    subprocess.check_call([python, '-m', 'pip', 'install', 'pandas'], stdout=subprocess.DEVNULL)
    print('Successfully installed pandas !!')
    subprocess.check_call([python, '-m', 'pip', 'install', 'numpy'], stdout=subprocess.DEVNULL)
    print('Successfully installed numpy !!')
    subprocess.check_call([python, '-m', 'pip', 'install', 'breeze_strategies==1.0.22'], stdout=subprocess.DEVNULL)
    print('Successfully installed breeze_strategies !!')
    subprocess.check_call([python, '-m', 'pip', 'install', 'alice_blue'], stdout=subprocess.DEVNULL)
    print('Successfully installed alice_blue !!')
    subprocess.check_call([python, '-m', 'pip', 'install', 'pya3'], stdout=subprocess.DEVNULL)
    print('Successfully installed pya3 !!')

# Import necessary libraries
import sys, subprocess, pkg_resources
module=True

while(module):
    try:
        from breeze_connect import BreezeConnect
        from tradingview_ta import TA_Handler, Interval, Exchange
        from breeze_strategies import Strategies
        import pandas as pd
        import numpy as np
        from alice_blue import *
        from pya3 import *
        from datetime import datetime
        from datetime import timedelta
        module=False
    except ModuleNotFoundError:
        print("module 'breeze_connect' is not installed. Installing it now...")
        print("module 'tradingview_ta' is not installed. Installing it now...")
        print("module 'timedelta' is not installed. Installing it now...")
        print("module 'pandas' is not installed. Installing it now...")
        print("module 'numpy' is not installed. Installing it now...")
        print("module 'breeze_strategies' is not installed. Installing it now...")
        print("module 'pandas' is not installed. Installing it now...")
        print("module 'alice_blue' is not installed. Installing it now...")
        print("module 'pya3' is not installed. Installing it now...")
        install()
print("Module install done")
from google.colab import drive
drive.mount('/content/drive')
now = datetime.now()
print("now =", now)
path='/content/drive/My Drive/My Folder/userid.txt'
f = open(path,'r'); a1 = f.readlines()
a1 = [x.strip() for x in a1]; # sb="NIFTY"; sr="cfd"; ex="NSE" #  trading View exchange code
print(a1[0], "\t", a1[1] ,"\t", a1[2])
# Out:
# module 'breeze_connect' is not installed. Installing it now...
# module 'tradingview_ta' is not installed. Installing it now...
# module 'timedelta' is not installed. Installing it now...
# module 'pandas' is not installed. Installing it now...
# module 'numpy' is not installed. Installing it now...
# module 'breeze_strategies' is not installed. Installing it now...
# module 'pandas' is not installed. Installing it now...
# module 'alice_blue' is not installed. Installing it now...
# module 'pya3' is not installed. Installing it now...
# Successfully installed Breeze !!
# Successfully installed tradingView !!
# Successfully installed timedelta !!
# Successfully installed pandas !!
# Successfully installed numpy !!
# Successfully installed breeze_strategies !!
# Successfully installed alice_blue !!
# Successfully installed pya3 !!
# Module install done
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-7de025af4b25> in <cell line: 50>()
#      48 print("Module install done")
#      49 from google.colab import drive
# ---> 50 drive.mount('/content/drive')
#      51 now = datetime.now()
#      52 print("now =", now)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     281             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     282         )
# --> 283       raise ValueError('mount failed' + extra_reason)
#     284     elif case == 4:
#     285       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %%
#Change Value " sb , sr, ex, -STOCK,EXCODE,psp,csp,exp, order_type, get_instrument_by_token, quantity, price", ---ICICI direct stock# STOCK="NIFTY"; EXCODE="NFO";psp="17700"; csp="17600"; qt="100"; exp="2023-04-20T06:00:00.000Z"; vdate="2023-04-15T06:00:00.000Z" # broker stock code   ##import os; import urllib;
from tradingview_ta import TA_Handler, Interval, Exchange; import time; import datetime; import pandas as pd;  from breeze_connect import BreezeConnect
sb="NIFTY";sr="india"; ex="NSE"; #  trading View exchange code #sb="BANKNIFTY"; sr="india"; ex="NSE" #  trading View exchange code #sb="CNXFINANCE"; sr="india"; ex="NSE" #  trading View exchange code # sb="BTCUSD"; sr="crypto" ; ex="BINANCE"; #sb="USOIL"; sr="cfd" ; ex="FX"; #Tok_A = 425903; ex='MCX'; qt = 1; #  trading View exchange code Crude oil
symbols = ['COROMANDEL','GLENMARK','SUNTV','DIVISLAB','SBILIFE','SYNGENE','EXIDEIND','HDFCLIFE','IGL','MUTHOOTFIN','IPCALAB','HEROMOTOCO','MFSL','GRASIM','AARTIIND','HDFCAMC','AUROPHARMA','BERGEPAINT','ASIANPAINT',
            'OBEROIRLTY','JUBLFOOD','DRREDDY','HINDCOPPER','ICICIPRULI','COLPAL','LAURUSLABS','ZEEL','ABFRL','PIDILITIND','CUMMINSIND','LTTS','MARICO','SHREECEM','GNFC','BRITANNIA','ICICIGI','BIOCON','WIPRO','SHRIRAMFIN','HINDUNILVR',
            'LICHSGFIN','HCLTECH','CANFINHOME','UBL','JSWSTEEL','HINDALCO','BALRAMCHIN','TORNTPHARM','PFC','AUBANK','TATACONSUM','SBICARD','TITAN','BAJAJFINSV','BATAINDIA','LT','METROPOLIS','BANDHANBNK','HAVELLS','ABCAPITAL','CIPLA',
            'PIIND','HDFCBANK','SUNPHARMA','ASHOKLEY','CROMPTON','TVSMOTOR','ALKEM','BALKRISIND','INDIACEM','LTIM','DABUR','CUB','JKCEMENT','NESTLEIND','BAJFINANCE','TATASTEEL','RECLTD','TCS','IDFC',
            'ULTRACEMCO','ICICIBANK','SBIN','GODREJCP','ZYDUSLIFE','ESCORTS','JINDALSTEL','INDUSTOWER','AXISBANK','ACC','GMRINFRA','INFY','BHARATFORG','EICHERMOT','PVRINOX','OFSS','ITC','KOTAKBANK','LALPATHLAB','APOLLOTYRE','MGL',
            'CHOLAFIN','MARUTI','RELIANCE','RAMCOCEM','INDIAMART','ATUL','DALBHARAT','TATACHEM','TATACOMM','AMBUJACEM','IDFCFIRSTB','LUPIN','APOLLOHOSP','PAGEIND','GRANULES','CANBK','RBLBANK','VEDL','INDUSINDBK','GAIL','NAVINFLUOR',
            'BHARTIARTL','LTF','VOLTAS','MCX','TATAMOTORS','TECHM','ONGC','CHAMBLFERT','SIEMENS','MRF','SRF','ABBOTINDIA','IOC','NATIONALUM','MOTHERSON','PEL','TRENT','PNB','NTPC','ASTRAL','INDIGO','NMDC','UPL','ADANIENT','COALINDIA',
            'PERSISTENT','MANAPPURAM','BPCL','POWERGRID','IRCTC','INDHOTEL','GUJGASLTD','MPHASIS','DIXON','BOSCHLTD','BEL','TATAPOWER','DEEPAKNTR','POLYCAB','ABB','PETRONET','HINDPETRO','ADANIPORTS','CONCOR','FEDERALBNK','COFORGE','IEX',
            'BSOFT','GODREJPROP','SAIL','HAL','BHEL','BANKBARODA','DLF','NAUKRI','IDEA',]
try:
    def get_recomm(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return output.get_analysis().summary['RECOMMENDATION']

    def get_recomm_rsi(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["RSI"])

    def get_recomm_CP(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["close"])

    def get_recomm_R1(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.R1"])

    def get_recomm_S1(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.S1"])

    def get_recomm_R2(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.R2"])

    def get_recomm_S2(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.S2"])

    def get_recomm_PV(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.Middle"])

    def get_recomm_ema5(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA5"])

    def get_recomm_ema10(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA10"])

    def get_recomm_ema20(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA20"])

    def get_recomm_SK(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["Stoch.K"])

    def get_recomm_SD(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["Stoch.D"])
    def get_recomm_MACD_m(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["MACD.macd"])

    def get_recomm_MACD_s(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["MACD.signal"])

    def get_recomm_trec(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return output.get_analysis().time
except Exception as error:
          print('Place Order API Error!<---BreezeAPI-->', error)
last_buy = False
last_sell = False
loop_counter = 0
#while  loop_counter < 2:
while True:
    print("------------while loop started ------------------------5 signal used ------------------------------------------------------------") #,get_recomm_trec(symbols))
    for iteam in symbols:
        try:
            #print("<-b/s->",iteam,"<-", get_recomm(iteam), "(RSI>50)", 50 < get_recomm_rsi(iteam), "(CP)", round(get_recomm_CP(iteam),2), "(RSI)", round(get_recomm_rsi(iteam),2),"<CP>R1>", get_recomm_CP(iteam) > get_recomm_R1(iteam),"<CP>PV>", get_recomm_CP(iteam) > get_recomm_PV(iteam),"<CP<S1>", get_recomm_CP(iteam) < get_recomm_S1(iteam),"(R1)", round(get_recomm_R1(iteam),2), "(S1)", round(get_recomm_S1(iteam),2),"(R2)", round(get_recomm_R2(iteam),2), "(S2)", round(get_recomm_S2(iteam),2),
            #        "<PV>", round(get_recomm_PV(iteam),2), "<MACD_M>", round(get_recomm_MACD_m(iteam),2), "<MACD_S>", round(get_recomm_MACD_s(iteam),2),  "<SK>", round(get_recomm_SK(iteam),2), "<SD>", round(get_recomm_SD(iteam),2), get_recomm_trec(iteam) )
            # if "BUY" in get_recomm(iteam) and 50 < get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R1(iteam):# and get_recomm_ema10(iteam) > get_recomm_ema20(iteam): # and not last_buy:
            if "BUY" in get_recomm(iteam) and 50 < get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R1(iteam) and get_recomm_SK(iteam)>get_recomm_SD(iteam) and  get_recomm_ema10(iteam) > get_recomm_ema20(iteam) and get_recomm_MACD_m(iteam) > get_recomm_MACD_s(iteam)  :# and get_recomm_ema10(iteam) > get_recomm_ema20(iteam): # and not last_buy:
                    print ("----->>>>>",iteam, "<<<<<<-----","tradingview rec", get_recomm(iteam)); # winsound.Beep(frequency, duration)
                    print("->B<-",iteam,"->", "(:CP:)", round(get_recomm_CP(iteam),2), "(CP>R1)", get_recomm_CP(iteam) > get_recomm_R1(iteam),"(RSI>50)",50 < get_recomm_rsi(iteam), "(SK>SD)", get_recomm_SK(iteam)>get_recomm_SD(iteam),"EMACROSS", get_recomm_ema10(iteam) > get_recomm_ema20(iteam), "(MACD_m>MACD_s)", get_recomm_MACD_m(iteam) > get_recomm_MACD_s(iteam),"T", get_recomm_trec(iteam))
                    with open('/content/drive/My Drive/SK_OUT/07_2024/B-(F-O-186)(07-04-9151)_5IND.txt', 'a') as f:
                          text_to_write = f"{str(iteam)} , {get_recomm(iteam)}, 'CP', {str(get_recomm_CP(iteam))}, 'RSI>50', {str(50 < get_recomm_rsi(iteam))}, {str(round(get_recomm_rsi(iteam),1))},'CP>R1', {str(get_recomm_CP(iteam) > get_recomm_R1(iteam))} , 'R1', {str(round(get_recomm_R1(iteam),2))},'R2', {str(round(get_recomm_R2(iteam),2))}, 'CP<S1', {str(get_recomm_CP(iteam) < get_recomm_S1(iteam))},'S1', {str(round(get_recomm_S1(iteam),2))} ,S2', {str(round(get_recomm_S2(iteam),2))} {str(get_recomm_trec(iteam))}\n"
                          #text_to_write = f"{get_recomm(iteam)} {str(iteam)} {str(get_recomm_CP(iteam))} {str(get_recomm_rsi(iteam))} {str(get_recomm_R1(iteam))} {str(get_recomm_R2(iteam))} {str(get_recomm_S1(iteam))} {str(get_recomm_S2(iteam))} {str(get_recomm_trec(iteam))}\n"
                          f.write(text_to_write)
                    print("---------------->>>>>>>>---------------")
                    #last_buy = True
                    #last_sell = False

            if "SELL" in get_recomm(iteam) and 50 > get_recomm_rsi(iteam) and get_recomm_CP(iteam) < get_recomm_S1(iteam) and get_recomm_SK(iteam)<get_recomm_SD(iteam) and  get_recomm_ema10(iteam) < get_recomm_ema20(iteam) and get_recomm_MACD_m(iteam) < get_recomm_MACD_s(iteam) : # and get_recomm_ema10(iteam) < get_recomm_ema20(iteam):# and not last_sell:
                    print ("----->>>>>",iteam, "<<<<<<-----",iteam, "tradingview rec", get_recomm(iteam)); # winsound.Beep(frequency, duration)
                    print("->S<-",iteam,"->", "(:CP:)", round(get_recomm_CP(iteam),2),"CP<S1", get_recomm_CP(iteam) < get_recomm_S1(iteam), "(RSI<50)",50 > get_recomm_rsi(iteam), "(SK<SD)", get_recomm_SK(iteam)<get_recomm_SD(iteam),"EMA**", get_recomm_ema10(iteam) < get_recomm_ema20(iteam), "(MACD_m<MACD_s)", get_recomm_MACD_m(iteam) < get_recomm_MACD_s(iteam),"T", get_recomm_trec(iteam))
                    with open('/content/drive/My Drive/SK_OUT/07_2024/S-(F-O-186)(07-04-9151)_5IND.txt', 'a') as f:
                        text_to_write = f"{str(iteam)} , {get_recomm(iteam)},'CP', {str(get_recomm_CP(iteam))}, 'RSI>50', {str(50 < get_recomm_rsi(iteam))}, {str(round(get_recomm_rsi(iteam),1))},'CP>R1', {str(get_recomm_CP(iteam) > get_recomm_R1(iteam))} , 'R1', {str(round(get_recomm_R1(iteam),2))},'R2', {str(round(get_recomm_R2(iteam),2))}, 'CP<S1', {str(get_recomm_CP(iteam) < get_recomm_S1(iteam))},'S1', {str(round(get_recomm_S1(iteam),2))} ,S2', {str(round(get_recomm_S2(iteam),2))} {str(get_recomm_trec(iteam))}\n"
                        #text_to_write = f"{get_recomm(iteam)} {str(iteam)} {str(get_recomm_CP(iteam))} {str(get_recomm_rsi(iteam))} {str(get_recomm_R1(iteam))} {str(get_recomm_R2(iteam))} {str(get_recomm_S1(iteam))} {str(get_recomm_S2(iteam))} {str(get_recomm_trec(iteam))}\n"
                        f.write(text_to_write)
                    print("---------------->>>>>>>>---------------")
                    #last_buy = False
                    #last_sell = True
            #else: # 45 > get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R(iteam):
                    #print("----->>>>Stoploss<<<<<---- order exec", iteam)
                    #if 48 > get_recomm_rsi(iteam): # and get_recomm_CP(iteam) < get_recomm_R1(iteam):
                        #print("---------------------------->>>>Stoploss<<<<<---- order exec", iteam, get_recomm_CP(iteam) < get_recomm_R1(iteam))
        #loop_counter += 1 # break
        #break

        except Exception as error:
          print('Place Order API Error!<---BreezeAPI--><----WhileLoop--->', error)
    print("------------Loop completed------------------------------------5 signal used -----------------------------------------", get_recomm_trec(iteam))
    break
# Out:
# Streaming output truncated to the last 5000 lines.
# ---------------->>>>>>>>---------------
# ----->>>>> NATIONALUM <<<<<<----- tradingview rec BUY
# ->B<- NATIONALUM -> (:CP:) 196.87 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 03:59:19.549617
# ---------------->>>>>>>>---------------
# ----->>>>> MOTHERSON <<<<<<----- tradingview rec BUY
# ->B<- MOTHERSON -> (:CP:) 207.15 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 03:59:25.447515
# ---------------->>>>>>>>---------------
# ----->>>>> NTPC <<<<<<----- tradingview rec BUY
# ->B<- NTPC -> (:CP:) 376.25 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 03:59:33.038932
# ---------------->>>>>>>>---------------
# ----->>>>> ASTRAL <<<<<<----- ASTRAL tradingview rec SELL
# ->S<- ASTRAL -> (:CP:) 2365.6 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 03:59:37.687643
# ---------------->>>>>>>>---------------
# ----->>>>> INDIGO <<<<<<----- tradingview rec BUY
# ->B<- INDIGO -> (:CP:) 4291.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 03:59:42.958261
# ---------------->>>>>>>>---------------
# ----->>>>> INDHOTEL <<<<<<----- tradingview rec STRONG_BUY
# ->B<- INDHOTEL -> (:CP:) 610.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 03:59:53.494089
# ---------------->>>>>>>>---------------
# ----->>>>> MPHASIS <<<<<<----- tradingview rec STRONG_BUY
# ->B<- MPHASIS -> (:CP:) 2592.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 03:59:59.924961
# ---------------->>>>>>>>---------------
# ----->>>>> HINDPETRO <<<<<<----- tradingview rec BUY
# ->B<- HINDPETRO -> (:CP:) 332.85 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:00:10.072463
# ---------------->>>>>>>>---------------
# ----->>>>> COFORGE <<<<<<----- tradingview rec BUY
# ->B<- COFORGE -> (:CP:) 5811.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:00:16.950270
# ---------------->>>>>>>>---------------
# ----->>>>> HAL <<<<<<----- tradingview rec BUY
# ->B<- HAL -> (:CP:) 5518.65 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:00:24.275185
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> SBILIFE <<<<<<----- tradingview rec BUY
# ->B<- SBILIFE -> (:CP:) 1508.35 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:00:35.621379
# ---------------->>>>>>>>---------------
# ----->>>>> CUMMINSIND <<<<<<----- tradingview rec BUY
# ->B<- CUMMINSIND -> (:CP:) 4017.45 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:00:55.797362
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (:CP:) 1500.65 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:01:07.297194
# ---------------->>>>>>>>---------------
# ----->>>>> CIPLA <<<<<<----- CIPLA tradingview rec SELL
# ->S<- CIPLA -> (:CP:) 1470.7 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:01:22.646567
# ---------------->>>>>>>>---------------
# ----->>>>> HDFCBANK <<<<<<----- HDFCBANK tradingview rec SELL
# ->S<- HDFCBANK -> (:CP:) 1744.25 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:01:29.103579
# ---------------->>>>>>>>---------------
# ----->>>>> LTIM <<<<<<----- tradingview rec BUY
# ->B<- LTIM -> (:CP:) 5509.9 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:01:37.826737
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (:CP:) 4015.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:01:48.392023
# ---------------->>>>>>>>---------------
# ----->>>>> ICICIBANK <<<<<<----- tradingview rec BUY
# ->B<- ICICIBANK -> (:CP:) 1220.9 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:01:54.256466
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (:CP:) 1651.6 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:02:05.387930
# ---------------->>>>>>>>---------------
# ----->>>>> APOLLOTYRE <<<<<<----- APOLLOTYRE tradingview rec SELL
# ->S<- APOLLOTYRE -> (:CP:) 527.6 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:02:14.912954
# ---------------->>>>>>>>---------------
# ----->>>>> MGL <<<<<<----- MGL tradingview rec SELL
# ->S<- MGL -> (:CP:) 1680.1 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:02:19.367838
# ---------------->>>>>>>>---------------
# ----->>>>> RAMCOCEM <<<<<<----- RAMCOCEM tradingview rec STRONG_SELL
# ->S<- RAMCOCEM -> (:CP:) 829.2 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:02:27.012954
# ---------------->>>>>>>>---------------
# ----->>>>> ATUL <<<<<<----- ATUL tradingview rec SELL
# ->S<- ATUL -> (:CP:) 6531.6 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:02:31.795083
# ---------------->>>>>>>>---------------
# ----->>>>> LUPIN <<<<<<----- tradingview rec BUY
# ->B<- LUPIN -> (:CP:) 1682.25 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:02:38.833329
# ---------------->>>>>>>>---------------
# ----->>>>> VOLTAS <<<<<<----- VOLTAS tradingview rec SELL
# ->S<- VOLTAS -> (:CP:) 1438.45 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:02:51.212985
# ---------------->>>>>>>>---------------
# ----->>>>> IOC <<<<<<----- tradingview rec BUY
# ->B<- IOC -> (:CP:) 171.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:03:03.470165
# ---------------->>>>>>>>---------------
# ----->>>>> MOTHERSON <<<<<<----- tradingview rec BUY
# ->B<- MOTHERSON -> (:CP:) 207.71 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:03:10.015505
# ---------------->>>>>>>>---------------
# ----->>>>> TRENT <<<<<<----- tradingview rec STRONG_BUY
# ->B<- TRENT -> (:CP:) 5584.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:03:16.348589
# ---------------->>>>>>>>---------------
# ----->>>>> NTPC <<<<<<----- tradingview rec BUY
# ->B<- NTPC -> (:CP:) 376.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:03:22.033642
# ---------------->>>>>>>>---------------
# ----->>>>> ASTRAL <<<<<<----- ASTRAL tradingview rec SELL
# ->S<- ASTRAL -> (:CP:) 2365.5 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:03:28.266981
# ---------------->>>>>>>>---------------
# ----->>>>> IRCTC <<<<<<----- tradingview rec STRONG_BUY
# ->B<- IRCTC -> (:CP:) 1010.85 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:03:39.831193
# ---------------->>>>>>>>---------------
# ----->>>>> INDHOTEL <<<<<<----- tradingview rec BUY
# ->B<- INDHOTEL -> (:CP:) 613.45 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:03:45.447939
# ---------------->>>>>>>>---------------
# ----->>>>> CONCOR <<<<<<----- tradingview rec BUY
# ->B<- CONCOR -> (:CP:) 1037.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:03:58.683870
# ---------------->>>>>>>>---------------
# ----->>>>> COFORGE <<<<<<----- tradingview rec BUY
# ->B<- COFORGE -> (:CP:) 5798.75 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:04:04.014699
# ---------------->>>>>>>>---------------
# ----->>>>> HAL <<<<<<----- tradingview rec BUY
# ->B<- HAL -> (:CP:) 5520.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:04:12.407931
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> CUMMINSIND <<<<<<----- tradingview rec BUY
# ->B<- CUMMINSIND -> (:CP:) 4038.85 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:04:39.094915
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (:CP:) 1500.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:04:49.504523
# ---------------->>>>>>>>---------------
# ----->>>>> JSWSTEEL <<<<<<----- tradingview rec BUY
# ->B<- JSWSTEEL -> (:CP:) 956.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:04:56.307031
# ---------------->>>>>>>>---------------
# ----->>>>> HDFCBANK <<<<<<----- HDFCBANK tradingview rec SELL
# ->S<- HDFCBANK -> (:CP:) 1742.85 CP<S1 True (RSI<50) True (SK<SD) False EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:05:11.513929
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (:CP:) 4015.55 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:05:26.690657
# ---------------->>>>>>>>---------------
# ----->>>>> ICICIBANK <<<<<<----- tradingview rec BUY
# ->B<- ICICIBANK -> (:CP:) 1221.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:05:32.521704
# ---------------->>>>>>>>---------------
# ----->>>>> GMRINFRA <<<<<<----- tradingview rec BUY
# ->B<- GMRINFRA -> (:CP:) 97.33 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:05:44.136822
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (:CP:) 1654.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:05:49.007178
# ---------------->>>>>>>>---------------
# ----->>>>> MGL <<<<<<----- MGL tradingview rec SELL
# ->S<- MGL -> (:CP:) 1675.75 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:06:00.221308
# ---------------->>>>>>>>---------------
# ----->>>>> RAMCOCEM <<<<<<----- RAMCOCEM tradingview rec SELL
# ->S<- RAMCOCEM -> (:CP:) 831.5 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:06:07.428111
# ---------------->>>>>>>>---------------
# ----->>>>> LUPIN <<<<<<----- tradingview rec BUY
# ->B<- LUPIN -> (:CP:) 1686.3 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:06:15.669003
# ---------------->>>>>>>>---------------
# ----->>>>> MOTHERSON <<<<<<----- tradingview rec BUY
# ->B<- MOTHERSON -> (:CP:) 208.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:06:37.705759
# ---------------->>>>>>>>---------------
# ----->>>>> NTPC <<<<<<----- tradingview rec STRONG_BUY
# ->B<- NTPC -> (:CP:) 378.6 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:06:45.342615
# ---------------->>>>>>>>---------------
# ----->>>>> IRCTC <<<<<<----- tradingview rec BUY
# ->B<- IRCTC -> (:CP:) 1010.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:06:56.681066
# ---------------->>>>>>>>---------------
# ----->>>>> INDHOTEL <<<<<<----- tradingview rec STRONG_BUY
# ->B<- INDHOTEL -> (:CP:) 613.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:07:01.700040
# ---------------->>>>>>>>---------------
# ----->>>>> TATAPOWER <<<<<<----- tradingview rec STRONG_BUY
# ->B<- TATAPOWER -> (:CP:) 436.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:07:10.486920
# ---------------->>>>>>>>---------------
# ----->>>>> CONCOR <<<<<<----- tradingview rec BUY
# ->B<- CONCOR -> (:CP:) 1038.6 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:07:18.660984
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> CUMMINSIND <<<<<<----- tradingview rec BUY
# ->B<- CUMMINSIND -> (:CP:) 4040.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:07:48.550842
# ---------------->>>>>>>>---------------
# ----->>>>> LTTS <<<<<<----- tradingview rec STRONG_BUY
# ->B<- LTTS -> (:CP:) 5071.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:07:54.618610
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (:CP:) 1499.7 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:08:04.780184
# ---------------->>>>>>>>---------------
# ----->>>>> PFC <<<<<<----- tradingview rec STRONG_BUY
# ->B<- PFC -> (:CP:) 539.45 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:08:13.765276
# ---------------->>>>>>>>---------------
# ----->>>>> CIPLA <<<<<<----- CIPLA tradingview rec STRONG_SELL
# ->S<- CIPLA -> (:CP:) 1469.5 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:08:24.901354
# ---------------->>>>>>>>---------------
# ----->>>>> HDFCBANK <<<<<<----- HDFCBANK tradingview rec SELL
# ->S<- HDFCBANK -> (:CP:) 1740.45 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:08:29.912170
# ---------------->>>>>>>>---------------
# ----->>>>> RECLTD <<<<<<----- tradingview rec BUY
# ->B<- RECLTD -> (:CP:) 573.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:08:42.871092
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (:CP:) 4015.35 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:08:47.312081
# ---------------->>>>>>>>---------------
# ----->>>>> ICICIBANK <<<<<<----- tradingview rec BUY
# ->B<- ICICIBANK -> (:CP:) 1220.7 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:08:53.774867
# ---------------->>>>>>>>---------------
# ----->>>>> GMRINFRA <<<<<<----- tradingview rec STRONG_BUY
# ->B<- GMRINFRA -> (:CP:) 97.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:09:02.780191
# ---------------->>>>>>>>---------------
# ----->>>>> MGL <<<<<<----- MGL tradingview rec SELL
# ->S<- MGL -> (:CP:) 1677.4 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:09:13.793223
# ---------------->>>>>>>>---------------
# ----->>>>> RAMCOCEM <<<<<<----- RAMCOCEM tradingview rec SELL
# ->S<- RAMCOCEM -> (:CP:) 832.5 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:09:20.439518
# ---------------->>>>>>>>---------------
# ----->>>>> LUPIN <<<<<<----- tradingview rec BUY
# ->B<- LUPIN -> (:CP:) 1681.1 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:09:29.215548
# ---------------->>>>>>>>---------------
# ----->>>>> IOC <<<<<<----- tradingview rec BUY
# ->B<- IOC -> (:CP:) 171.2 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:09:47.010385
# ---------------->>>>>>>>---------------
# ----->>>>> MOTHERSON <<<<<<----- tradingview rec BUY
# ->B<- MOTHERSON -> (:CP:) 208.44 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:09:53.679621
# ---------------->>>>>>>>---------------
# ----->>>>> NTPC <<<<<<----- tradingview rec BUY
# ->B<- NTPC -> (:CP:) 379.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:09:59.486934
# ---------------->>>>>>>>---------------
# ----->>>>> IRCTC <<<<<<----- tradingview rec STRONG_BUY
# ->B<- IRCTC -> (:CP:) 1015.1 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:10:12.189795
# ---------------->>>>>>>>---------------
# ----->>>>> TATAPOWER <<<<<<----- tradingview rec BUY
# ->B<- TATAPOWER -> (:CP:) 439.1 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:10:21.377121
# ---------------->>>>>>>>---------------
# ----->>>>> CONCOR <<<<<<----- tradingview rec BUY
# ->B<- CONCOR -> (:CP:) 1039.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:10:29.418893
# ---------------->>>>>>>>---------------
# ----->>>>> BSOFT <<<<<<----- tradingview rec BUY
# ->B<- BSOFT -> (:CP:) 721.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:10:37.432546
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> LICHSGFIN <<<<<<----- LICHSGFIN tradingview rec SELL
# ->S<- LICHSGFIN -> (:CP:) 793.15 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:11:11.187788
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (:CP:) 1498.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:11:15.448766
# ---------------->>>>>>>>---------------
# ----->>>>> PFC <<<<<<----- tradingview rec BUY
# ->B<- PFC -> (:CP:) 540.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:11:24.387824
# ---------------->>>>>>>>---------------
# ----->>>>> CIPLA <<<<<<----- CIPLA tradingview rec SELL
# ->S<- CIPLA -> (:CP:) 1471.1 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:11:36.274117
# ---------------->>>>>>>>---------------
# ----->>>>> HDFCBANK <<<<<<----- HDFCBANK tradingview rec SELL
# ->S<- HDFCBANK -> (:CP:) 1741.55 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:11:41.503834
# ---------------->>>>>>>>---------------
# ----->>>>> RECLTD <<<<<<----- tradingview rec BUY
# ->B<- RECLTD -> (:CP:) 574.65 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:11:54.142313
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (:CP:) 4016.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:11:58.579228
# ---------------->>>>>>>>---------------
# ----->>>>> ICICIBANK <<<<<<----- tradingview rec BUY
# ->B<- ICICIBANK -> (:CP:) 1221.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:12:05.063184
# ---------------->>>>>>>>---------------
# ----->>>>> GMRINFRA <<<<<<----- tradingview rec BUY
# ->B<- GMRINFRA -> (:CP:) 97.85 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:12:15.693509
# ---------------->>>>>>>>---------------
# ----->>>>> APOLLOTYRE <<<<<<----- APOLLOTYRE tradingview rec SELL
# ->S<- APOLLOTYRE -> (:CP:) 526.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:12:27.226325
# ---------------->>>>>>>>---------------
# ----->>>>> MGL <<<<<<----- MGL tradingview rec SELL
# ->S<- MGL -> (:CP:) 1678.15 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:12:32.693841
# ---------------->>>>>>>>---------------
# ----->>>>> ATUL <<<<<<----- ATUL tradingview rec SELL
# ->S<- ATUL -> (:CP:) 6536.95 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:12:40.620916
# ---------------->>>>>>>>---------------
# ----->>>>> MOTHERSON <<<<<<----- tradingview rec BUY
# ->B<- MOTHERSON -> (:CP:) 208.2 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:13:02.461426
# ---------------->>>>>>>>---------------
# ----->>>>> NTPC <<<<<<----- tradingview rec STRONG_BUY
# ->B<- NTPC -> (:CP:) 379.7 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:13:09.222840
# ---------------->>>>>>>>---------------
# ----->>>>> IRCTC <<<<<<----- tradingview rec BUY
# ->B<- IRCTC -> (:CP:) 1015.2 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:13:21.217767
# ---------------->>>>>>>>---------------
# ----->>>>> INDHOTEL <<<<<<----- tradingview rec BUY
# ->B<- INDHOTEL -> (:CP:) 616.3 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:13:25.662315
# ---------------->>>>>>>>---------------
# ----->>>>> GUJGASLTD <<<<<<----- GUJGASLTD tradingview rec SELL
# ->S<- GUJGASLTD -> (:CP:) 629.8 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:13:30.204944
# ---------------->>>>>>>>---------------
# ----->>>>> BSOFT <<<<<<----- tradingview rec BUY
# ->B<- BSOFT -> (:CP:) 720.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:13:47.015639
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> LTTS <<<<<<----- tradingview rec BUY
# ->B<- LTTS -> (:CP:) 5072.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:14:16.749980
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec STRONG_BUY
# ->B<- HCLTECH -> (:CP:) 1504.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:14:28.061429
# ---------------->>>>>>>>---------------
# ----->>>>> PFC <<<<<<----- tradingview rec BUY
# ->B<- PFC -> (:CP:) 540.55 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:14:37.559023
# ---------------->>>>>>>>---------------
# ----->>>>> BAJAJFINSV <<<<<<----- tradingview rec STRONG_BUY
# ->B<- BAJAJFINSV -> (:CP:) 1603.55 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:14:44.751224
# ---------------->>>>>>>>---------------
# ----->>>>> ABCAPITAL <<<<<<----- tradingview rec BUY
# ->B<- ABCAPITAL -> (:CP:) 239.09 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:14:54.438985
# ---------------->>>>>>>>---------------
# ----->>>>> RECLTD <<<<<<----- tradingview rec STRONG_BUY
# ->B<- RECLTD -> (:CP:) 578.6 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:15:10.082301
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec STRONG_BUY
# ->B<- TCS -> (:CP:) 4023.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:15:14.910535
# ---------------->>>>>>>>---------------
# ----->>>>> ICICIBANK <<<<<<----- tradingview rec BUY
# ->B<- ICICIBANK -> (:CP:) 1222.85 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:15:21.342290
# ---------------->>>>>>>>---------------
# ----->>>>> GMRINFRA <<<<<<----- tradingview rec BUY
# ->B<- GMRINFRA -> (:CP:) 98.15 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:15:31.408606
# ---------------->>>>>>>>---------------
# ----->>>>> ATUL <<<<<<----- ATUL tradingview rec SELL
# ->S<- ATUL -> (:CP:) 6532.6 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:15:46.441957
# ---------------->>>>>>>>---------------
# ----->>>>> INDIGO <<<<<<----- tradingview rec BUY
# ->B<- INDIGO -> (:CP:) 4294.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:16:12.186860
# ---------------->>>>>>>>---------------
# ----->>>>> COALINDIA <<<<<<----- tradingview rec BUY
# ->B<- COALINDIA -> (:CP:) 489.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:16:18.837587
# ---------------->>>>>>>>---------------
# ----->>>>> IRCTC <<<<<<----- tradingview rec BUY
# ->B<- IRCTC -> (:CP:) 1012.7 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:16:25.254659
# ---------------->>>>>>>>---------------
# ----->>>>> INDHOTEL <<<<<<----- tradingview rec BUY
# ->B<- INDHOTEL -> (:CP:) 616.75 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:16:30.396477
# ---------------->>>>>>>>---------------
# ----->>>>> GUJGASLTD <<<<<<----- GUJGASLTD tradingview rec SELL
# ->S<- GUJGASLTD -> (:CP:) 629.7 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:16:35.341476
# ---------------->>>>>>>>---------------
# ----->>>>> MPHASIS <<<<<<----- tradingview rec STRONG_BUY
# ->B<- MPHASIS -> (:CP:) 2595.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:16:40.100531
# ---------------->>>>>>>>---------------
# ----->>>>> TATAPOWER <<<<<<----- tradingview rec BUY
# ->B<- TATAPOWER -> (:CP:) 440.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:16:48.237093
# ---------------->>>>>>>>---------------
# ----->>>>> COFORGE <<<<<<----- tradingview rec BUY
# ->B<- COFORGE -> (:CP:) 5810.25 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:16:57.180174
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> SBILIFE <<<<<<----- tradingview rec BUY
# ->B<- SBILIFE -> (:CP:) 1510.3 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:17:09.961996
# ---------------->>>>>>>>---------------
# ----->>>>> LTTS <<<<<<----- tradingview rec BUY
# ->B<- LTTS -> (:CP:) 5075.35 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:17:29.857258
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (:CP:) 1506.25 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:17:41.342514
# ---------------->>>>>>>>---------------
# ----->>>>> PFC <<<<<<----- tradingview rec BUY
# ->B<- PFC -> (:CP:) 538.75 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:17:50.676707
# ---------------->>>>>>>>---------------
# ----->>>>> ABCAPITAL <<<<<<----- tradingview rec BUY
# ->B<- ABCAPITAL -> (:CP:) 239.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:18:02.354178
# ---------------->>>>>>>>---------------
# ----->>>>> RECLTD <<<<<<----- tradingview rec BUY
# ->B<- RECLTD -> (:CP:) 577.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:18:17.812317
# ---------------->>>>>>>>---------------
# ----->>>>> ICICIBANK <<<<<<----- tradingview rec BUY
# ->B<- ICICIBANK -> (:CP:) 1223.6 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:18:24.320250
# ---------------->>>>>>>>---------------
# ----->>>>> APOLLOTYRE <<<<<<----- APOLLOTYRE tradingview rec SELL
# ->S<- APOLLOTYRE -> (:CP:) 526.45 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:18:40.578564
# ---------------->>>>>>>>---------------
# ----->>>>> IRCTC <<<<<<----- tradingview rec BUY
# ->B<- IRCTC -> (:CP:) 1013.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:19:15.085200
# ---------------->>>>>>>>---------------
# ----->>>>> INDHOTEL <<<<<<----- tradingview rec BUY
# ->B<- INDHOTEL -> (:CP:) 619.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:19:20.128451
# ---------------->>>>>>>>---------------
# ----->>>>> MPHASIS <<<<<<----- tradingview rec BUY
# ->B<- MPHASIS -> (:CP:) 2594.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:19:24.794334
# ---------------->>>>>>>>---------------
# ----->>>>> TATAPOWER <<<<<<----- tradingview rec BUY
# ->B<- TATAPOWER -> (:CP:) 441.65 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:19:31.723692
# ---------------->>>>>>>>---------------
# ----->>>>> COFORGE <<<<<<----- tradingview rec BUY
# ->B<- COFORGE -> (:CP:) 5817.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:19:41.509437
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> SBILIFE <<<<<<----- tradingview rec BUY
# ->B<- SBILIFE -> (:CP:) 1513.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:19:54.631528
# ---------------->>>>>>>>---------------
# ----->>>>> LTTS <<<<<<----- tradingview rec BUY
# ->B<- LTTS -> (:CP:) 5075.15 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:20:16.067308
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec STRONG_BUY
# ->B<- HCLTECH -> (:CP:) 1507.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:20:27.537904
# ---------------->>>>>>>>---------------
# ----->>>>> TORNTPHARM <<<<<<----- TORNTPHARM tradingview rec STRONG_SELL
# ->S<- TORNTPHARM -> (:CP:) 2815.6 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:20:36.359894
# ---------------->>>>>>>>---------------
# ----->>>>> PFC <<<<<<----- tradingview rec BUY
# ->B<- PFC -> (:CP:) 542.15 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:20:40.754985
# ---------------->>>>>>>>---------------
# ----->>>>> ABCAPITAL <<<<<<----- tradingview rec BUY
# ->B<- ABCAPITAL -> (:CP:) 239.3 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:20:51.751607
# ---------------->>>>>>>>---------------
# ----->>>>> RECLTD <<<<<<----- tradingview rec STRONG_BUY
# ->B<- RECLTD -> (:CP:) 580.25 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:21:06.735254
# ---------------->>>>>>>>---------------
# ----->>>>> TCS <<<<<<----- tradingview rec BUY
# ->B<- TCS -> (:CP:) 4022.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:21:11.649709
# ---------------->>>>>>>>---------------
# ----->>>>> ICICIBANK <<<<<<----- tradingview rec BUY
# ->B<- ICICIBANK -> (:CP:) 1224.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:21:18.632681
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec BUY
# ->B<- INFY -> (:CP:) 1654.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:21:31.486157
# ---------------->>>>>>>>---------------
# ----->>>>> ATUL <<<<<<----- ATUL tradingview rec SELL
# ->S<- ATUL -> (:CP:) 6530.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:21:46.024453
# ---------------->>>>>>>>---------------
# ----->>>>> INDHOTEL <<<<<<----- tradingview rec BUY
# ->B<- INDHOTEL -> (:CP:) 618.55 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:22:16.329464
# ---------------->>>>>>>>---------------
# ----->>>>> MPHASIS <<<<<<----- tradingview rec BUY
# ->B<- MPHASIS -> (:CP:) 2606.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:22:21.220977
# ---------------->>>>>>>>---------------
# ----->>>>> TATAPOWER <<<<<<----- tradingview rec BUY
# ->B<- TATAPOWER -> (:CP:) 441.75 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:22:27.369561
# ---------------->>>>>>>>---------------
# ----->>>>> COFORGE <<<<<<----- tradingview rec BUY
# ->B<- COFORGE -> (:CP:) 5814.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:22:37.420882
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> SBILIFE <<<<<<----- tradingview rec BUY
# ->B<- SBILIFE -> (:CP:) 1514.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:22:50.586431
# ---------------->>>>>>>>---------------
# ----->>>>> SYNGENE <<<<<<----- tradingview rec STRONG_BUY
# ->B<- SYNGENE -> (:CP:) 722.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:22:55.079659
# ---------------->>>>>>>>---------------
# ----->>>>> HDFCLIFE <<<<<<----- tradingview rec BUY
# ->B<- HDFCLIFE -> (:CP:) 602.3 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:23:01.316952
# ---------------->>>>>>>>---------------
# ----->>>>> LTTS <<<<<<----- tradingview rec BUY
# ->B<- LTTS -> (:CP:) 5085.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:23:20.079357
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec BUY
# ->B<- HCLTECH -> (:CP:) 1506.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:23:31.945922
# ---------------->>>>>>>>---------------
# ----->>>>> PFC <<<<<<----- tradingview rec BUY
# ->B<- PFC -> (:CP:) 543.55 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:23:40.180028
# ---------------->>>>>>>>---------------
# ----->>>>> BAJAJFINSV <<<<<<----- tradingview rec STRONG_BUY
# ->B<- BAJAJFINSV -> (:CP:) 1603.75 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:23:49.947055
# ---------------->>>>>>>>---------------
# ----->>>>> ABCAPITAL <<<<<<----- tradingview rec BUY
# ->B<- ABCAPITAL -> (:CP:) 240.1 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:23:58.070403
# ---------------->>>>>>>>---------------
# ----->>>>> ICICIBANK <<<<<<----- tradingview rec BUY
# ->B<- ICICIBANK -> (:CP:) 1224.3 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:24:17.397664
# ---------------->>>>>>>>---------------
# ----->>>>> ATUL <<<<<<----- ATUL tradingview rec SELL
# ->S<- ATUL -> (:CP:) 6526.7 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:24:36.626306
# ---------------->>>>>>>>---------------
# ----->>>>> PERSISTENT <<<<<<----- tradingview rec BUY
# ->B<- PERSISTENT -> (:CP:) 4690.3 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:25:07.255808
# ---------------->>>>>>>>---------------
# ----->>>>> INDHOTEL <<<<<<----- tradingview rec BUY
# ->B<- INDHOTEL -> (:CP:) 616.8 (CP>R1) True (RSI>50) True (SK>SD) False EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:25:13.896766
# ---------------->>>>>>>>---------------
# ----->>>>> MPHASIS <<<<<<----- tradingview rec BUY
# ->B<- MPHASIS -> (:CP:) 2609.65 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:25:19.379714
# ---------------->>>>>>>>---------------
# ----->>>>> CONCOR <<<<<<----- tradingview rec BUY
# ->B<- CONCOR -> (:CP:) 1042.85 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:25:31.258987
# ---------------->>>>>>>>---------------
# ----->>>>> COFORGE <<<<<<----- tradingview rec BUY
# ->B<- COFORGE -> (:CP:) 5822.85 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:25:36.682970
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> SBILIFE <<<<<<----- tradingview rec BUY
# ->B<- SBILIFE -> (:CP:) 1516.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:25:49.729928
# ---------------->>>>>>>>---------------
# ----->>>>> SYNGENE <<<<<<----- tradingview rec STRONG_BUY
# ->B<- SYNGENE -> (:CP:) 724.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:25:54.554554
# ---------------->>>>>>>>---------------
# ----->>>>> HDFCLIFE <<<<<<----- tradingview rec STRONG_BUY
# ->B<- HDFCLIFE -> (:CP:) 603.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:26:00.712131
# ---------------->>>>>>>>---------------
# ----->>>>> MFSL <<<<<<----- tradingview rec STRONG_BUY
# ->B<- MFSL -> (:CP:) 1012.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:26:07.899120
# ---------------->>>>>>>>---------------
# ----->>>>> LTTS <<<<<<----- tradingview rec BUY
# ->B<- LTTS -> (:CP:) 5092.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:26:21.833395
# ---------------->>>>>>>>---------------
# ----->>>>> LICHSGFIN <<<<<<----- LICHSGFIN tradingview rec STRONG_SELL
# ->S<- LICHSGFIN -> (:CP:) 791.05 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:26:33.008698
# ---------------->>>>>>>>---------------
# ----->>>>> CIPLA <<<<<<----- CIPLA tradingview rec SELL
# ->S<- CIPLA -> (:CP:) 1472.45 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:26:50.697396
# ---------------->>>>>>>>---------------
# ----->>>>> INFY <<<<<<----- tradingview rec STRONG_BUY
# ->B<- INFY -> (:CP:) 1653.7 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:27:15.159208
# ---------------->>>>>>>>---------------
# ----->>>>> LUPIN <<<<<<----- tradingview rec BUY
# ->B<- LUPIN -> (:CP:) 1677.25 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:27:33.263291
# ---------------->>>>>>>>---------------
# ----->>>>> NAVINFLUOR <<<<<<----- tradingview rec STRONG_BUY
# ->B<- NAVINFLUOR -> (:CP:) 3663.45 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:27:43.482322
# ---------------->>>>>>>>---------------
# ----->>>>> PERSISTENT <<<<<<----- tradingview rec BUY
# ->B<- PERSISTENT -> (:CP:) 4702.85 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:28:02.425213
# ---------------->>>>>>>>---------------
# ----->>>>> MPHASIS <<<<<<----- tradingview rec STRONG_BUY
# ->B<- MPHASIS -> (:CP:) 2613.15 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:28:11.132612
# ---------------->>>>>>>>---------------
# ----->>>>> CONCOR <<<<<<----- tradingview rec BUY
# ->B<- CONCOR -> (:CP:) 1042.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:28:22.373194
# ---------------->>>>>>>>---------------
# ----->>>>> COFORGE <<<<<<----- tradingview rec BUY
# ->B<- COFORGE -> (:CP:) 5821.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:28:28.670596
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> SBILIFE <<<<<<----- tradingview rec BUY
# ->B<- SBILIFE -> (:CP:) 1516.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:28:40.846191
# ---------------->>>>>>>>---------------
# ----->>>>> SYNGENE <<<<<<----- tradingview rec BUY
# ->B<- SYNGENE -> (:CP:) 723.65 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:28:46.159020
# ---------------->>>>>>>>---------------
# ----->>>>> HDFCLIFE <<<<<<----- tradingview rec BUY
# ->B<- HDFCLIFE -> (:CP:) 603.7 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:28:51.169523
# ---------------->>>>>>>>---------------
# ----->>>>> MFSL <<<<<<----- tradingview rec BUY
# ->B<- MFSL -> (:CP:) 1011.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:28:59.247824
# ---------------->>>>>>>>---------------
# ----->>>>> LTTS <<<<<<----- tradingview rec BUY
# ->B<- LTTS -> (:CP:) 5091.75 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:29:13.915597
# ---------------->>>>>>>>---------------
# ----->>>>> LICHSGFIN <<<<<<----- LICHSGFIN tradingview rec SELL
# ->S<- LICHSGFIN -> (:CP:) 791.35 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:29:23.707955
# ---------------->>>>>>>>---------------
# ----->>>>> ICICIBANK <<<<<<----- tradingview rec STRONG_BUY
# ->B<- ICICIBANK -> (:CP:) 1225.7 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:29:55.203397
# ---------------->>>>>>>>---------------
# ----->>>>> KOTAKBANK <<<<<<----- tradingview rec BUY
# ->B<- KOTAKBANK -> (:CP:) 1833.45 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:30:09.103983
# ---------------->>>>>>>>---------------
# ----->>>>> LUPIN <<<<<<----- tradingview rec BUY
# ->B<- LUPIN -> (:CP:) 1681.9 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:30:21.618149
# ---------------->>>>>>>>---------------
# ----->>>>> NAVINFLUOR <<<<<<----- tradingview rec BUY
# ->B<- NAVINFLUOR -> (:CP:) 3666.35 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:30:32.184697
# ---------------->>>>>>>>---------------
# ----->>>>> TATAMOTORS <<<<<<----- tradingview rec BUY
# ->B<- TATAMOTORS -> (:CP:) 992.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:30:39.263076
# ---------------->>>>>>>>---------------
# ----->>>>> CONCOR <<<<<<----- tradingview rec BUY
# ->B<- CONCOR -> (:CP:) 1043.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:31:07.768944
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> SYNGENE <<<<<<----- tradingview rec BUY
# ->B<- SYNGENE -> (:CP:) 724.15 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:31:22.489810
# ---------------->>>>>>>>---------------
# ----->>>>> MFSL <<<<<<----- tradingview rec BUY
# ->B<- MFSL -> (:CP:) 1010.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:31:31.607664
# ---------------->>>>>>>>---------------
# ----->>>>> ASIANPAINT <<<<<<----- tradingview rec BUY
# ->B<- ASIANPAINT -> (:CP:) 2949.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:31:38.499162
# ---------------->>>>>>>>---------------
# ----->>>>> ICICIPRULI <<<<<<----- tradingview rec STRONG_BUY
# ->B<- ICICIPRULI -> (:CP:) 642.45 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:31:46.487004
# ---------------->>>>>>>>---------------
# ----->>>>> LTTS <<<<<<----- tradingview rec BUY
# ->B<- LTTS -> (:CP:) 5088.2 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:31:55.398551
# ---------------->>>>>>>>---------------
# ----->>>>> LICHSGFIN <<<<<<----- LICHSGFIN tradingview rec SELL
# ->S<- LICHSGFIN -> (:CP:) 791.1 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:32:04.855891
# ---------------->>>>>>>>---------------
# ----->>>>> HAVELLS <<<<<<----- tradingview rec BUY
# ->B<- HAVELLS -> (:CP:) 1907.3 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:32:19.990966
# ---------------->>>>>>>>---------------
# ----->>>>> HDFCBANK <<<<<<----- HDFCBANK tradingview rec SELL
# ->S<- HDFCBANK -> (:CP:) 1741.9 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 04:32:26.823723
# ---------------->>>>>>>>---------------
# ----->>>>> PVRINOX <<<<<<----- tradingview rec STRONG_BUY
# ->B<- PVRINOX -> (:CP:) 1474.85 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:32:50.489915
# ---------------->>>>>>>>---------------
# ----->>>>> KOTAKBANK <<<<<<----- tradingview rec BUY
# ->B<- KOTAKBANK -> (:CP:) 1835.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:32:57.259656
# ---------------->>>>>>>>---------------
# ----->>>>> LUPIN <<<<<<----- tradingview rec BUY
# ->B<- LUPIN -> (:CP:) 1680.15 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:33:11.420861
# ---------------->>>>>>>>---------------
# ----->>>>> NAVINFLUOR <<<<<<----- tradingview rec BUY
# ->B<- NAVINFLUOR -> (:CP:) 3663.55 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:33:21.860546
# ---------------->>>>>>>>---------------
# ----->>>>> PERSISTENT <<<<<<----- tradingview rec BUY
# ->B<- PERSISTENT -> (:CP:) 4698.6 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:33:43.624350
# ---------------->>>>>>>>---------------
# ----->>>>> CONCOR <<<<<<----- tradingview rec BUY
# ->B<- CONCOR -> (:CP:) 1045.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:33:58.495424
# ---------------->>>>>>>>---------------
# ----->>>>> COFORGE <<<<<<----- tradingview rec BUY
# ->B<- COFORGE -> (:CP:) 5821.1 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:34:03.551648
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> SBILIFE <<<<<<----- tradingview rec BUY
# ->B<- SBILIFE -> (:CP:) 1516.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:34:16.421991
# ---------------->>>>>>>>---------------
# ----->>>>> SYNGENE <<<<<<----- tradingview rec BUY
# ->B<- SYNGENE -> (:CP:) 726.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:34:21.210313
# ---------------->>>>>>>>---------------
# ----->>>>> HDFCLIFE <<<<<<----- tradingview rec BUY
# ->B<- HDFCLIFE -> (:CP:) 605.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:34:27.809362
# ---------------->>>>>>>>---------------
# ----->>>>> MFSL <<<<<<----- tradingview rec BUY
# ->B<- MFSL -> (:CP:) 1013.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:34:35.670666
# ---------------->>>>>>>>---------------
# ----->>>>> ICICIPRULI <<<<<<----- tradingview rec BUY
# ->B<- ICICIPRULI -> (:CP:) 642.55 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:34:46.792980
# ---------------->>>>>>>>---------------
# ----->>>>> ABFRL <<<<<<----- tradingview rec BUY
# ->B<- ABFRL -> (:CP:) 332.5 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:34:54.237866
# ---------------->>>>>>>>---------------
# ----->>>>> HCLTECH <<<<<<----- tradingview rec STRONG_BUY
# ->B<- HCLTECH -> (:CP:) 1512.35 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 04:35:06.361196
# ---------------->>>>>>>>---------------
# ...
# ----->>>>> MPHASIS <<<<<<----- tradingview rec STRONG_BUY
# ->B<- MPHASIS -> (:CP:) 2595.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:10:24.342680
# ---------------->>>>>>>>---------------
# ----->>>>> TATAPOWER <<<<<<----- tradingview rec STRONG_BUY
# ->B<- TATAPOWER -> (:CP:) 436.9 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:10:30.833904
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> MUTHOOTFIN <<<<<<----- tradingview rec BUY
# ->B<- MUTHOOTFIN -> (:CP:) 1808.55 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:10:56.288022
# ---------------->>>>>>>>---------------
# ----->>>>> GRASIM <<<<<<----- GRASIM tradingview rec STRONG_SELL
# ->S<- GRASIM -> (:CP:) 2725.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 10:11:03.881995
# ---------------->>>>>>>>---------------
# ----->>>>> BATAINDIA <<<<<<----- tradingview rec STRONG_BUY
# ->B<- BATAINDIA -> (:CP:) 1513.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:11:37.282424
# ---------------->>>>>>>>---------------
# ----->>>>> JKCEMENT <<<<<<----- JKCEMENT tradingview rec STRONG_SELL
# ->S<- JKCEMENT -> (:CP:) 4260.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 10:11:55.708707
# ---------------->>>>>>>>---------------
# ----->>>>> RECLTD <<<<<<----- tradingview rec STRONG_BUY
# ->B<- RECLTD -> (:CP:) 576.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:12:01.858451
# ---------------->>>>>>>>---------------
# ----->>>>> LUPIN <<<<<<----- tradingview rec BUY
# ->B<- LUPIN -> (:CP:) 1764.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:12:32.022475
# ---------------->>>>>>>>---------------
# ----->>>>> GRANULES <<<<<<----- tradingview rec STRONG_BUY
# ->B<- GRANULES -> (:CP:) 516.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:12:38.482847
# ---------------->>>>>>>>---------------
# ----->>>>> TATAMOTORS <<<<<<----- tradingview rec BUY
# ->B<- TATAMOTORS -> (:CP:) 1002.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:12:50.217400
# ---------------->>>>>>>>---------------
# ----->>>>> ONGC <<<<<<----- tradingview rec BUY
# ->B<- ONGC -> (:CP:) 277.75 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:12:55.692117
# ---------------->>>>>>>>---------------
# ----->>>>> IOC <<<<<<----- tradingview rec STRONG_BUY
# ->B<- IOC -> (:CP:) 170.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:13:03.618366
# ---------------->>>>>>>>---------------
# ----->>>>> NATIONALUM <<<<<<----- tradingview rec STRONG_BUY
# ->B<- NATIONALUM -> (:CP:) 195.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:13:08.325963
# ---------------->>>>>>>>---------------
# ----->>>>> ADANIENT <<<<<<----- ADANIENT tradingview rec SELL
# ->S<- ADANIENT -> (:CP:) 3143.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 10:13:18.531126
# ---------------->>>>>>>>---------------
# ----->>>>> PERSISTENT <<<<<<----- tradingview rec BUY
# ->B<- PERSISTENT -> (:CP:) 4759.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:13:23.974918
# ---------------->>>>>>>>---------------
# ----->>>>> MPHASIS <<<<<<----- tradingview rec STRONG_BUY
# ->B<- MPHASIS -> (:CP:) 2595.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:13:33.135576
# ---------------->>>>>>>>---------------
# ----->>>>> TATAPOWER <<<<<<----- tradingview rec STRONG_BUY
# ->B<- TATAPOWER -> (:CP:) 436.9 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:13:39.716171
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> MUTHOOTFIN <<<<<<----- tradingview rec BUY
# ->B<- MUTHOOTFIN -> (:CP:) 1808.55 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:14:04.738294
# ---------------->>>>>>>>---------------
# ----->>>>> GRASIM <<<<<<----- GRASIM tradingview rec STRONG_SELL
# ->S<- GRASIM -> (:CP:) 2725.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 10:14:11.330907
# ---------------->>>>>>>>---------------
# ----->>>>> BATAINDIA <<<<<<----- tradingview rec STRONG_BUY
# ->B<- BATAINDIA -> (:CP:) 1513.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:14:43.297728
# ---------------->>>>>>>>---------------
# ----->>>>> JKCEMENT <<<<<<----- JKCEMENT tradingview rec STRONG_SELL
# ->S<- JKCEMENT -> (:CP:) 4260.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 10:15:03.813002
# ---------------->>>>>>>>---------------
# ----->>>>> RECLTD <<<<<<----- tradingview rec STRONG_BUY
# ->B<- RECLTD -> (:CP:) 576.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:15:10.838636
# ---------------->>>>>>>>---------------
# ----->>>>> LUPIN <<<<<<----- tradingview rec BUY
# ->B<- LUPIN -> (:CP:) 1764.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:15:40.069364
# ---------------->>>>>>>>---------------
# ----->>>>> GRANULES <<<<<<----- tradingview rec STRONG_BUY
# ->B<- GRANULES -> (:CP:) 516.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:15:46.010313
# ---------------->>>>>>>>---------------
# ----->>>>> TATAMOTORS <<<<<<----- tradingview rec BUY
# ->B<- TATAMOTORS -> (:CP:) 1002.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:15:57.798010
# ---------------->>>>>>>>---------------
# ----->>>>> ONGC <<<<<<----- tradingview rec BUY
# ->B<- ONGC -> (:CP:) 277.75 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:16:03.745346
# ---------------->>>>>>>>---------------
# ----->>>>> IOC <<<<<<----- tradingview rec STRONG_BUY
# ->B<- IOC -> (:CP:) 170.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:16:11.244559
# ---------------->>>>>>>>---------------
# ----->>>>> NATIONALUM <<<<<<----- tradingview rec STRONG_BUY
# ->B<- NATIONALUM -> (:CP:) 195.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:16:16.087924
# ---------------->>>>>>>>---------------
# ----->>>>> ADANIENT <<<<<<----- ADANIENT tradingview rec SELL
# ->S<- ADANIENT -> (:CP:) 3143.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 10:16:26.778849
# ---------------->>>>>>>>---------------
# ----->>>>> PERSISTENT <<<<<<----- tradingview rec BUY
# ->B<- PERSISTENT -> (:CP:) 4759.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:16:32.751834
# ---------------->>>>>>>>---------------
# ----->>>>> MPHASIS <<<<<<----- tradingview rec STRONG_BUY
# ->B<- MPHASIS -> (:CP:) 2595.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:16:43.309744
# ---------------->>>>>>>>---------------
# ----->>>>> TATAPOWER <<<<<<----- tradingview rec STRONG_BUY
# ->B<- TATAPOWER -> (:CP:) 436.9 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:16:51.342177
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> MUTHOOTFIN <<<<<<----- tradingview rec BUY
# ->B<- MUTHOOTFIN -> (:CP:) 1808.55 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:17:16.996970
# ---------------->>>>>>>>---------------
# ----->>>>> GRASIM <<<<<<----- GRASIM tradingview rec STRONG_SELL
# ->S<- GRASIM -> (:CP:) 2725.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 10:17:23.834155
# ---------------->>>>>>>>---------------
# ----->>>>> BATAINDIA <<<<<<----- tradingview rec STRONG_BUY
# ->B<- BATAINDIA -> (:CP:) 1513.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:17:55.770921
# ---------------->>>>>>>>---------------
# ----->>>>> JKCEMENT <<<<<<----- JKCEMENT tradingview rec STRONG_SELL
# ->S<- JKCEMENT -> (:CP:) 4260.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 10:18:14.982062
# ---------------->>>>>>>>---------------
# ----->>>>> RECLTD <<<<<<----- tradingview rec STRONG_BUY
# ->B<- RECLTD -> (:CP:) 576.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:18:21.542449
# ---------------->>>>>>>>---------------
# ----->>>>> LUPIN <<<<<<----- tradingview rec BUY
# ->B<- LUPIN -> (:CP:) 1764.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:18:52.484546
# ---------------->>>>>>>>---------------
# ----->>>>> GRANULES <<<<<<----- tradingview rec STRONG_BUY
# ->B<- GRANULES -> (:CP:) 516.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:18:58.203490
# ---------------->>>>>>>>---------------
# ----->>>>> TATAMOTORS <<<<<<----- tradingview rec BUY
# ->B<- TATAMOTORS -> (:CP:) 1002.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:19:09.928152
# ---------------->>>>>>>>---------------
# ----->>>>> ONGC <<<<<<----- tradingview rec BUY
# ->B<- ONGC -> (:CP:) 277.75 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:19:15.723036
# ---------------->>>>>>>>---------------
# ----->>>>> IOC <<<<<<----- tradingview rec STRONG_BUY
# ->B<- IOC -> (:CP:) 170.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:19:23.374152
# ---------------->>>>>>>>---------------
# ----->>>>> NATIONALUM <<<<<<----- tradingview rec STRONG_BUY
# ->B<- NATIONALUM -> (:CP:) 195.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:19:27.888923
# ---------------->>>>>>>>---------------
# ----->>>>> ADANIENT <<<<<<----- ADANIENT tradingview rec SELL
# ->S<- ADANIENT -> (:CP:) 3143.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 10:19:38.912821
# ---------------->>>>>>>>---------------
# ----->>>>> PERSISTENT <<<<<<----- tradingview rec BUY
# ->B<- PERSISTENT -> (:CP:) 4759.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:19:44.981398
# ---------------->>>>>>>>---------------
# ----->>>>> MPHASIS <<<<<<----- tradingview rec STRONG_BUY
# ->B<- MPHASIS -> (:CP:) 2595.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:19:55.577285
# ---------------->>>>>>>>---------------
# ----->>>>> TATAPOWER <<<<<<----- tradingview rec STRONG_BUY
# ->B<- TATAPOWER -> (:CP:) 436.9 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:20:02.524030
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> MUTHOOTFIN <<<<<<----- tradingview rec BUY
# ->B<- MUTHOOTFIN -> (:CP:) 1808.55 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:20:29.551371
# ---------------->>>>>>>>---------------
# ----->>>>> GRASIM <<<<<<----- GRASIM tradingview rec STRONG_SELL
# ->S<- GRASIM -> (:CP:) 2725.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 10:20:37.275905
# ---------------->>>>>>>>---------------
# ----->>>>> BATAINDIA <<<<<<----- tradingview rec STRONG_BUY
# ->B<- BATAINDIA -> (:CP:) 1513.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:21:09.626629
# ---------------->>>>>>>>---------------
# ----->>>>> JKCEMENT <<<<<<----- JKCEMENT tradingview rec STRONG_SELL
# ->S<- JKCEMENT -> (:CP:) 4260.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 10:21:28.636375
# ---------------->>>>>>>>---------------
# ----->>>>> RECLTD <<<<<<----- tradingview rec STRONG_BUY
# ->B<- RECLTD -> (:CP:) 576.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:21:35.917710
# ---------------->>>>>>>>---------------
# ----->>>>> LUPIN <<<<<<----- tradingview rec BUY
# ->B<- LUPIN -> (:CP:) 1764.05 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:22:04.725959
# ---------------->>>>>>>>---------------
# ----->>>>> GRANULES <<<<<<----- tradingview rec STRONG_BUY
# ->B<- GRANULES -> (:CP:) 516.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:22:10.349560
# ---------------->>>>>>>>---------------
# ----->>>>> TATAMOTORS <<<<<<----- tradingview rec BUY
# ->B<- TATAMOTORS -> (:CP:) 1002.8 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:22:22.425456
# ---------------->>>>>>>>---------------
# ----->>>>> ONGC <<<<<<----- tradingview rec BUY
# ->B<- ONGC -> (:CP:) 277.75 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:22:27.523518
# ---------------->>>>>>>>---------------
# ----->>>>> IOC <<<<<<----- tradingview rec STRONG_BUY
# ->B<- IOC -> (:CP:) 170.4 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:22:35.745280
# ---------------->>>>>>>>---------------
# ----->>>>> NATIONALUM <<<<<<----- tradingview rec STRONG_BUY
# ->B<- NATIONALUM -> (:CP:) 195.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:22:40.121583
# ---------------->>>>>>>>---------------
# ----->>>>> ADANIENT <<<<<<----- ADANIENT tradingview rec SELL
# ->S<- ADANIENT -> (:CP:) 3143.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 10:22:50.715140
# ---------------->>>>>>>>---------------
# ----->>>>> PERSISTENT <<<<<<----- tradingview rec BUY
# ->B<- PERSISTENT -> (:CP:) 4759.95 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:22:55.772394
# ---------------->>>>>>>>---------------
# ----->>>>> MPHASIS <<<<<<----- tradingview rec STRONG_BUY
# ->B<- MPHASIS -> (:CP:) 2595.0 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:23:05.314401
# ---------------->>>>>>>>---------------
# ----->>>>> TATAPOWER <<<<<<----- tradingview rec STRONG_BUY
# ->B<- TATAPOWER -> (:CP:) 436.9 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:23:11.485371
# ---------------->>>>>>>>---------------
# ------------Loop completed--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----->>>>> MUTHOOTFIN <<<<<<----- tradingview rec BUY
# ->B<- MUTHOOTFIN -> (:CP:) 1808.55 (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-04 10:23:36.518612
# ---------------->>>>>>>>---------------
# ----->>>>> GRASIM <<<<<<----- GRASIM tradingview rec STRONG_SELL
# ->S<- GRASIM -> (:CP:) 2725.0 CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-04 10:23:43.169419
# ---------------->>>>>>>>---------------

# %%
with open('outputBuy.txt', 'w') as file:
                            # Write the text to the file
                    text_to_write = f"{get_recomm(iteam)} {str(iteam)} {str(get_recomm_CP(iteam))} {str(get_recomm_rsi(iteam))} {str(get_recomm_R1(iteam))} {str(get_recomm_R2(iteam))} {str(get_recomm_S1(iteam))} {str(get_recomm_S2(iteam))}\n "

# %%
with open('outputBuy.txt', 'w') as file:file.write(text_to_write) # , "test") #get_recomm(iteam)) #,get_recomm_rsi(iteam), get_recomm_CP(iteam))
                            # Write the text to the file
                    text_to_write = f"{get_recomm(iteam)} {str(iteam)} {str(get_recomm_CP(iteam))} {str(get_recomm_rsi(iteam))} {str(get_recomm_R1(iteam))} {str(get_recomm_R2(iteam))} {str(get_recomm_S1(iteam))} {str(get_recomm_S2(iteam))}\n "

# %%
#F & O stock - inventory BUY / SELL - Signal testing 29/05/2024 -----------------------------------------------------------
# Nifty options order for buy call and put - updates as on 15-10-2023
#Change Value " sb , sr, ex, -STOCK,EXCODE,psp,csp,exp, order_type, get_instrument_by_token, quantity, price", ---ICICI direct stock
# STOCK="NIFTY"; EXCODE="NFO";psp="17700"; csp="17600"; qt="100"; exp="2023-04-20T06:00:00.000Z"; vdate="2023-04-15T06:00:00.000Z" # broker stock code   ##import os; import urllib;
from tradingview_ta import TA_Handler, Interval, Exchange; import time; import datetime; import pandas as pd;  from breeze_connect import BreezeConnect; from datetime import datetime; from datetime import timedelta
#sb="NIFTY";sr="cfd"; ex="NSE"; #  trading View exchange code
sb="BANKNIFTY"; sr="india"; ex="NSE" #  trading View exchange code
#sb="CNXFINANCE"; sr="india"; ex="NSE" #  trading View exchange code
# sb="BTCUSD"; sr="crypto" ; ex="BINANCE";
#sb="USOIL"; sr="cfd" ; ex="FX"; #Tok_A = 425903; ex='MCX'; qt = 1; #  trading View exchange code Crude oil
symbols = ['COROMANDEL','GLENMARK','SUNTV','DIVISLAB','SBILIFE','SYNGENE','EXIDEIND','HDFCLIFE','IGL','MUTHOOTFIN','IPCALAB','HEROMOTOCO','MFSL','GRASIM','AARTIIND','HDFCAMC','AUROPHARMA','BERGEPAINT','ASIANPAINT',
            'OBEROIRLTY','JUBLFOOD','DRREDDY','HINDCOPPER','ICICIPRULI','COLPAL','LAURUSLABS','ZEEL','ABFRL','PIDILITIND','CUMMINSIND','LTTS','MARICO','SHREECEM','GNFC','BRITANNIA','ICICIGI','BIOCON','WIPRO','SHRIRAMFIN','HINDUNILVR',
            'LICHSGFIN','HCLTECH','CANFINHOME','UBL','JSWSTEEL','HINDALCO','BALRAMCHIN','TORNTPHARM','PFC','AUBANK','TATACONSUM','SBICARD','TITAN','BAJAJFINSV','BATAINDIA','LT','METROPOLIS','BANDHANBNK','HAVELLS','ABCAPITAL','CIPLA',
            'PIIND','HDFCBANK','SUNPHARMA','ASHOKLEY','CROMPTON','TVSMOTOR','ALKEM','BALKRISIND','INDIACEM','LTIM','DABUR','CUB','JKCEMENT','NESTLEIND','BAJFINANCE','TATASTEEL','RECLTD','TCS','IDFC',
            'ULTRACEMCO','ICICIBANK','SBIN','GODREJCP','ZYDUSLIFE','ESCORTS','JINDALSTEL','INDUSTOWER','AXISBANK','ACC','GMRINFRA','INFY','BHARATFORG','EICHERMOT','PVRINOX','OFSS','ITC','KOTAKBANK','LALPATHLAB','APOLLOTYRE','MGL',
            'CHOLAFIN','MARUTI','RELIANCE','RAMCOCEM','INDIAMART','ATUL','DALBHARAT','TATACHEM','TATACOMM','AMBUJACEM','IDFCFIRSTB','LUPIN','APOLLOHOSP','PAGEIND','GRANULES','CANBK','RBLBANK','VEDL','INDUSINDBK','GAIL','NAVINFLUOR',
            'BHARTIARTL','LTF','VOLTAS','MCX','TATAMOTORS','TECHM','ONGC','CHAMBLFERT','SIEMENS','MRF','SRF','ABBOTINDIA','IOC','NATIONALUM','MOTHERSON','PEL','TRENT','PNB','NTPC','ASTRAL','INDIGO','NMDC','UPL','ADANIENT','COALINDIA',
            'PERSISTENT','MANAPPURAM','BPCL','POWERGRID','IRCTC','INDHOTEL','GUJGASLTD','MPHASIS','DIXON','BOSCHLTD','BEL','TATAPOWER','DEEPAKNTR','POLYCAB','ABB','PETRONET','HINDPETRO','ADANIPORTS','CONCOR','FEDERALBNK','COFORGE','IEX',
            'BSOFT','GODREJPROP','SAIL','HAL','BHEL','BANKBARODA','DLF','NAUKRI','IDEA','M_M','MCDOWELL_N','BAJAJ_AUTO','OBEROIRLTY']
try:
    def get_recomm(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return output.get_analysis().summary['RECOMMENDATION']

    def get_recomm_rsi(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["RSI"])

    def get_recomm_CP(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["close"])

    def get_recomm_R1(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.R1"])

    def get_recomm_S1(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.S1"])

    def get_recomm_R2(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.R2"])

    def get_recomm_S2(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.S2"])

    def get_recomm_PV(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.Middle"])

    def get_recomm_ema5(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA5"])

    def get_recomm_ema10(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA10"])

    def get_recomm_ema20(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA20"])

    def get_recomm_SK(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["Stoch.K"])

    def get_recomm_SD(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["Stoch.D"])

    def get_recomm_trec(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return output.get_analysis().time
except Exception as error:
          print('Place Order TV-API Error!<---BreezeAPI-->', error)
# recomm = get_recomm(data['symbols'])
last_buy = False
last_sell = False
loop_counter = 0
#while  loop_counter < 2:
while True:

    for iteam in symbols:
        try:
            #now = datetime.now()
            #print("buy or sell order executed",  iteam, get_recomm(iteam), "RSI>50", 50 < get_recomm_rsi(iteam), "Close Price", get_recomm_CP(iteam),  "RSI", get_recomm_rsi(iteam),"CP>R1", get_recomm_CP(iteam) > get_recomm_R1(iteam),"CP>PV", get_recomm_CP(iteam) > get_recomm_PV(iteam),"CP<S1", get_recomm_CP(iteam) < get_recomm_S1(iteam),"R1", get_recomm_R1(iteam), "S1", get_recomm_S1(iteam),"R2", get_recomm_R2(iteam), "S2", get_recomm_S2(iteam),
            #        "PV", get_recomm_PV(iteam))
            #print("buy or sell order executed",  iteam, get_recomm(iteam), "RSI>50", 50 < get_recomm_rsi(iteam), "Close Price", round(get_recomm_CP(iteam),2),  "RSI", round(get_recomm_rsi(iteam),2),"CP>R1", get_recomm_CP(iteam) > get_recomm_R1(iteam),"CP>PV", get_recomm_CP(iteam) > get_recomm_PV(iteam),"CP<S1", get_recomm_CP(iteam) < get_recomm_S1(iteam),"R1", round(get_recomm_R1(iteam),2), "S1", round(get_recomm_S1(iteam),2),"R2", round(get_recomm_R2(iteam),2), "S2", round(get_recomm_S2(iteam),2),
            #        "PV", round(get_recomm_PV(iteam),2), get_recomm_trec(iteam))
            #now = datetime.now()
            #print("now =", now)
            if "BUY" in get_recomm(iteam) and 50 < get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R1(iteam):# and not last_buy:
                    print(get_recomm(iteam),"->",iteam, "<-","tradingview rec", get_recomm(iteam), str(get_recomm_trec(iteam)))
                    print("exchange buy order executed" , ">>>>",iteam,"<<<<" , ">>>>>>BUY<<<<<<", "CP>R1", get_recomm_CP(iteam) > get_recomm_R1(iteam),"CP>PV", get_recomm_CP(iteam) > get_recomm_PV(iteam), "CP:", get_recomm_CP(iteam), "R1:", str(round(get_recomm_R1(iteam),2)))
                    with open('/content/drive/My Drive/My Folder/buy_stock(F-O-186)(07-02-915).csv', 'a') as f:
                        text_to_write = f"{str(iteam)} , {get_recomm(iteam)}, ' CP ', {str(get_recomm_CP(iteam))}, ' RSI>50 ', {str(50 < get_recomm_rsi(iteam))}, {str(round(get_recomm_rsi(iteam),1))},'CP>R1', {str(get_recomm_CP(iteam) > get_recomm_R1(iteam))} , 'R1', {str(round(get_recomm_R1(iteam),2))},'R2', {str(round(get_recomm_R2(iteam),2))}, 'CP<S1', {str(get_recomm_CP(iteam) < get_recomm_S1(iteam))},'S1', {str(round(get_recomm_S1(iteam),2))} ,S2', {str(round(get_recomm_S2(iteam),2))} {str(get_recomm_trec(iteam))}\n"
                        #text_to_write = f"{get_recomm(iteam)} {str(iteam)} {str(get_recomm_CP(iteam))} {str(get_recomm_rsi(iteam))} {str(get_recomm_R1(iteam))} {str(get_recomm_R2(iteam))} {str(get_recomm_S1(iteam))} {str(get_recomm_S2(iteam))} {str(get_recomm_trec(iteam))}\n"
                        f.write(text_to_write)
                    print("---------------->>>>>>>>---------------")
                    #last_buy = True
                    #last_sell = False
            elif  "SELL" in get_recomm(iteam) and 50 > get_recomm_rsi(iteam) and get_recomm_CP(iteam) < get_recomm_S1(iteam): # and not last_sell:
                    print(get_recomm(iteam),"->",iteam,"<-","tradingview rec", get_recomm(iteam),"T", get_recomm_trec(iteam), str(get_recomm_trec(iteam)))
                    print("exchange Sell order executed" ,">>>>",iteam,"<<<<<" , ">>>>>SELL<<<<", "CP<S1", get_recomm_CP(iteam) < get_recomm_S1(iteam),"CP<PV", get_recomm_CP(iteam) < get_recomm_PV(iteam),"CP:", get_recomm_CP(iteam), "S1:", str(round(get_recomm_S1(iteam),2)))
                    with open('/content/drive/My Drive/My Folder/sell_stock(F-O-186)(07-02-915).csv', 'a') as f:
                        text_to_write = f"{str(iteam)} , {get_recomm(iteam)}, 'CP', {str(get_recomm_CP(iteam))}, 'RSI>50', {str(50 < get_recomm_rsi(iteam))}, {str(round(get_recomm_rsi(iteam),1))},'CP>R1', {str(get_recomm_CP(iteam) > get_recomm_R1(iteam))} , 'R1', {str(round(get_recomm_R1(iteam),2))},'R2', {str(round(get_recomm_R2(iteam),2))}, 'CP<S1', {str(get_recomm_CP(iteam) < get_recomm_S1(iteam))},'S1', {str(round(get_recomm_S1(iteam),2))} ,S2', {str(round(get_recomm_S2(iteam),2))} {str(get_recomm_trec(iteam))}\n"
                        #text_to_write = f"{get_recomm(iteam)} {str(iteam)} {str(get_recomm_CP(iteam))} {str(get_recomm_rsi(iteam))} {str(get_recomm_R1(iteam))} {str(get_recomm_R2(iteam))} {str(get_recomm_S1(iteam))} {str(get_recomm_S2(iteam))} {str(get_recomm_trec(iteam))}\n"
                        f.write(text_to_write)
                    print("---------------->>>>>>>>---------------")
                    #last_buy = False
                    #last_sell = True
            #else: # 45 > get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R(iteam):
                    #print("----->>>>Stoploss<<<<<---- order exec", iteam)
                    #if 48 > get_recomm_rsi(iteam): # and get_recomm_CP(iteam) < get_recomm_R1(iteam):
                        #print("---------------------------->>>>Stoploss<<<<<---- order exec", iteam, get_recomm_CP(iteam) < get_recomm_R1(iteam))
        except Exception as error:
            print('Place Order API Error!<---BreezeAPI-->', error)
    #loop_counter += 1 # break
    print("------------Loop completed---------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
    break
