# %%
# last_order == "buy"
# Nifty options order for buy call and put - updates as on 15-10-2023
#Change Value " sb , sr, ex, -STOCK,EXCODE,psp,csp,exp, order_type, get_instrument_by_token, quantity, price", ---ICICI direct stock
# STOCK="NIFTY"; EXCODE="NFO";psp="17700"; csp="17600"; qt="100"; exp="2023-04-20T06:00:00.000Z"; vdate="2023-04-15T06:00:00.000Z" # broker stock code   ##import os; import urllib;
from tradingview_ta import TA_Handler, Interval, Exchange; import time; import datetime; import pandas as pd;  from breeze_connect import BreezeConnect
#sb="NIFTY";sr="cfd"; ex="NSE"; #  trading View exchange code
sb="BANKNIFTY"; sr="india"; ex="NSE" #  trading View exchange code
#sb="CNXFINANCE"; sr="india"; ex="NSE" #  trading View exchange code
# sb="BTCUSD"; sr="crypto" ; ex="BINANCE";
#sb="USOIL"; sr="cfd" ; ex="FX"; #Tok_A = 425903; ex='MCX'; qt = 1; #  trading View exchange code Crude oil
#symbols = ['CNXFINANCE','BANKNIFTY','NIFTY','TCS','NIFTYJR', 'WIPRO']
import time; import datetime; import pandas as pd; import winsound; from gtts import gTTS; import os; import urllib
mytext1 = 'Buy nifty signal buy CALL OPTION  executed'; mytext2 = 'Sell nifty signal buy PUT OPTION executed'
language = 'en'; myobj1 = gTTS(text=mytext1, lang=language, slow=False); myobj2 = gTTS(text=mytext2, lang=language, slow=False); frequency = 7000; duration = 500; myobj1.save("buyCallNB.mp3"); myobj2.save("buyPutNB.mp3")

#symbols = ['ADANIENT','ADANIPORTS','APOLLOHOSP','ASIANPAINT','AXISBANK','BAJAJ_AUTO','BAJAJFINSV','BAJFINANCE','BHARTIARTL','BPCL','BRITANNIA','CIPLA','COALINDIA','DIVISLAB','DRREDDY', 'EICHERMOT','GRASIM','HCLTECH', 'HDFCBANK','HDFCLIFE','HEROMOTOCO','HINDALCO','HINDUNILVR','ICICIBANK','INDUSINDBK','INFY','ITC','JSWSTEEL','KOTAKBANK','LT','LTIM','M_M','MARUTI','NESTLEIND','NIFTY','NTPC','ONGC','POWERGRID','RELIANCE', 'SBILIFE','SBIN', 'SHRIRAMFIN', 'SUNPHARMA','TATACONSUM','TATAMOTORS','TATASTEEL','TCS','TECHM','TITAN','ULTRACEMCO','WIPRO']
symbols = ['ABB','ACC','ATUL','BHEL','BIOCON','CIPLA','COLPAL','CONCOR','GAIL','GNFC','GRASIM','IDFC','ITC','LUPIN','MCX','NTPC','ONGC','SAIL','SRF','SUNTV','TCS','TRENT','VOLTAS','WIPRO','ABB','ACC','ATUL','BHEL','BIOCON','CIPLA','COLPAL','CONCOR','GAIL','GNFC','GRASIM','IDFC','ITC','LUPIN','MCX','NTPC','ONGC','SAIL','SRF','SUNTV','TCS','TRENT','VOLTAS','WIPRO']
try:
    def get_recomm(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return output.get_analysis().summary['RECOMMENDATION']

    def get_recomm_rsi(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["RSI"])

    def get_recomm_CP(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["close"])

    def get_recomm_R1(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.R1"])

    def get_recomm_S1(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.S1"])

    def get_recomm_R2(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.R2"])

    def get_recomm_S2(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.S2"])

    def get_recomm_PV(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["Pivot.M.Classic.Middle"])

    def get_recomm_ema5(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA5"])

    def get_recomm_ema10(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA10"])

    def get_recomm_ema20(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return float(output.get_analysis().indicators["EMA20"])

    def get_recomm_SK(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["Stoch.K"])

    def get_recomm_SD(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["Stoch.D"])        
    def get_recomm_MACD_m(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["MACD.macd"])

    def get_recomm_MACD_s(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
        return float(output.get_analysis().indicators["MACD.signal"])

   # def get_recomm_MACD_s(symbols):
   #     output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_5_MINUTES, timeout=None)
   #     return float(output.get_analysis().indicators["MACD.signal"])

    def get_recomm_trec(symbols):
        output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
        return output.get_analysis().time

    def get_buy_stock(symbols):
        buy_stock = 123; #breeze.place_order(stock_code=iteam, exchange_code="NSE", product="cash", action="buy", order_type="market", stoploss="", quantity="1", price="0.0", validity="day")
        return buy_stock

    def get_sell_stock(symbols):
        sell_stock = 54321; #breeze.place_order(stock_code=iteam, exchange_code="NSE", product="cash", action="buy", order_type="market", stoploss="", quantity="1", price="0.0", validity="day")
        return sell_stock

# MACD_m=round(float(handler.get_analysis().indicators["MACD.macd"]),2); MACD_s= round(float(handler.get_analysis().indicators["MACD.signal"]),2)

except Exception as error:
          print('Place Order API Error!<---BreezeAPI-->', error)

#trec = handler.get_analysis().time

# recomm = get_recomm(data['symbols'])
last_buy = False
last_sell = False
loop_counter = 0
#while  loop_counter < 2:
while True:
    print("------------while loop started ------tradingView and ICICI same script ------------------5 signal used --------------------------------------------------")
    for iteam in symbols:
        try:
            print("<-b/s->",iteam,"<-", get_recomm(iteam), "(RSI>50)", 50 < get_recomm_rsi(iteam), "(CP)", round(get_recomm_CP(iteam),2), "(RSI)", round(get_recomm_rsi(iteam),2),"<CP>R1>", get_recomm_CP(iteam) > get_recomm_R1(iteam),"<CP>PV>", get_recomm_CP(iteam) > get_recomm_PV(iteam),"<CP<S1>", get_recomm_CP(iteam) < get_recomm_S1(iteam),"(R1)", round(get_recomm_R1(iteam),2), "(S1)", round(get_recomm_S1(iteam),2),"(R2)", round(get_recomm_R2(iteam),2), "(S2)", round(get_recomm_S2(iteam),2),
                    "<PV>", round(get_recomm_PV(iteam),2), "<MACD_M>", round(get_recomm_MACD_m(iteam),2), "<MACD_S>", round(get_recomm_MACD_s(iteam),2),  "<SK>", round(get_recomm_SK(iteam),2), "<SD>", round(get_recomm_SD(iteam),2), get_recomm_trec(iteam) )
            # if "BUY" in get_recomm(iteam) and 50 < get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R1(iteam):# and get_recomm_ema10(iteam) > get_recomm_ema20(iteam): # and not last_buy:
            if "BUY" in get_recomm(iteam) and 50 < get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R1(iteam) and get_recomm_SK(iteam)>get_recomm_SD(iteam) and  get_recomm_ema10(iteam) > get_recomm_ema20(iteam) and get_recomm_MACD_m(iteam) > get_recomm_MACD_s(iteam)  :# and get_recomm_ema10(iteam) > get_recomm_ema20(iteam): # and not last_buy:
                    print ("----->>>>>",iteam, "<<<<<<-----","tradingview rec", get_recomm(iteam)); winsound.Beep(frequency, duration); str1= iteam; mytext1 = str1 + 'Buy buy signal R1 above' +str1;  myobj1 = gTTS(text=mytext1, lang=language, slow=False); myobj1.save("buytric.mp3"); os.system("start buytric.mp3")
                    print("->B<-",iteam,"->", "(CP>R1)", get_recomm_CP(iteam) > get_recomm_R1(iteam),"(RSI>50)",50 < get_recomm_rsi(iteam), "(SK>SD)", get_recomm_SK(iteam)>get_recomm_SD(iteam),"EMACROSS", get_recomm_ema10(iteam) > get_recomm_ema20(iteam), "(MACD_m>MACD_s)", get_recomm_MACD_m(iteam) > get_recomm_MACD_s(iteam),"T", get_recomm_trec(iteam))
                    with open('l_b_f_o(7-8-915(tric)-r1).csv', 'a') as f:
                          text_to_write = f"{str(iteam)} , {get_recomm(iteam)}, 'CP', {str(get_recomm_CP(iteam))}, 'RSI>50', {str(50 < get_recomm_rsi(iteam))}, {str(round(get_recomm_rsi(iteam),1))},'CP>R1', {str(get_recomm_CP(iteam) > get_recomm_R1(iteam))} , 'R1', {str(round(get_recomm_R1(iteam),2))},'R2', {str(round(get_recomm_R2(iteam),2))}, 'CP<S1', {str(get_recomm_CP(iteam) < get_recomm_S1(iteam))},'S1', {str(round(get_recomm_S1(iteam),2))} ,S2', {str(round(get_recomm_S2(iteam),2))} {str(get_recomm_trec(iteam))}\n"
                          #text_to_write = f"{get_recomm(iteam)} {str(iteam)} {str(get_recomm_CP(iteam))} {str(get_recomm_rsi(iteam))} {str(get_recomm_R1(iteam))} {str(get_recomm_R2(iteam))} {str(get_recomm_S1(iteam))} {str(get_recomm_S2(iteam))} {str(get_recomm_trec(iteam))}\n"
                          f.write(text_to_write)
                    print("---------------->>>>>>>>---------------")
                    #last_buy = True
                    #last_sell = False

            if "SELL" in get_recomm(iteam) and 50 > get_recomm_rsi(iteam) and get_recomm_CP(iteam) < get_recomm_S1(iteam) and get_recomm_SK(iteam)<get_recomm_SD(iteam) and  get_recomm_ema10(iteam) < get_recomm_ema20(iteam) and get_recomm_MACD_m(iteam) < get_recomm_MACD_s(iteam) : # and get_recomm_ema10(iteam) < get_recomm_ema20(iteam):# and not last_sell:
                    print ("----->>>>>",iteam, "<<<<<<-----",iteam, "tradingview rec", get_recomm(iteam)); winsound.Beep(frequency, duration);str1= iteam; mytext2 = str1 + 'Sell Sell signal S1 bellow' +str1;  myobj2 = gTTS(text=mytext2, lang=language, slow=False); myobj2.save("selltric.mp3"); os.system("start selltric.mp3")
                    print("->S<-",iteam,"->" , "CP<S1", get_recomm_CP(iteam) < get_recomm_S1(iteam), "(RSI<50)",50 > get_recomm_rsi(iteam), "(SK<SD)", get_recomm_SK(iteam)<get_recomm_SD(iteam),"EMA**", get_recomm_ema10(iteam) < get_recomm_ema20(iteam), "(MACD_m<MACD_s)", get_recomm_MACD_m(iteam) < get_recomm_MACD_s(iteam),"T", get_recomm_trec(iteam)) 
                    with open('l_s_f_o(7-8-915(tric)-s1).csv', 'a') as f:
                        text_to_write = f"{str(iteam)} , {get_recomm(iteam)},'CP', {str(get_recomm_CP(iteam))}, 'RSI>50', {str(50 < get_recomm_rsi(iteam))}, {str(round(get_recomm_rsi(iteam),1))},'CP>R1', {str(get_recomm_CP(iteam) > get_recomm_R1(iteam))} , 'R1', {str(round(get_recomm_R1(iteam),2))},'R2', {str(round(get_recomm_R2(iteam),2))}, 'CP<S1', {str(get_recomm_CP(iteam) < get_recomm_S1(iteam))},'S1', {str(round(get_recomm_S1(iteam),2))} ,S2', {str(round(get_recomm_S2(iteam),2))} {str(get_recomm_trec(iteam))}\n"
                        #text_to_write = f"{get_recomm(iteam)} {str(iteam)} {str(get_recomm_CP(iteam))} {str(get_recomm_rsi(iteam))} {str(get_recomm_R1(iteam))} {str(get_recomm_R2(iteam))} {str(get_recomm_S1(iteam))} {str(get_recomm_S2(iteam))} {str(get_recomm_trec(iteam))}\n"
                        f.write(text_to_write)
                    print("---------------->>>>>>>>---------------")
                    #last_buy = False
                    #last_sell = True
            #else: # 45 > get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R(iteam):
                    #print("----->>>>Stoploss<<<<<---- order exec", iteam)
                    #if 48 > get_recomm_rsi(iteam): # and get_recomm_CP(iteam) < get_recomm_R1(iteam):
                        #print("---------------------------->>>>Stoploss<<<<<---- order exec", iteam, get_recomm_CP(iteam) < get_recomm_R1(iteam))
        #loop_counter += 1 # break
        #break

        except Exception as error:
          print('Place Order API Error!<---BreezeAPI--><----WhileLoop--->', error)
    print("------------Loop completed----------tradingView and ICICI same script --------------------------5 signal used -------------------------------------------")
    #break
# Out:
# ------------while loop started ------tradingView and ICICI same script ------------------5 signal used --------------------------------------------------
# <-b/s-> ABB <- STRONG_SELL (RSI>50) False (CP) 8639.35 (RSI) 38.09 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 8725.82 (S1) 8614.32 (R2) 8776.63 (S2) 8553.63 <PV> 8665.13 <MACD_M> 0.35 <MACD_S> 2.58 <SK> 26.91 <SD> 45.65 2024-07-08 09:28:12.136349
# <-b/s-> ACC <- STRONG_BUY (RSI>50) True (CP) 2688.35 (RSI) 64.47 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2724.65 (S1) 2632.85 (R2) 2778.35 (S2) 2594.75 <PV> 2686.55 <MACD_M> -3.62 <MACD_S> -6.47 <SK> 89.09 <SD> 77.78 2024-07-08 09:28:19.667982
# <-b/s-> ATUL <- SELL (RSI>50) False (CP) 6727.0 (RSI) 41.99 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 6816.5 (S1) 6669.0 (R2) 6887.0 (S2) 6592.0 <PV> 6739.5 <MACD_M> -1.12 <MACD_S> -0.57 <SK> 60.53 <SD> 62.45 2024-07-08 09:28:27.440308
# <-b/s-> BHEL <- NEUTRAL (RSI>50) False (CP) 317.0 (RSI) 48.24 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 322.43 (S1) 308.73 (R2) 329.07 (S2) 301.67 <PV> 315.37 <MACD_M> 0.23 <MACD_S> 0.08 <SK> 63.64 <SD> 64.77 2024-07-08 09:28:35.121205
# <-b/s-> BIOCON <- SELL (RSI>50) False (CP) 370.15 (RSI) 48.19 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 373.67 (S1) 362.37 (R2) 378.18 (S2) 355.58 <PV> 366.88 <MACD_M> 0.41 <MACD_S> 0.5 <SK> 51.27 <SD> 52.29 2024-07-08 09:28:41.881827
# <-b/s-> CIPLA <- BUY (RSI>50) True (CP) 1519.05 (RSI) 58.45 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1522.03 (S1) 1492.03 (R2) 1534.02 (S2) 1474.02 <PV> 1504.02 <MACD_M> 2.86 <MACD_S> 1.26 <SK> 77.72 <SD> 80.33 2024-07-08 09:28:49.552136
# <-b/s-> COLPAL <- STRONG_BUY (RSI>50) True (CP) 2920.0 (RSI) 55.87 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2928.45 (S1) 2878.8 (R2) 2947.0 (S2) 2847.7 <PV> 2897.35 <MACD_M> 6.08 <MACD_S> 4.8 <SK> 77.5 <SD> 80.33 2024-07-08 09:28:57.168949
# <-b/s-> CONCOR <- SELL (RSI>50) False (CP) 1056.95 (RSI) 43.46 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1077.48 (S1) 1034.33 (R2) 1095.47 (S2) 1009.17 <PV> 1052.32 <MACD_M> -0.7 <MACD_S> -0.43 <SK> 38.77 <SD> 40.5 2024-07-08 09:29:06.205737
# <-b/s-> GAIL <- BUY (RSI>50) True (CP) 223.39 (RSI) 51.75 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 225.62 (S1) 219.21 (R2) 227.99 (S2) 215.17 <PV> 221.58 <MACD_M> 0.26 <MACD_S> 0.23 <SK> 53.22 <SD> 62.72 2024-07-08 09:29:14.194206
# <-b/s-> GNFC <- SELL (RSI>50) False (CP) 713.0 (RSI) 45.8 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 726.12 (S1) 706.17 (R2) 738.03 (S2) 698.13 <PV> 718.08 <MACD_M> -0.38 <MACD_S> -0.53 <SK> 42.73 <SD> 51.66 2024-07-08 09:29:22.296178
# <-b/s-> GRASIM <- SELL (RSI>50) False (CP) 2734.65 (RSI) 31.12 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 2765.0 (S1) 2729.7 (R2) 2778.0 (S2) 2707.4 <PV> 2742.7 <MACD_M> -1.76 <MACD_S> -0.49 <SK> 29.32 <SD> 50.32 2024-07-08 09:29:30.545028
# <-b/s-> IDFC <- SELL (RSI>50) False (CP) 120.73 (RSI) 38.19 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 121.94 (S1) 120.43 (R2) 122.78 (S2) 119.76 <PV> 121.27 <MACD_M> -0.12 <MACD_S> -0.09 <SK> 37.45 <SD> 45.34 2024-07-08 09:29:39.462642
# <-b/s-> ITC <- NEUTRAL (RSI>50) False (CP) 434.1 (RSI) 48.58 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 435.8 (S1) 429.4 (R2) 438.1 (S2) 425.3 <PV> 431.7 <MACD_M> 0.52 <MACD_S> 0.36 <SK> 71.82 <SD> 79.59 2024-07-08 09:29:47.124231
# <-b/s-> LUPIN <- SELL (RSI>50) False (CP) 1771.35 (RSI) 45.67 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1781.7 (S1) 1752.6 (R2) 1797.9 (S2) 1739.7 <PV> 1768.8 <MACD_M> 2.19 <MACD_S> 1.19 <SK> 63.04 <SD> 63.49 2024-07-08 09:29:55.831004
# <-b/s-> MCX <- SELL (RSI>50) False (CP) 3972.1 (RSI) 49.83 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 4029.53 (S1) 3915.73 (R2) 4079.07 (S2) 3851.47 <PV> 3965.27 <MACD_M> -0.29 <MACD_S> 0.88 <SK> 31.48 <SD> 43.99 2024-07-08 09:30:04.161001
# <-b/s-> NTPC <- BUY (RSI>50) True (CP) 380.0 (RSI) 54.62 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 383.57 (S1) 373.32 (R2) 387.53 (S2) 367.03 <PV> 377.28 <MACD_M> 0.94 <MACD_S> 0.89 <SK> 71.64 <SD> 74.01 2024-07-08 09:30:11.779301
# <-b/s-> ONGC <- BUY (RSI>50) True (CP) 291.75 (RSI) 59.44 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 293.07 (S1) 280.27 (R2) 297.58 (S2) 271.98 <PV> 284.78 <MACD_M> 1.17 <MACD_S> 0.75 <SK> 81.74 <SD> 78.89 2024-07-08 09:30:20.362731
# <-b/s-> SAIL <- STRONG_BUY (RSI>50) True (CP) 156.29 (RSI) 62.95 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 159.47 (S1) 150.57 (R2) 163.56 (S2) 145.76 <PV> 154.66 <MACD_M> 0.15 <MACD_S> 0.07 <SK> 78.2 <SD> 72.36 2024-07-08 09:30:28.812123
# <-b/s-> SRF <- BUY (RSI>50) True (CP) 2405.85 (RSI) 60.59 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2413.4 (S1) 2374.7 (R2) 2431.8 (S2) 2354.4 <PV> 2393.1 <MACD_M> 0.94 <MACD_S> -0.18 <SK> 96.05 <SD> 78.27 2024-07-08 09:30:36.988648
# <-b/s-> SUNTV <- NEUTRAL (RSI>50) True (CP) 783.75 (RSI) 50.8 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 790.47 (S1) 774.37 (R2) 797.43 (S2) 765.23 <PV> 781.33 <MACD_M> -0.04 <MACD_S> 0.01 <SK> 35.26 <SD> 35.18 2024-07-08 09:30:45.690453
# <-b/s-> TCS <- STRONG_BUY (RSI>50) True (CP) 4020.7 (RSI) 56.93 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 4028.5 (S1) 3989.75 (R2) 4047.0 (S2) 3969.5 <PV> 4008.25 <MACD_M> 3.53 <MACD_S> 2.38 <SK> 69.65 <SD> 62.34 2024-07-08 09:30:52.669752
# <-b/s-> TRENT <- STRONG_BUY (RSI>50) True (CP) 5650.0 (RSI) 63.12 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 5661.3 (S1) 5551.85 (R2) 5707.6 (S2) 5488.7 <PV> 5598.15 <MACD_M> 6.08 <MACD_S> 2.77 <SK> 58.7 <SD> 47.22 2024-07-08 09:31:00.569738
# <-b/s-> VOLTAS <- SELL (RSI>50) False (CP) 1447.4 (RSI) 39.97 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 1460.67 (S1) 1441.72 (R2) 1469.28 (S2) 1431.38 <PV> 1450.33 <MACD_M> -0.86 <MACD_S> -0.41 <SK> 21.35 <SD> 35.8 2024-07-08 09:31:08.747869
# <-b/s-> WIPRO <- BUY (RSI>50) True (CP) 540.5 (RSI) 66.01 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 537.78 (S1) 530.73 (R2) 540.67 (S2) 526.57 <PV> 533.62 <MACD_M> 1.26 <MACD_S> 0.52 <SK> 91.2 <SD> 87.33 2024-07-08 09:31:16.908155
# ----->>>>> WIPRO <<<<<<----- tradingview rec BUY
# ->B<- WIPRO -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-08 09:31:24.778683
# ---------------->>>>>>>>---------------
# <-b/s-> ABB <- SELL (RSI>50) False (CP) 8659.75 (RSI) 48.18 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 8725.82 (S1) 8614.32 (R2) 8776.63 (S2) 8553.63 <PV> 8665.13 <MACD_M> 1.34 <MACD_S> 2.61 <SK> 40.64 <SD> 43.49 2024-07-08 09:31:35.345937
# <-b/s-> ACC <- BUY (RSI>50) True (CP) 2692.2 (RSI) 66.59 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2724.65 (S1) 2632.85 (R2) 2778.35 (S2) 2594.75 <PV> 2686.55 <MACD_M> -2.1 <MACD_S> -5.53 <SK> 90.66 <SD> 86.72 2024-07-08 09:31:44.280307
# <-b/s-> ATUL <- SELL (RSI>50) False (CP) 6728.6 (RSI) 44.56 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 6816.5 (S1) 6669.0 (R2) 6887.0 (S2) 6592.0 <PV> 6739.5 <MACD_M> -1.99 <MACD_S> -0.9 <SK> 56.44 <SD> 58.14 2024-07-08 09:31:52.547685
# <-b/s-> BHEL <- STRONG_BUY (RSI>50) True (CP) 317.95 (RSI) 56.81 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 322.43 (S1) 308.73 (R2) 329.07 (S2) 301.67 <PV> 315.37 <MACD_M> 0.35 <MACD_S> 0.14 <SK> 61.68 <SD> 64.23 2024-07-08 09:32:00.821489
# <-b/s-> BIOCON <- SELL (RSI>50) False (CP) 370.15 (RSI) 47.98 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 373.67 (S1) 362.37 (R2) 378.18 (S2) 355.58 <PV> 366.88 <MACD_M> 0.4 <MACD_S> 0.48 <SK> 38.94 <SD> 48.02 2024-07-08 09:32:08.529208
# <-b/s-> CIPLA <- BUY (RSI>50) True (CP) 1516.9 (RSI) 52.44 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1522.03 (S1) 1492.03 (R2) 1534.02 (S2) 1474.02 <PV> 1504.02 <MACD_M> 2.7 <MACD_S> 1.5 <SK> 64.21 <SD> 72.45 2024-07-08 09:32:16.238969
# <-b/s-> COLPAL <- SELL (RSI>50) False (CP) 2916.05 (RSI) 49.37 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2928.45 (S1) 2878.8 (R2) 2947.0 (S2) 2847.7 <PV> 2897.35 <MACD_M> 6.17 <MACD_S> 5.12 <SK> 72.63 <SD> 77.09 2024-07-08 09:32:23.217963
# <-b/s-> CONCOR <- BUY (RSI>50) True (CP) 1062.25 (RSI) 57.97 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1077.48 (S1) 1034.33 (R2) 1095.47 (S2) 1009.17 <PV> 1052.32 <MACD_M> -0.16 <MACD_S> -0.32 <SK> 59.66 <SD> 53.34 2024-07-08 09:32:30.995976
# <-b/s-> GAIL <- NEUTRAL (RSI>50) False (CP) 223.36 (RSI) 49.84 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 225.62 (S1) 219.21 (R2) 227.99 (S2) 215.17 <PV> 221.58 <MACD_M> 0.28 <MACD_S> 0.24 <SK> 51.58 <SD> 56.78 2024-07-08 09:32:40.069894
# <-b/s-> GNFC <- STRONG_SELL (RSI>50) False (CP) 712.5 (RSI) 44.19 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 726.12 (S1) 706.17 (R2) 738.03 (S2) 698.13 <PV> 718.08 <MACD_M> -0.4 <MACD_S> -0.5 <SK> 37.52 <SD> 45.87 2024-07-08 09:32:47.858497
# <-b/s-> GRASIM <- SELL (RSI>50) False (CP) 2736.2 (RSI) 37.07 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 2765.0 (S1) 2729.7 (R2) 2778.0 (S2) 2707.4 <PV> 2742.7 <MACD_M> -2.26 <MACD_S> -0.84 <SK> 21.29 <SD> 34.77 2024-07-08 09:32:56.045627
# <-b/s-> IDFC <- SELL (RSI>50) False (CP) 120.69 (RSI) 40.38 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 121.94 (S1) 120.43 (R2) 122.78 (S2) 119.76 <PV> 121.27 <MACD_M> -0.16 <MACD_S> -0.11 <SK> 11.21 <SD> 29.24 2024-07-08 09:33:03.283682
# <-b/s-> ITC <- BUY (RSI>50) True (CP) 434.4 (RSI) 53.02 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 435.8 (S1) 429.4 (R2) 438.1 (S2) 425.3 <PV> 431.7 <MACD_M> 0.54 <MACD_S> 0.4 <SK> 66.32 <SD> 72.74 2024-07-08 09:33:11.015480
# <-b/s-> LUPIN <- SELL (RSI>50) False (CP) 1771.0 (RSI) 46.08 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1781.7 (S1) 1752.6 (R2) 1797.9 (S2) 1739.7 <PV> 1768.8 <MACD_M> 2.01 <MACD_S> 1.33 <SK> 47.76 <SD> 56.73 2024-07-08 09:33:18.773016
# <-b/s-> MCX <- BUY (RSI>50) True (CP) 3975.95 (RSI) 52.52 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 4029.53 (S1) 3915.73 (R2) 4079.07 (S2) 3851.47 <PV> 3965.27 <MACD_M> -0.3 <MACD_S> 0.63 <SK> 34.24 <SD> 34.86 2024-07-08 09:33:26.530136
# <-b/s-> NTPC <- BUY (RSI>50) True (CP) 380.35 (RSI) 56.21 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 383.57 (S1) 373.32 (R2) 387.53 (S2) 367.03 <PV> 377.28 <MACD_M> 0.99 <MACD_S> 0.91 <SK> 74.32 <SD> 73.59 2024-07-08 09:33:34.520833
# <-b/s-> ONGC <- BUY (RSI>50) True (CP) 290.95 (RSI) 52.63 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 293.07 (S1) 280.27 (R2) 297.58 (S2) 271.98 <PV> 284.78 <MACD_M> 1.1 <MACD_S> 0.73 <SK> 76.19 <SD> 77.33 2024-07-08 09:33:42.670889
# <-b/s-> SAIL <- BUY (RSI>50) True (CP) 156.31 (RSI) 59.87 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 159.47 (S1) 150.57 (R2) 163.56 (S2) 145.76 <PV> 154.66 <MACD_M> 0.15 <MACD_S> 0.07 <SK> 78.72 <SD> 72.54 2024-07-08 09:33:50.824062
# <-b/s-> SRF <- BUY (RSI>50) True (CP) 2403.0 (RSI) 51.4 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2413.4 (S1) 2374.7 (R2) 2431.8 (S2) 2354.4 <PV> 2393.1 <MACD_M> 0.71 <MACD_S> -0.23 <SK> 83.4 <SD> 74.05 2024-07-08 09:33:59.143847
# <-b/s-> SUNTV <- SELL (RSI>50) False (CP) 782.05 (RSI) 45.43 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 790.47 (S1) 774.37 (R2) 797.43 (S2) 765.23 <PV> 781.33 <MACD_M> -0.18 <MACD_S> -0.02 <SK> 28.27 <SD> 32.85 2024-07-08 09:34:07.184818
# <-b/s-> TCS <- BUY (RSI>50) True (CP) 4016.25 (RSI) 51.21 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 4028.5 (S1) 3989.75 (R2) 4047.0 (S2) 3969.5 <PV> 4008.25 <MACD_M> 3.15 <MACD_S> 2.3 <SK> 65.03 <SD> 60.8 2024-07-08 09:34:15.081186
# <-b/s-> TRENT <- BUY (RSI>50) True (CP) 5640.0 (RSI) 53.05 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 5661.3 (S1) 5551.85 (R2) 5707.6 (S2) 5488.7 <PV> 5598.15 <MACD_M> 5.28 <MACD_S> 2.61 <SK> 52.03 <SD> 45.0 2024-07-08 09:34:23.849773
# <-b/s-> VOLTAS <- SELL (RSI>50) False (CP) 1445.95 (RSI) 37.79 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 1460.67 (S1) 1441.72 (R2) 1469.28 (S2) 1431.38 <PV> 1450.33 <MACD_M> -0.98 <MACD_S> -0.43 <SK> 20.77 <SD> 35.61 2024-07-08 09:34:34.113830
# <-b/s-> WIPRO <- BUY (RSI>50) True (CP) 540.15 (RSI) 62.22 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 537.78 (S1) 530.73 (R2) 540.67 (S2) 526.57 <PV> 533.62 <MACD_M> 1.23 <MACD_S> 0.52 <SK> 89.88 <SD> 86.89 2024-07-08 09:34:41.672469
# ----->>>>> WIPRO <<<<<<----- tradingview rec BUY
# ->B<- WIPRO -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-08 09:34:50.146069
# ---------------->>>>>>>>---------------
# ------------Loop completed----------tradingView and ICICI same script --------------------------5 signal used -------------------------------------------
# ------------while loop started ------tradingView and ICICI same script ------------------5 signal used --------------------------------------------------
# <-b/s-> ABB <- SELL (RSI>50) False (CP) 8654.4 (RSI) 47.54 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 8725.82 (S1) 8614.32 (R2) 8776.63 (S2) 8553.63 <PV> 8665.13 <MACD_M> 0.92 <MACD_S> 2.53 <SK> 37.99 <SD> 42.61 2024-07-08 09:35:01.051390
# <-b/s-> ACC <- BUY (RSI>50) True (CP) 2689.8 (RSI) 59.08 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2724.65 (S1) 2632.85 (R2) 2778.35 (S2) 2594.75 <PV> 2686.55 <MACD_M> -2.11 <MACD_S> -5.53 <SK> 90.51 <SD> 86.67 2024-07-08 09:35:09.215878
# <-b/s-> ATUL <- STRONG_SELL (RSI>50) False (CP) 6719.95 (RSI) 40.05 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 6816.5 (S1) 6669.0 (R2) 6887.0 (S2) 6592.0 <PV> 6739.5 <MACD_M> -3.87 <MACD_S> -1.6 <SK> 52.51 <SD> 55.33 2024-07-08 09:35:16.663529
# <-b/s-> BHEL <- STRONG_BUY (RSI>50) True (CP) 320.45 (RSI) 71.89 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 322.43 (S1) 308.73 (R2) 329.07 (S2) 301.67 <PV> 315.37 <MACD_M> 0.75 <MACD_S> 0.29 <SK> 85.29 <SD> 75.23 2024-07-08 09:35:26.281193
# <-b/s-> BIOCON <- NEUTRAL (RSI>50) True (CP) 370.45 (RSI) 50.06 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 373.67 (S1) 362.37 (R2) 378.18 (S2) 355.58 <PV> 366.88 <MACD_M> 0.42 <MACD_S> 0.48 <SK> 45.29 <SD> 47.58 2024-07-08 09:35:33.673809
# <-b/s-> CIPLA <- BUY (RSI>50) True (CP) 1517.1 (RSI) 52.48 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1522.03 (S1) 1492.03 (R2) 1534.02 (S2) 1474.02 <PV> 1504.02 <MACD_M> 3.0 <MACD_S> 1.83 <SK> 66.4 <SD> 68.89 2024-07-08 09:35:41.030964
# <-b/s-> COLPAL <- NEUTRAL (RSI>50) False (CP) 2916.0 (RSI) 49.55 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2928.45 (S1) 2878.8 (R2) 2947.0 (S2) 2847.7 <PV> 2897.35 <MACD_M> 5.93 <MACD_S> 5.28 <SK> 71.29 <SD> 74.9 2024-07-08 09:35:49.171722
# <-b/s-> CONCOR <- BUY (RSI>50) True (CP) 1063.2 (RSI) 59.77 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1077.48 (S1) 1034.33 (R2) 1095.47 (S2) 1009.17 <PV> 1052.32 <MACD_M> 0.12 <MACD_S> -0.23 <SK> 75.43 <SD> 63.16 2024-07-08 09:35:55.631246
# <-b/s-> GAIL <- SELL (RSI>50) False (CP) 223.05 (RSI) 45.8 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 225.62 (S1) 219.21 (R2) 227.99 (S2) 215.17 <PV> 221.58 <MACD_M> 0.22 <MACD_S> 0.23 <SK> 42.83 <SD> 48.38 2024-07-08 09:36:02.936649
# <-b/s-> GNFC <- SELL (RSI>50) False (CP) 710.4 (RSI) 36.47 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 726.12 (S1) 706.17 (R2) 738.03 (S2) 698.13 <PV> 718.08 <MACD_M> -0.68 <MACD_S> -0.54 <SK> 19.27 <SD> 33.25 2024-07-08 09:36:10.883118
# <-b/s-> GRASIM <- SELL (RSI>50) False (CP) 2735.0 (RSI) 35.88 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 2765.0 (S1) 2729.7 (R2) 2778.0 (S2) 2707.4 <PV> 2742.7 <MACD_M> -2.83 <MACD_S> -1.26 <SK> 16.14 <SD> 21.74 2024-07-08 09:36:21.044566
# <-b/s-> IDFC <- STRONG_SELL (RSI>50) False (CP) 120.41 (RSI) 34.34 <CP>R1> False <CP>PV> False <CP<S1> True (R1) 121.94 (S1) 120.43 (R2) 122.78 (S2) 119.76 <PV> 121.27 <MACD_M> -0.2 <MACD_S> -0.13 <SK> 6.56 <SD> 17.23 2024-07-08 09:36:29.681740
# ----->>>>> IDFC <<<<<<----- IDFC tradingview rec STRONG_SELL
# ->S<- IDFC -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-08 09:36:37.872536
# ---------------->>>>>>>>---------------
# <-b/s-> ITC <- SELL (RSI>50) False (CP) 433.95 (RSI) 44.45 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 435.8 (S1) 429.4 (R2) 438.1 (S2) 425.3 <PV> 431.7 <MACD_M> 0.54 <MACD_S> 0.43 <SK> 64.95 <SD> 67.93 2024-07-08 09:36:47.739267
# <-b/s-> LUPIN <- SELL (RSI>50) False (CP) 1769.05 (RSI) 40.14 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1781.7 (S1) 1752.6 (R2) 1797.9 (S2) 1739.7 <PV> 1768.8 <MACD_M> 1.68 <MACD_S> 1.38 <SK> 34.16 <SD> 46.94 2024-07-08 09:36:55.694266
# <-b/s-> MCX <- SELL (RSI>50) False (CP) 3962.55 (RSI) 43.46 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4029.53 (S1) 3915.73 (R2) 4079.07 (S2) 3851.47 <PV> 3965.27 <MACD_M> -1.67 <MACD_S> 0.08 <SK> 32.61 <SD> 30.96 2024-07-08 09:37:03.623921
# <-b/s-> NTPC <- SELL (RSI>50) False (CP) 379.4 (RSI) 46.89 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 383.57 (S1) 373.32 (R2) 387.53 (S2) 367.03 <PV> 377.28 <MACD_M> 0.91 <MACD_S> 0.91 <SK> 73.81 <SD> 74.19 2024-07-08 09:37:12.469494
# <-b/s-> ONGC <- NEUTRAL (RSI>50) False (CP) 290.15 (RSI) 45.94 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 293.07 (S1) 280.27 (R2) 297.58 (S2) 271.98 <PV> 284.78 <MACD_M> 1.06 <MACD_S> 0.8 <SK> 66.03 <SD> 74.0 2024-07-08 09:37:20.392812
# <-b/s-> SAIL <- BUY (RSI>50) True (CP) 156.12 (RSI) 54.05 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 159.47 (S1) 150.57 (R2) 163.56 (S2) 145.76 <PV> 154.66 <MACD_M> 0.16 <MACD_S> 0.09 <SK> 83.11 <SD> 79.71 2024-07-08 09:37:27.370578
# <-b/s-> SRF <- STRONG_SELL (RSI>50) False (CP) 2397.35 (RSI) 41.04 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2413.4 (S1) 2374.7 (R2) 2431.8 (S2) 2354.4 <PV> 2393.1 <MACD_M> 0.24 <MACD_S> -0.17 <SK> 55.39 <SD> 70.6 2024-07-08 09:37:35.195106
# <-b/s-> SUNTV <- SELL (RSI>50) False (CP) 780.45 (RSI) 40.07 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 790.47 (S1) 774.37 (R2) 797.43 (S2) 765.23 <PV> 781.33 <MACD_M> -0.42 <MACD_S> -0.11 <SK> 26.54 <SD> 29.02 2024-07-08 09:37:43.106795
# <-b/s-> TCS <- SELL (RSI>50) False (CP) 4008.95 (RSI) 42.13 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 4028.5 (S1) 3989.75 (R2) 4047.0 (S2) 3969.5 <PV> 4008.25 <MACD_M> 2.45 <MACD_S> 2.31 <SK> 49.71 <SD> 57.58 2024-07-08 09:37:50.429838
# <-b/s-> TRENT <- NEUTRAL (RSI>50) False (CP) 5635.55 (RSI) 48.91 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 5661.3 (S1) 5551.85 (R2) 5707.6 (S2) 5488.7 <PV> 5598.15 <MACD_M> 5.38 <MACD_S> 3.16 <SK> 52.37 <SD> 52.29 2024-07-08 09:37:57.929839
# <-b/s-> VOLTAS <- SELL (RSI>50) False (CP) 1444.8 (RSI) 37.07 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 1460.67 (S1) 1441.72 (R2) 1469.28 (S2) 1431.38 <PV> 1450.33 <MACD_M> -1.35 <MACD_S> -0.62 <SK> 13.73 <SD> 23.8 2024-07-08 09:38:04.850837
# <-b/s-> WIPRO <- BUY (RSI>50) False (CP) 538.65 (RSI) 49.22 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 537.78 (S1) 530.73 (R2) 540.67 (S2) 526.57 <PV> 533.62 <MACD_M> 1.27 <MACD_S> 0.67 <SK> 85.9 <SD> 88.53 2024-07-08 09:38:13.128238
# <-b/s-> ABB <- SELL (RSI>50) False (CP) 8646.6 (RSI) 46.15 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 8725.82 (S1) 8614.32 (R2) 8776.63 (S2) 8553.63 <PV> 8665.13 <MACD_M> -0.44 <MACD_S> 1.98 <SK> 40.99 <SD> 41.09 2024-07-08 09:38:20.071267
# <-b/s-> ACC <- BUY (RSI>50) True (CP) 2690.85 (RSI) 59.41 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2724.65 (S1) 2632.85 (R2) 2778.35 (S2) 2594.75 <PV> 2686.55 <MACD_M> -1.17 <MACD_S> -4.66 <SK> 92.06 <SD> 91.35 2024-07-08 09:38:28.000371
# <-b/s-> ATUL <- SELL (RSI>50) False (CP) 6723.6 (RSI) 44.87 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 6816.5 (S1) 6669.0 (R2) 6887.0 (S2) 6592.0 <PV> 6739.5 <MACD_M> -3.38 <MACD_S> -1.5 <SK> 54.32 <SD> 55.93 2024-07-08 09:38:35.535347
# <-b/s-> BHEL <- BUY (RSI>50) True (CP) 318.75 (RSI) 55.88 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 322.43 (S1) 308.73 (R2) 329.07 (S2) 301.67 <PV> 315.37 <MACD_M> 0.61 <MACD_S> 0.26 <SK> 75.53 <SD> 71.98 2024-07-08 09:38:43.018116
# <-b/s-> BIOCON <- SELL (RSI>50) False (CP) 369.95 (RSI) 48.31 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 373.67 (S1) 362.37 (R2) 378.18 (S2) 355.58 <PV> 366.88 <MACD_M> 0.38 <MACD_S> 0.47 <SK> 41.67 <SD> 46.37 2024-07-08 09:38:50.400031
# <-b/s-> CIPLA <- NEUTRAL (RSI>50) False (CP) 1515.0 (RSI) 46.12 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1522.03 (S1) 1492.03 (R2) 1534.02 (S2) 1474.02 <PV> 1504.02 <MACD_M> 2.83 <MACD_S> 1.8 <SK> 63.36 <SD> 67.88 2024-07-08 09:38:57.789632
# <-b/s-> COLPAL <- SELL (RSI>50) False (CP) 2911.8 (RSI) 46.07 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2928.45 (S1) 2878.8 (R2) 2947.0 (S2) 2847.7 <PV> 2897.35 <MACD_M> 5.59 <MACD_S> 5.21 <SK> 67.66 <SD> 73.69 2024-07-08 09:39:05.149608
# <-b/s-> CONCOR <- BUY (RSI>50) True (CP) 1062.65 (RSI) 57.3 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1077.48 (S1) 1034.33 (R2) 1095.47 (S2) 1009.17 <PV> 1052.32 <MACD_M> 0.08 <MACD_S> -0.23 <SK> 73.54 <SD> 62.53 2024-07-08 09:39:14.279450
# <-b/s-> GAIL <- SELL (RSI>50) False (CP) 222.57 (RSI) 40.0 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 225.62 (S1) 219.21 (R2) 227.99 (S2) 215.17 <PV> 221.58 <MACD_M> 0.18 <MACD_S> 0.23 <SK> 36.82 <SD> 46.38 2024-07-08 09:39:23.735977
# <-b/s-> GNFC <- SELL (RSI>50) False (CP) 711.4 (RSI) 45.09 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 726.12 (S1) 706.17 (R2) 738.03 (S2) 698.13 <PV> 718.08 <MACD_M> -0.6 <MACD_S> -0.53 <SK> 32.05 <SD> 37.51 2024-07-08 09:39:32.262048
# <-b/s-> GRASIM <- SELL (RSI>50) False (CP) 2735.3 (RSI) 40.78 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 2765.0 (S1) 2729.7 (R2) 2778.0 (S2) 2707.4 <PV> 2742.7 <MACD_M> -2.81 <MACD_S> -1.25 <SK> 16.56 <SD> 21.88 2024-07-08 09:39:40.153756
# <-b/s-> IDFC <- SELL (RSI>50) False (CP) 120.73 (RSI) 44.62 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 121.94 (S1) 120.43 (R2) 122.78 (S2) 119.76 <PV> 121.27 <MACD_M> -0.17 <MACD_S> -0.12 <SK> 16.97 <SD> 20.71 2024-07-08 09:39:48.520930
# <-b/s-> ITC <- SELL (RSI>50) False (CP) 434.0 (RSI) 45.44 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 435.8 (S1) 429.4 (R2) 438.1 (S2) 425.3 <PV> 431.7 <MACD_M> 0.51 <MACD_S> 0.42 <SK> 62.89 <SD> 67.24 2024-07-08 09:39:56.470995
# <-b/s-> LUPIN <- SELL (RSI>50) False (CP) 1770.6 (RSI) 47.31 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1781.7 (S1) 1752.6 (R2) 1797.9 (S2) 1739.7 <PV> 1768.8 <MACD_M> 1.81 <MACD_S> 1.41 <SK> 36.34 <SD> 47.66 2024-07-08 09:40:05.130140
# <-b/s-> MCX <- STRONG_SELL (RSI>50) False (CP) 3963.45 (RSI) 45.14 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4029.53 (S1) 3915.73 (R2) 4079.07 (S2) 3851.47 <PV> 3965.27 <MACD_M> -2.3 <MACD_S> -0.4 <SK> 27.1 <SD> 29.67 2024-07-08 09:40:13.424679
# <-b/s-> NTPC <- SELL (RSI>50) False (CP) 378.35 (RSI) 38.9 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 383.57 (S1) 373.32 (R2) 387.53 (S2) 367.03 <PV> 377.28 <MACD_M> 0.69 <MACD_S> 0.85 <SK> 47.87 <SD> 62.46 2024-07-08 09:40:21.545016
# <-b/s-> ONGC <- NEUTRAL (RSI>50) True (CP) 290.75 (RSI) 51.03 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 293.07 (S1) 280.27 (R2) 297.58 (S2) 271.98 <PV> 284.78 <MACD_M> 1.1 <MACD_S> 0.87 <SK> 62.05 <SD> 69.46 2024-07-08 09:40:29.292095
# <-b/s-> SAIL <- BUY (RSI>50) True (CP) 156.22 (RSI) 54.7 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 159.47 (S1) 150.57 (R2) 163.56 (S2) 145.76 <PV> 154.66 <MACD_M> 0.19 <MACD_S> 0.11 <SK> 84.11 <SD> 83.54 2024-07-08 09:40:35.981072
# <-b/s-> SRF <- SELL (RSI>50) False (CP) 2400.9 (RSI) 49.12 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2413.4 (S1) 2374.7 (R2) 2431.8 (S2) 2354.4 <PV> 2393.1 <MACD_M> 0.65 <MACD_S> 0.06 <SK> 50.33 <SD> 64.32 2024-07-08 09:40:43.377346
# <-b/s-> SUNTV <- SELL (RSI>50) False (CP) 781.45 (RSI) 45.92 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 790.47 (S1) 774.37 (R2) 797.43 (S2) 765.23 <PV> 781.33 <MACD_M> -0.45 <MACD_S> -0.16 <SK> 20.58 <SD> 25.54 2024-07-08 09:40:51.465557
# <-b/s-> TCS <- SELL (RSI>50) False (CP) 4005.9 (RSI) 39.23 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4028.5 (S1) 3989.75 (R2) 4047.0 (S2) 3969.5 <PV> 4008.25 <MACD_M> 1.49 <MACD_S> 2.09 <SK> 33.86 <SD> 47.72 2024-07-08 09:41:00.534098
# <-b/s-> TRENT <- NEUTRAL (RSI>50) False (CP) 5634.45 (RSI) 48.29 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 5661.3 (S1) 5551.85 (R2) 5707.6 (S2) 5488.7 <PV> 5598.15 <MACD_M> 5.08 <MACD_S> 3.5 <SK> 40.87 <SD> 47.6 2024-07-08 09:41:07.981106
# <-b/s-> VOLTAS <- SELL (RSI>50) False (CP) 1445.9 (RSI) 42.8 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 1460.67 (S1) 1441.72 (R2) 1469.28 (S2) 1431.38 <PV> 1450.33 <MACD_M> -1.71 <MACD_S> -0.8 <SK> 16.12 <SD> 19.27 2024-07-08 09:41:14.469432
# <-b/s-> WIPRO <- BUY (RSI>50) True (CP) 539.05 (RSI) 52.49 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 537.78 (S1) 530.73 (R2) 540.67 (S2) 526.57 <PV> 533.62 <MACD_M> 1.34 <MACD_S> 0.81 <SK> 81.59 <SD> 86.4 2024-07-08 09:41:21.954911
# ------------Loop completed----------tradingView and ICICI same script --------------------------5 signal used -------------------------------------------
# ------------while loop started ------tradingView and ICICI same script ------------------5 signal used --------------------------------------------------
# <-b/s-> ABB <- SELL (RSI>50) False (CP) 8631.75 (RSI) 40.74 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 8725.82 (S1) 8614.32 (R2) 8776.63 (S2) 8553.63 <PV> 8665.13 <MACD_M> -2.89 <MACD_S> 1.0 <SK> 26.37 <SD> 35.68 2024-07-08 09:41:30.384514
# <-b/s-> ACC <- NEUTRAL (RSI>50) True (CP) 2688.85 (RSI) 54.24 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2724.65 (S1) 2632.85 (R2) 2778.35 (S2) 2594.75 <PV> 2686.55 <MACD_M> -0.57 <MACD_S> -3.84 <SK> 88.4 <SD> 90.35 2024-07-08 09:41:38.838203
# <-b/s-> ATUL <- NEUTRAL (RSI>50) True (CP) 6732.0 (RSI) 50.5 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 6816.5 (S1) 6669.0 (R2) 6887.0 (S2) 6592.0 <PV> 6739.5 <MACD_M> -2.96 <MACD_S> -1.68 <SK> 58.27 <SD> 56.41 2024-07-08 09:41:47.300057
# <-b/s-> BHEL <- NEUTRAL (RSI>50) True (CP) 318.2 (RSI) 50.99 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 322.43 (S1) 308.73 (R2) 329.07 (S2) 301.67 <PV> 315.37 <MACD_M> 0.63 <MACD_S> 0.34 <SK> 77.51 <SD> 75.78 2024-07-08 09:41:54.812614
# <-b/s-> BIOCON <- STRONG_SELL (RSI>50) False (CP) 369.0 (RSI) 42.3 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 373.67 (S1) 362.37 (R2) 378.18 (S2) 355.58 <PV> 366.88 <MACD_M> 0.23 <MACD_S> 0.42 <SK> 27.17 <SD> 36.29 2024-07-08 09:42:01.028615
# <-b/s-> CIPLA <- SELL (RSI>50) False (CP) 1513.0 (RSI) 40.3 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1522.03 (S1) 1492.03 (R2) 1534.02 (S2) 1474.02 <PV> 1504.02 <MACD_M> 2.62 <MACD_S> 1.96 <SK> 57.78 <SD> 62.91 2024-07-08 09:42:08.222519
# <-b/s-> COLPAL <- BUY (RSI>50) True (CP) 2917.5 (RSI) 53.36 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2928.45 (S1) 2878.8 (R2) 2947.0 (S2) 2847.7 <PV> 2897.35 <MACD_M> 5.74 <MACD_S> 5.4 <SK> 65.63 <SD> 70.34 2024-07-08 09:42:15.587309
# <-b/s-> CONCOR <- STRONG_SELL (RSI>50) False (CP) 1056.7 (RSI) 37.98 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1077.48 (S1) 1034.33 (R2) 1095.47 (S2) 1009.17 <PV> 1052.32 <MACD_M> -0.29 <MACD_S> -0.26 <SK> 56.01 <SD> 62.73 2024-07-08 09:42:23.385313
# <-b/s-> GAIL <- SELL (RSI>50) False (CP) 221.74 (RSI) 29.48 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 225.62 (S1) 219.21 (R2) 227.99 (S2) 215.17 <PV> 221.58 <MACD_M> 0.04 <MACD_S> 0.18 <SK> 9.32 <SD> 28.81 2024-07-08 09:42:31.424712
# <-b/s-> GNFC <- SELL (RSI>50) False (CP) 707.6 (RSI) 34.01 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 726.12 (S1) 706.17 (R2) 738.03 (S2) 698.13 <PV> 718.08 <MACD_M> -1.04 <MACD_S> -0.63 <SK> 17.22 <SD> 27.3 2024-07-08 09:42:38.921717
# <-b/s-> GRASIM <- SELL (RSI>50) False (CP) 2733.85 (RSI) 39.7 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 2765.0 (S1) 2729.7 (R2) 2778.0 (S2) 2707.4 <PV> 2742.7 <MACD_M> -3.25 <MACD_S> -1.66 <SK> 15.39 <SD> 16.96 2024-07-08 09:42:47.201879
# <-b/s-> IDFC <- SELL (RSI>50) False (CP) 120.32 (RSI) 34.41 <CP>R1> False <CP>PV> False <CP<S1> True (R1) 121.94 (S1) 120.43 (R2) 122.78 (S2) 119.76 <PV> 121.27 <MACD_M> -0.22 <MACD_S> -0.14 <SK> 16.86 <SD> 14.76 2024-07-08 09:42:55.993904
# <-b/s-> ITC <- NEUTRAL (RSI>50) False (CP) 434.0 (RSI) 46.63 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 435.8 (S1) 429.4 (R2) 438.1 (S2) 425.3 <PV> 431.7 <MACD_M> 0.49 <MACD_S> 0.44 <SK> 61.13 <SD> 63.68 2024-07-08 09:43:04.171659
# <-b/s-> LUPIN <- STRONG_SELL (RSI>50) False (CP) 1763.2 (RSI) 35.21 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 1781.7 (S1) 1752.6 (R2) 1797.9 (S2) 1739.7 <PV> 1768.8 <MACD_M> 1.07 <MACD_S> 1.32 <SK> 24.69 <SD> 35.02 2024-07-08 09:43:10.986663
# <-b/s-> MCX <- SELL (RSI>50) False (CP) 3956.25 (RSI) 42.52 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4029.53 (S1) 3915.73 (R2) 4079.07 (S2) 3851.47 <PV> 3965.27 <MACD_M> -2.87 <MACD_S> -0.52 <SK> 25.95 <SD> 29.29 2024-07-08 09:43:18.609935
# <-b/s-> NTPC <- SELL (RSI>50) False (CP) 377.75 (RSI) 35.27 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 383.57 (S1) 373.32 (R2) 387.53 (S2) 367.03 <PV> 377.28 <MACD_M> 0.64 <MACD_S> 0.84 <SK> 43.05 <SD> 60.85 2024-07-08 09:43:26.192939
# <-b/s-> ONGC <- NEUTRAL (RSI>50) False (CP) 289.75 (RSI) 44.04 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 293.07 (S1) 280.27 (R2) 297.58 (S2) 271.98 <PV> 284.78 <MACD_M> 1.02 <MACD_S> 0.85 <SK> 56.15 <SD> 67.5 2024-07-08 09:43:34.867631
# <-b/s-> SAIL <- NEUTRAL (RSI>50) False (CP) 155.85 (RSI) 46.75 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 159.47 (S1) 150.57 (R2) 163.56 (S2) 145.76 <PV> 154.66 <MACD_M> 0.16 <MACD_S> 0.1 <SK> 75.78 <SD> 80.33 2024-07-08 09:43:42.517249
# <-b/s-> SRF <- SELL (RSI>50) False (CP) 2394.0 (RSI) 38.8 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2413.4 (S1) 2374.7 (R2) 2431.8 (S2) 2354.4 <PV> 2393.1 <MACD_M> 0.1 <MACD_S> -0.05 <SK> 38.39 <SD> 60.34 2024-07-08 09:43:49.297305
# <-b/s-> SUNTV <- SELL (RSI>50) False (CP) 781.15 (RSI) 45.65 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 790.47 (S1) 774.37 (R2) 797.43 (S2) 765.23 <PV> 781.33 <MACD_M> -0.47 <MACD_S> -0.17 <SK> 22.24 <SD> 26.09 2024-07-08 09:43:56.898928
# <-b/s-> TCS <- SELL (RSI>50) False (CP) 4006.5 (RSI) 41.38 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4028.5 (S1) 3989.75 (R2) 4047.0 (S2) 3969.5 <PV> 4008.25 <MACD_M> 1.54 <MACD_S> 2.1 <SK> 34.44 <SD> 47.91 2024-07-08 09:44:04.324439
# <-b/s-> TRENT <- BUY (RSI>50) True (CP) 5636.65 (RSI) 51.58 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 5661.3 (S1) 5551.85 (R2) 5707.6 (S2) 5488.7 <PV> 5598.15 <MACD_M> 5.26 <MACD_S> 3.53 <SK> 42.33 <SD> 48.09 2024-07-08 09:44:11.611743
# <-b/s-> VOLTAS <- SELL (RSI>50) False (CP) 1444.95 (RSI) 44.92 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 1460.67 (S1) 1441.72 (R2) 1469.28 (S2) 1431.38 <PV> 1450.33 <MACD_M> -1.42 <MACD_S> -0.74 <SK> 26.95 <SD> 22.88 2024-07-08 09:44:18.974478
# <-b/s-> WIPRO <- NEUTRAL (RSI>50) False (CP) 538.1 (RSI) 44.18 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 537.78 (S1) 530.73 (R2) 540.67 (S2) 526.57 <PV> 533.62 <MACD_M> 1.26 <MACD_S> 0.79 <SK> 78.44 <SD> 85.35 2024-07-08 09:44:26.424050
# <-b/s-> ABB <- SELL (RSI>50) False (CP) 8626.75 (RSI) 40.99 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 8725.82 (S1) 8614.32 (R2) 8776.63 (S2) 8553.63 <PV> 8665.13 <MACD_M> -3.29 <MACD_S> 0.92 <SK> 28.64 <SD> 36.44 2024-07-08 09:44:34.981813
# <-b/s-> ACC <- BUY (RSI>50) True (CP) 2692.0 (RSI) 57.59 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2724.65 (S1) 2632.85 (R2) 2778.35 (S2) 2594.75 <PV> 2686.55 <MACD_M> -0.31 <MACD_S> -3.79 <SK> 90.64 <SD> 91.1 2024-07-08 09:44:42.194669
# <-b/s-> ATUL <- STRONG_BUY (RSI>50) True (CP) 6746.2 (RSI) 58.53 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 6816.5 (S1) 6669.0 (R2) 6887.0 (S2) 6592.0 <PV> 6739.5 <MACD_M> -1.5 <MACD_S> -1.38 <SK> 63.6 <SD> 58.19 2024-07-08 09:44:49.740198
# <-b/s-> BHEL <- BUY (RSI>50) True (CP) 319.2 (RSI) 57.49 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 322.43 (S1) 308.73 (R2) 329.07 (S2) 301.67 <PV> 315.37 <MACD_M> 0.71 <MACD_S> 0.36 <SK> 82.93 <SD> 77.58 2024-07-08 09:44:58.495185
# <-b/s-> BIOCON <- SELL (RSI>50) False (CP) 368.8 (RSI) 41.65 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 373.67 (S1) 362.37 (R2) 378.18 (S2) 355.58 <PV> 366.88 <MACD_M> 0.21 <MACD_S> 0.41 <SK> 27.63 <SD> 36.44 2024-07-08 09:45:06.387809
# <-b/s-> CIPLA <- NEUTRAL (RSI>50) False (CP) 1511.7 (RSI) 38.76 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1522.03 (S1) 1492.03 (R2) 1534.02 (S2) 1474.02 <PV> 1504.02 <MACD_M> 2.14 <MACD_S> 1.97 <SK> 42.2 <SD> 53.53 2024-07-08 09:45:13.968731
# <-b/s-> COLPAL <- STRONG_BUY (RSI>50) True (CP) 2918.3 (RSI) 53.71 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2928.45 (S1) 2878.8 (R2) 2947.0 (S2) 2847.7 <PV> 2897.35 <MACD_M> 5.73 <MACD_S> 5.48 <SK> 67.96 <SD> 69.23 2024-07-08 09:45:21.785488
# <-b/s-> CONCOR <- STRONG_SELL (RSI>50) False (CP) 1055.7 (RSI) 35.47 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1077.48 (S1) 1034.33 (R2) 1095.47 (S2) 1009.17 <PV> 1052.32 <MACD_M> -0.67 <MACD_S> -0.35 <SK> 28.35 <SD> 50.57 2024-07-08 09:45:32.698932
# <-b/s-> GAIL <- SELL (RSI>50) False (CP) 221.89 (RSI) 35.28 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 225.62 (S1) 219.21 (R2) 227.99 (S2) 215.17 <PV> 221.58 <MACD_M> -0.02 <MACD_S> 0.15 <SK> 9.69 <SD> 18.76 2024-07-08 09:45:40.753750
# <-b/s-> GNFC <- SELL (RSI>50) False (CP) 709.5 (RSI) 42.22 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 726.12 (S1) 706.17 (R2) 738.03 (S2) 698.13 <PV> 718.08 <MACD_M> -1.07 <MACD_S> -0.7 <SK> 26.44 <SD> 27.0 2024-07-08 09:45:48.384747
# <-b/s-> GRASIM <- STRONG_SELL (RSI>50) False (CP) 2730.4 (RSI) 35.14 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 2765.0 (S1) 2729.7 (R2) 2778.0 (S2) 2707.4 <PV> 2742.7 <MACD_M> -3.94 <MACD_S> -2.14 <SK> 7.26 <SD> 11.96 2024-07-08 09:45:56.293375
# <-b/s-> IDFC <- SELL (RSI>50) False (CP) 120.21 (RSI) 33.11 <CP>R1> False <CP>PV> False <CP<S1> True (R1) 121.94 (S1) 120.43 (R2) 122.78 (S2) 119.76 <PV> 121.27 <MACD_M> -0.26 <MACD_S> -0.17 <SK> 9.89 <SD> 13.73 2024-07-08 09:46:04.153338
# ----->>>>> IDFC <<<<<<----- IDFC tradingview rec SELL
# ->S<- IDFC -> CP<S1 True (RSI<50) True (SK<SD) True EMA** True (MACD_m<MACD_s) True T 2024-07-08 09:46:11.982018
# ---------------->>>>>>>>---------------
# <-b/s-> ITC <- BUY (RSI>50) True (CP) 434.35 (RSI) 52.82 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 435.8 (S1) 429.4 (R2) 438.1 (S2) 425.3 <PV> 431.7 <MACD_M> 0.52 <MACD_S> 0.46 <SK> 62.71 <SD> 63.7 2024-07-08 09:46:23.546586
# <-b/s-> LUPIN <- SELL (RSI>50) False (CP) 1767.55 (RSI) 47.2 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 1781.7 (S1) 1752.6 (R2) 1797.9 (S2) 1739.7 <PV> 1768.8 <MACD_M> 0.88 <MACD_S> 1.23 <SK> 22.64 <SD> 27.47 2024-07-08 09:46:31.958746
# <-b/s-> MCX <- SELL (RSI>50) False (CP) 3952.95 (RSI) 41.02 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4029.53 (S1) 3915.73 (R2) 4079.07 (S2) 3851.47 <PV> 3965.27 <MACD_M> -4.14 <MACD_S> -1.27 <SK> 17.2 <SD> 24.65 2024-07-08 09:46:39.792926
# <-b/s-> NTPC <- SELL (RSI>50) False (CP) 377.85 (RSI) 37.22 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 383.57 (S1) 373.32 (R2) 387.53 (S2) 367.03 <PV> 377.28 <MACD_M> 0.53 <MACD_S> 0.78 <SK> 23.29 <SD> 44.25 2024-07-08 09:46:47.720295
# <-b/s-> ONGC <- NEUTRAL (RSI>50) False (CP) 289.15 (RSI) 39.87 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 293.07 (S1) 280.27 (R2) 297.58 (S2) 271.98 <PV> 284.78 <MACD_M> 0.89 <MACD_S> 0.86 <SK> 45.43 <SD> 56.95 2024-07-08 09:46:55.664908
# <-b/s-> SAIL <- BUY (RSI>50) True (CP) 156.14 (RSI) 53.96 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 159.47 (S1) 150.57 (R2) 163.56 (S2) 145.76 <PV> 154.66 <MACD_M> 0.16 <MACD_S> 0.11 <SK> 67.31 <SD> 75.66 2024-07-08 09:47:02.619617
# <-b/s-> SRF <- SELL (RSI>50) False (CP) 2397.25 (RSI) 46.85 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2413.4 (S1) 2374.7 (R2) 2431.8 (S2) 2354.4 <PV> 2393.1 <MACD_M> -0.09 <MACD_S> -0.06 <SK> 33.39 <SD> 45.33 2024-07-08 09:47:10.850555
# <-b/s-> SUNTV <- SELL (RSI>50) False (CP) 780.5 (RSI) 43.18 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 790.47 (S1) 774.37 (R2) 797.43 (S2) 765.23 <PV> 781.33 <MACD_M> -0.6 <MACD_S> -0.25 <SK> 21.64 <SD> 24.76 2024-07-08 09:47:20.555561
# <-b/s-> TCS <- SELL (RSI>50) False (CP) 4002.95 (RSI) 37.61 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4028.5 (S1) 3989.75 (R2) 4047.0 (S2) 3969.5 <PV> 4008.25 <MACD_M> 0.61 <MACD_S> 1.77 <SK> 21.0 <SD> 32.92 2024-07-08 09:47:28.979584
# <-b/s-> TRENT <- BUY (RSI>50) True (CP) 5638.75 (RSI) 53.17 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 5661.3 (S1) 5551.85 (R2) 5707.6 (S2) 5488.7 <PV> 5598.15 <MACD_M> 5.65 <MACD_S> 3.99 <SK> 43.17 <SD> 45.69 2024-07-08 09:47:36.644140
# <-b/s-> VOLTAS <- SELL (RSI>50) False (CP) 1444.2 (RSI) 44.18 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 1460.67 (S1) 1441.72 (R2) 1469.28 (S2) 1431.38 <PV> 1450.33 <MACD_M> -1.79 <MACD_S> -0.92 <SK> 33.34 <SD> 24.57 2024-07-08 09:47:44.447493
# <-b/s-> WIPRO <- BUY (RSI>50) False (CP) 538.45 (RSI) 48.6 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 537.78 (S1) 530.73 (R2) 540.67 (S2) 526.57 <PV> 533.62 <MACD_M> 1.29 <MACD_S> 0.89 <SK> 74.13 <SD> 79.99 2024-07-08 09:47:51.984047
# ------------Loop completed----------tradingView and ICICI same script --------------------------5 signal used -------------------------------------------
# ------------while loop started ------tradingView and ICICI same script ------------------5 signal used --------------------------------------------------
# <-b/s-> ABB <- SELL (RSI>50) False (CP) 8633.5 (RSI) 45.07 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 8725.82 (S1) 8614.32 (R2) 8776.63 (S2) 8553.63 <PV> 8665.13 <MACD_M> -4.63 <MACD_S> -0.12 <SK> 23.11 <SD> 31.66 2024-07-08 09:48:00.761072
# <-b/s-> ACC <- BUY (RSI>50) True (CP) 2691.3 (RSI) 56.07 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2724.65 (S1) 2632.85 (R2) 2778.35 (S2) 2594.75 <PV> 2686.55 <MACD_M> 0.16 <MACD_S> -3.03 <SK> 90.03 <SD> 90.4 2024-07-08 09:48:10.131159
# <-b/s-> ATUL <- BUY (RSI>50) True (CP) 6800.5 (RSI) 73.52 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 6816.5 (S1) 6669.0 (R2) 6887.0 (S2) 6592.0 <PV> 6739.5 <MACD_M> 3.97 <MACD_S> -0.26 <SK> 77.52 <SD> 66.43 2024-07-08 09:48:18.589697
# <-b/s-> BHEL <- BUY (RSI>50) True (CP) 319.4 (RSI) 58.38 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 322.43 (S1) 308.73 (R2) 329.07 (S2) 301.67 <PV> 315.37 <MACD_M> 0.77 <MACD_S> 0.44 <SK> 76.8 <SD> 78.96 2024-07-08 09:48:26.157856
# <-b/s-> BIOCON <- NEUTRAL (RSI>50) False (CP) 369.5 (RSI) 49.76 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 373.67 (S1) 362.37 (R2) 378.18 (S2) 355.58 <PV> 366.88 <MACD_M> 0.13 <MACD_S> 0.35 <SK> 20.53 <SD> 28.29 2024-07-08 09:48:33.816453
# <-b/s-> CIPLA <- BUY (RSI>50) True (CP) 1515.8 (RSI) 53.42 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1522.03 (S1) 1492.03 (R2) 1534.02 (S2) 1474.02 <PV> 1504.02 <MACD_M> 2.51 <MACD_S> 2.05 <SK> 49.9 <SD> 56.09 2024-07-08 09:48:40.581818
# <-b/s-> COLPAL <- BUY (RSI>50) True (CP) 2928.0 (RSI) 63.31 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2928.45 (S1) 2878.8 (R2) 2947.0 (S2) 2847.7 <PV> 2897.35 <MACD_M> 6.5 <MACD_S> 5.64 <SK> 77.15 <SD> 72.29 2024-07-08 09:48:48.277528
# <-b/s-> CONCOR <- SELL (RSI>50) False (CP) 1056.3 (RSI) 41.46 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1077.48 (S1) 1034.33 (R2) 1095.47 (S2) 1009.17 <PV> 1052.32 <MACD_M> -0.62 <MACD_S> -0.34 <SK> 32.86 <SD> 52.08 2024-07-08 09:48:56.169496
# <-b/s-> GAIL <- SELL (RSI>50) False (CP) 221.55 (RSI) 33.74 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 225.62 (S1) 219.21 (R2) 227.99 (S2) 215.17 <PV> 221.58 <MACD_M> -0.05 <MACD_S> 0.14 <SK> 8.24 <SD> 18.28 2024-07-08 09:49:05.305493
# <-b/s-> GNFC <- SELL (RSI>50) False (CP) 709.05 (RSI) 41.91 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 726.12 (S1) 706.17 (R2) 738.03 (S2) 698.13 <PV> 718.08 <MACD_M> -1.1 <MACD_S> -0.7 <SK> 25.07 <SD> 26.54 2024-07-08 09:49:14.475726
# <-b/s-> GRASIM <- NEUTRAL (RSI>50) False (CP) 2735.0 (RSI) 48.22 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 2765.0 (S1) 2729.7 (R2) 2778.0 (S2) 2707.4 <PV> 2742.7 <MACD_M> -3.58 <MACD_S> -2.07 <SK> 14.14 <SD> 14.25 2024-07-08 09:49:22.853907
# <-b/s-> IDFC <- NEUTRAL (RSI>50) False (CP) 120.5 (RSI) 46.68 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 121.94 (S1) 120.43 (R2) 122.78 (S2) 119.76 <PV> 121.27 <MACD_M> -0.24 <MACD_S> -0.16 <SK> 18.87 <SD> 16.72 2024-07-08 09:49:29.742927
# <-b/s-> ITC <- BUY (RSI>50) True (CP) 435.35 (RSI) 66.18 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 435.8 (S1) 429.4 (R2) 438.1 (S2) 425.3 <PV> 431.7 <MACD_M> 0.6 <MACD_S> 0.48 <SK> 70.65 <SD> 66.34 2024-07-08 09:49:36.622960
# <-b/s-> LUPIN <- BUY (RSI>50) True (CP) 1770.95 (RSI) 53.43 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1781.7 (S1) 1752.6 (R2) 1797.9 (S2) 1739.7 <PV> 1768.8 <MACD_M> 1.24 <MACD_S> 1.3 <SK> 28.92 <SD> 29.57 2024-07-08 09:49:45.540478
# <-b/s-> MCX <- SELL (RSI>50) False (CP) 3961.1 (RSI) 48.73 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4029.53 (S1) 3915.73 (R2) 4079.07 (S2) 3851.47 <PV> 3965.27 <MACD_M> -3.49 <MACD_S> -1.14 <SK> 22.14 <SD> 26.29 2024-07-08 09:49:53.137719
# <-b/s-> NTPC <- SELL (RSI>50) False (CP) 378.25 (RSI) 43.35 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 383.57 (S1) 373.32 (R2) 387.53 (S2) 367.03 <PV> 377.28 <MACD_M> 0.54 <MACD_S> 0.79 <SK> 25.02 <SD> 44.82 2024-07-08 09:50:01.284730
# <-b/s-> ONGC <- SELL (RSI>50) False (CP) 289.25 (RSI) 42.81 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 293.07 (S1) 280.27 (R2) 297.58 (S2) 271.98 <PV> 284.78 <MACD_M> 0.89 <MACD_S> 0.86 <SK> 46.02 <SD> 57.15 2024-07-08 09:50:09.690664
# <-b/s-> SAIL <- STRONG_BUY (RSI>50) True (CP) 156.45 (RSI) 58.21 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 159.47 (S1) 150.57 (R2) 163.56 (S2) 145.76 <PV> 154.66 <MACD_M> 0.21 <MACD_S> 0.14 <SK> 76.29 <SD> 74.46 2024-07-08 09:50:17.543187
# <-b/s-> SRF <- SELL (RSI>50) False (CP) 2395.0 (RSI) 42.44 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2413.4 (S1) 2374.7 (R2) 2431.8 (S2) 2354.4 <PV> 2393.1 <MACD_M> -0.53 <MACD_S> -0.19 <SK> 16.48 <SD> 27.83 2024-07-08 09:50:25.831206
# <-b/s-> SUNTV <- BUY (RSI>50) True (CP) 783.25 (RSI) 57.27 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 790.47 (S1) 774.37 (R2) 797.43 (S2) 765.23 <PV> 781.33 <MACD_M> -0.33 <MACD_S> -0.23 <SK> 41.25 <SD> 31.69 2024-07-08 09:50:34.198398
# <-b/s-> TCS <- STRONG_SELL (RSI>50) False (CP) 4000.05 (RSI) 34.09 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4028.5 (S1) 3989.75 (R2) 4047.0 (S2) 3969.5 <PV> 4008.25 <MACD_M> -0.35 <MACD_S> 1.31 <SK> 12.03 <SD> 20.82 2024-07-08 09:50:42.103112
# <-b/s-> TRENT <- BUY (RSI>50) True (CP) 5644.1 (RSI) 57.33 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 5661.3 (S1) 5551.85 (R2) 5707.6 (S2) 5488.7 <PV> 5598.15 <MACD_M> 6.49 <MACD_S> 4.56 <SK> 54.83 <SD> 48.5 2024-07-08 09:50:49.568434
# <-b/s-> VOLTAS <- NEUTRAL (RSI>50) False (CP) 1445.5 (RSI) 49.25 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 1460.67 (S1) 1441.72 (R2) 1469.28 (S2) 1431.38 <PV> 1450.33 <MACD_M> -1.79 <MACD_S> -1.11 <SK> 32.23 <SD> 29.16 2024-07-08 09:50:58.592431
# <-b/s-> WIPRO <- SELL (RSI>50) False (CP) 538.05 (RSI) 45.13 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 537.78 (S1) 530.73 (R2) 540.67 (S2) 526.57 <PV> 533.62 <MACD_M> 1.21 <MACD_S> 0.96 <SK> 69.36 <SD> 73.86 2024-07-08 09:51:05.172573
# <-b/s-> ABB <- BUY (RSI>50) True (CP) 8652.0 (RSI) 53.17 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 8725.82 (S1) 8614.32 (R2) 8776.63 (S2) 8553.63 <PV> 8665.13 <MACD_M> -3.0 <MACD_S> -0.39 <SK> 38.91 <SD> 34.35 2024-07-08 09:51:12.786583
# <-b/s-> ACC <- BUY (RSI>50) True (CP) 2696.25 (RSI) 59.67 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2724.65 (S1) 2632.85 (R2) 2778.35 (S2) 2594.75 <PV> 2686.55 <MACD_M> 1.6 <MACD_S> -1.99 <SK> 91.28 <SD> 90.99 2024-07-08 09:51:19.256572
# <-b/s-> ATUL <- BUY (RSI>50) True (CP) 6809.9 (RSI) 70.28 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 6816.5 (S1) 6669.0 (R2) 6887.0 (S2) 6592.0 <PV> 6739.5 <MACD_M> 9.31 <MACD_S> 1.77 <SK> 90.62 <SD> 78.3 2024-07-08 09:51:27.091530
# <-b/s-> BHEL <- BUY (RSI>50) True (CP) 320.7 (RSI) 66.44 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 322.43 (S1) 308.73 (R2) 329.07 (S2) 301.67 <PV> 315.37 <MACD_M> 0.99 <MACD_S> 0.57 <SK> 89.01 <SD> 84.6 2024-07-08 09:51:34.588130
# <-b/s-> BIOCON <- BUY (RSI>50) True (CP) 370.5 (RSI) 58.28 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 373.67 (S1) 362.37 (R2) 378.18 (S2) 355.58 <PV> 366.88 <MACD_M> 0.2 <MACD_S> 0.33 <SK> 32.86 <SD> 27.26 2024-07-08 09:51:42.513515
# <-b/s-> CIPLA <- STRONG_BUY (RSI>50) True (CP) 1515.9 (RSI) 53.72 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1522.03 (S1) 1492.03 (R2) 1534.02 (S2) 1474.02 <PV> 1504.02 <MACD_M> 2.42 <MACD_S> 2.1 <SK> 45.88 <SD> 49.18 2024-07-08 09:51:50.606131
# <-b/s-> COLPAL <- BUY (RSI>50) True (CP) 2936.5 (RSI) 69.43 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 2928.45 (S1) 2878.8 (R2) 2947.0 (S2) 2847.7 <PV> 2897.35 <MACD_M> 7.7 <MACD_S> 6.07 <SK> 82.42 <SD> 75.22 2024-07-08 09:51:59.123199
# ----->>>>> COLPAL <<<<<<----- tradingview rec BUY
# ->B<- COLPAL -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-08 09:52:07.425288
# ---------------->>>>>>>>---------------
# <-b/s-> CONCOR <- SELL (RSI>50) True (CP) 1059.1 (RSI) 50.6 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1077.48 (S1) 1034.33 (R2) 1095.47 (S2) 1009.17 <PV> 1052.32 <MACD_M> -0.37 <MACD_S> -0.3 <SK> 36.21 <SD> 44.27 2024-07-08 09:52:18.105081
# <-b/s-> GAIL <- SELL (RSI>50) False (CP) 222.1 (RSI) 45.13 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 225.62 (S1) 219.21 (R2) 227.99 (S2) 215.17 <PV> 221.58 <MACD_M> -0.06 <MACD_S> 0.11 <SK> 20.95 <SD> 15.99 2024-07-08 09:52:24.880700
# <-b/s-> GNFC <- BUY (RSI>50) True (CP) 714.25 (RSI) 59.94 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 726.12 (S1) 706.17 (R2) 738.03 (S2) 698.13 <PV> 718.08 <MACD_M> -0.61 <MACD_S> -0.63 <SK> 47.34 <SD> 36.01 2024-07-08 09:52:32.760695
# <-b/s-> GRASIM <- SELL (RSI>50) False (CP) 2733.95 (RSI) 46.04 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 2765.0 (S1) 2729.7 (R2) 2778.0 (S2) 2707.4 <PV> 2742.7 <MACD_M> -3.61 <MACD_S> -2.35 <SK> 16.97 <SD> 15.48 2024-07-08 09:52:41.885522
# <-b/s-> IDFC <- SELL (RSI>50) False (CP) 120.48 (RSI) 45.98 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 121.94 (S1) 120.43 (R2) 122.78 (S2) 119.76 <PV> 121.27 <MACD_M> -0.25 <MACD_S> -0.18 <SK> 19.09 <SD> 18.11 2024-07-08 09:52:50.821032
# <-b/s-> ITC <- BUY (RSI>50) True (CP) 437.05 (RSI) 81.04 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 435.8 (S1) 429.4 (R2) 438.1 (S2) 425.3 <PV> 431.7 <MACD_M> 0.81 <MACD_S> 0.55 <SK> 84.1 <SD> 73.99 2024-07-08 09:52:58.664573
# ----->>>>> ITC <<<<<<----- tradingview rec BUY
# ->B<- ITC -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-08 09:53:07.680550
# ---------------->>>>>>>>---------------
# <-b/s-> LUPIN <- BUY (RSI>50) True (CP) 1770.55 (RSI) 51.09 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1781.7 (S1) 1752.6 (R2) 1797.9 (S2) 1739.7 <PV> 1768.8 <MACD_M> 1.31 <MACD_S> 1.32 <SK> 31.95 <SD> 29.01 2024-07-08 09:53:18.830720
# <-b/s-> MCX <- SELL (RSI>50) False (CP) 3960.65 (RSI) 47.95 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4029.53 (S1) 3915.73 (R2) 4079.07 (S2) 3851.47 <PV> 3965.27 <MACD_M> -3.7 <MACD_S> -1.63 <SK> 25.97 <SD> 24.66 2024-07-08 09:53:26.946719
# <-b/s-> NTPC <- SELL (RSI>50) False (CP) 378.25 (RSI) 43.75 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 383.57 (S1) 373.32 (R2) 387.53 (S2) 367.03 <PV> 377.28 <MACD_M> 0.45 <MACD_S> 0.72 <SK> 21.58 <SD> 30.43 2024-07-08 09:53:37.460813
# <-b/s-> ONGC <- SELL (RSI>50) False (CP) 288.45 (RSI) 39.02 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 293.07 (S1) 280.27 (R2) 297.58 (S2) 271.98 <PV> 284.78 <MACD_M> 0.72 <MACD_S> 0.83 <SK> 30.66 <SD> 44.37 2024-07-08 09:53:46.762824
# <-b/s-> SAIL <- NEUTRAL (RSI>50) False (CP) 156.05 (RSI) 48.88 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 159.47 (S1) 150.57 (R2) 163.56 (S2) 145.76 <PV> 154.66 <MACD_M> 0.18 <MACD_S> 0.13 <SK> 65.15 <SD> 70.75 2024-07-08 09:53:54.658827
# <-b/s-> SRF <- SELL (RSI>50) False (CP) 2394.25 (RSI) 41.62 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2413.4 (S1) 2374.7 (R2) 2431.8 (S2) 2354.4 <PV> 2393.1 <MACD_M> -0.59 <MACD_S> -0.2 <SK> 15.11 <SD> 27.38 2024-07-08 09:54:01.636824
# <-b/s-> SUNTV <- BUY (RSI>50) True (CP) 783.55 (RSI) 57.11 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 790.47 (S1) 774.37 (R2) 797.43 (S2) 765.23 <PV> 781.33 <MACD_M> -0.3 <MACD_S> -0.23 <SK> 42.36 <SD> 32.06 2024-07-08 09:54:09.322854
# <-b/s-> TCS <- STRONG_SELL (RSI>50) False (CP) 3996.0 (RSI) 31.39 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4028.5 (S1) 3989.75 (R2) 4047.0 (S2) 3969.5 <PV> 4008.25 <MACD_M> -0.78 <MACD_S> 1.23 <SK> 10.45 <SD> 20.26 2024-07-08 09:54:17.376748
# ...
# <-b/s-> LUPIN <- STRONG_BUY (RSI>50) True (CP) 1772.4 (RSI) 52.66 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1781.7 (S1) 1752.6 (R2) 1797.9 (S2) 1739.7 <PV> 1768.8 <MACD_M> 1.24 <MACD_S> 1.51 <SK> 49.76 <SD> 48.18 2024-07-08 10:39:55.112894
# <-b/s-> MCX <- STRONG_SELL (RSI>50) False (CP) 3954.0 (RSI) 44.33 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4029.53 (S1) 3915.73 (R2) 4079.07 (S2) 3851.47 <PV> 3965.27 <MACD_M> -4.74 <MACD_S> -4.17 <SK> 30.13 <SD> 31.01 2024-07-08 10:40:02.583983
# <-b/s-> NTPC <- BUY (RSI>50) True (CP) 378.85 (RSI) 54.93 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 383.57 (S1) 373.32 (R2) 387.53 (S2) 367.03 <PV> 377.28 <MACD_M> 0.22 <MACD_S> 0.25 <SK> 58.33 <SD> 48.16 2024-07-08 10:40:10.944499
# <-b/s-> ONGC <- SELL (RSI>50) False (CP) 288.05 (RSI) 43.34 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 293.07 (S1) 280.27 (R2) 297.58 (S2) 271.98 <PV> 284.78 <MACD_M> -0.01 <MACD_S> 0.21 <SK> 14.85 <SD> 19.9 2024-07-08 10:40:25.322536
# <-b/s-> SAIL <- BUY (RSI>50) False (CP) 156.5 (RSI) 49.87 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 159.47 (S1) 150.57 (R2) 163.56 (S2) 145.76 <PV> 154.66 <MACD_M> 0.24 <MACD_S> 0.19 <SK> 49.79 <SD> 58.47 2024-07-08 10:40:33.807609
# <-b/s-> SRF <- BUY (RSI>50) True (CP) 2415.35 (RSI) 60.37 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 2413.4 (S1) 2374.7 (R2) 2431.8 (S2) 2354.4 <PV> 2393.1 <MACD_M> 3.46 <MACD_S> 1.17 <SK> 76.85 <SD> 79.02 2024-07-08 10:40:41.493789
# <-b/s-> SUNTV <- BUY (RSI>50) True (CP) 782.85 (RSI) 54.14 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 790.47 (S1) 774.37 (R2) 797.43 (S2) 765.23 <PV> 781.33 <MACD_M> -0.3 <MACD_S> -0.29 <SK> 49.86 <SD> 50.06 2024-07-08 10:40:49.331403
# <-b/s-> TCS <- SELL (RSI>50) False (CP) 3990.0 (RSI) 38.12 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4028.5 (S1) 3989.75 (R2) 4047.0 (S2) 3969.5 <PV> 4008.25 <MACD_M> -4.02 <MACD_S> -2.94 <SK> 9.75 <SD> 14.03 2024-07-08 10:40:57.123153
# <-b/s-> TRENT <- SELL (RSI>50) False (CP) 5613.75 (RSI) 37.8 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 5661.3 (S1) 5551.85 (R2) 5707.6 (S2) 5488.7 <PV> 5598.15 <MACD_M> -1.48 <MACD_S> 2.18 <SK> 22.63 <SD> 20.92 2024-07-08 10:41:07.551725
# <-b/s-> VOLTAS <- BUY (RSI>50) True (CP) 1473.5 (RSI) 59.0 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 1460.67 (S1) 1441.72 (R2) 1469.28 (S2) 1431.38 <PV> 1450.33 <MACD_M> 5.93 <MACD_S> 4.03 <SK> 80.77 <SD> 83.77 2024-07-08 10:41:16.666872
# <-b/s-> WIPRO <- BUY (RSI>50) True (CP) 538.5 (RSI) 58.17 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 537.78 (S1) 530.73 (R2) 540.67 (S2) 526.57 <PV> 533.62 <MACD_M> 0.61 <MACD_S> 0.64 <SK> 42.79 <SD> 38.25 2024-07-08 10:41:26.458145
# <-b/s-> ABB <- BUY (RSI>50) True (CP) 8680.2 (RSI) 70.96 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 8725.82 (S1) 8614.32 (R2) 8776.63 (S2) 8553.63 <PV> 8665.13 <MACD_M> 1.51 <MACD_S> -1.86 <SK> 86.9 <SD> 71.02 2024-07-08 10:41:35.578250
# <-b/s-> ACC <- SELL (RSI>50) False (CP) 2696.0 (RSI) 43.88 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 2724.65 (S1) 2632.85 (R2) 2778.35 (S2) 2594.75 <PV> 2686.55 <MACD_M> 3.64 <MACD_S> 3.05 <SK> 56.09 <SD> 65.51 2024-07-08 10:41:43.039975
# <-b/s-> ATUL <- SELL (RSI>50) False (CP) 6795.9 (RSI) 45.48 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 6816.5 (S1) 6669.0 (R2) 6887.0 (S2) 6592.0 <PV> 6739.5 <MACD_M> 15.68 <MACD_S> 15.05 <SK> 65.32 <SD> 70.95 2024-07-08 10:41:49.708490
# <-b/s-> BHEL <- STRONG_BUY (RSI>50) True (CP) 324.2 (RSI) 63.31 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 322.43 (S1) 308.73 (R2) 329.07 (S2) 301.67 <PV> 315.37 <MACD_M> 1.79 <MACD_S> 1.56 <SK> 81.45 <SD> 80.19 2024-07-08 10:41:57.270025
# ----->>>>> BHEL <<<<<<----- tradingview rec STRONG_BUY
# ->B<- BHEL -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-08 10:42:06.619911
# ---------------->>>>>>>>---------------
# <-b/s-> BIOCON <- BUY (RSI>50) True (CP) 372.4 (RSI) 59.37 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 373.67 (S1) 362.37 (R2) 378.18 (S2) 355.58 <PV> 366.88 <MACD_M> 0.6 <MACD_S> 0.42 <SK> 68.03 <SD> 70.52 2024-07-08 10:42:17.315743
# <-b/s-> CIPLA <- SELL (RSI>50) False (CP) 1510.45 (RSI) 42.67 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1522.03 (S1) 1492.03 (R2) 1534.02 (S2) 1474.02 <PV> 1504.02 <MACD_M> 0.54 <MACD_S> 1.12 <SK> 25.3 <SD> 30.07 2024-07-08 10:42:25.412639
# <-b/s-> COLPAL <- BUY (RSI>50) True (CP) 2959.85 (RSI) 69.99 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 2928.45 (S1) 2878.8 (R2) 2947.0 (S2) 2847.7 <PV> 2897.35 <MACD_M> 11.73 <MACD_S> 10.3 <SK> 93.82 <SD> 88.77 2024-07-08 10:42:32.946848
# ----->>>>> COLPAL <<<<<<----- tradingview rec BUY
# ->B<- COLPAL -> (CP>R1) True (RSI>50) True (SK>SD) True EMACROSS True (MACD_m>MACD_s) True T 2024-07-08 10:42:40.622440
# ---------------->>>>>>>>---------------
# <-b/s-> CONCOR <- BUY (RSI>50) True (CP) 1060.2 (RSI) 53.32 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1077.48 (S1) 1034.33 (R2) 1095.47 (S2) 1009.17 <PV> 1052.32 <MACD_M> -0.29 <MACD_S> -0.17 <SK> 45.41 <SD> 51.11 2024-07-08 10:42:51.127637
# <-b/s-> GAIL <- BUY (RSI>50) True (CP) 222.72 (RSI) 53.14 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 225.62 (S1) 219.21 (R2) 227.99 (S2) 215.17 <PV> 221.58 <MACD_M> -0.01 <MACD_S> -0.03 <SK> 59.8 <SD> 54.47 2024-07-08 10:42:59.675634
# <-b/s-> GNFC <- SELL (RSI>50) False (CP) 716.7 (RSI) 42.97 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 726.12 (S1) 706.17 (R2) 738.03 (S2) 698.13 <PV> 718.08 <MACD_M> 1.11 <MACD_S> 0.62 <SK> 67.64 <SD> 72.67 2024-07-08 10:43:07.742101
# <-b/s-> GRASIM <- SELL (RSI>50) False (CP) 2734.0 (RSI) 34.43 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 2765.0 (S1) 2729.7 (R2) 2778.0 (S2) 2707.4 <PV> 2742.7 <MACD_M> -2.03 <MACD_S> -2.33 <SK> 50.21 <SD> 60.29 2024-07-08 10:43:15.594453
# <-b/s-> IDFC <- BUY (RSI>50) True (CP) 120.7 (RSI) 52.69 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 121.94 (S1) 120.43 (R2) 122.78 (S2) 119.76 <PV> 121.27 <MACD_M> -0.16 <MACD_S> -0.18 <SK> 49.47 <SD> 44.98 2024-07-08 10:43:23.598109
# <-b/s-> ITC <- BUY (RSI>50) True (CP) 439.15 (RSI) 63.36 <CP>R1> True <CP>PV> True <CP<S1> False (R1) 435.8 (S1) 429.4 (R2) 438.1 (S2) 425.3 <PV> 431.7 <MACD_M> 1.47 <MACD_S> 1.28 <SK> 79.48 <SD> 82.64 2024-07-08 10:43:31.181917
# <-b/s-> LUPIN <- BUY (RSI>50) True (CP) 1776.05 (RSI) 58.39 <CP>R1> False <CP>PV> True <CP<S1> False (R1) 1781.7 (S1) 1752.6 (R2) 1797.9 (S2) 1739.7 <PV> 1768.8 <MACD_M> 1.59 <MACD_S> 1.54 <SK> 63.33 <SD> 53.55 2024-07-08 10:43:39.429011
# <-b/s-> MCX <- NEUTRAL (RSI>50) True (CP) 3957.7 (RSI) 52.0 <CP>R1> False <CP>PV> False <CP<S1> False (R1) 4029.53 (S1) 3915.73 (R2) 4079.07 (S2) 3851.47 <PV> 3965.27 <MACD_M> -4.47 <MACD_S> -4.23 <SK> 31.53 <SD> 30.9 2024-07-08 10:43:47.718036
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 110
#     108 for iteam in symbols:
#     109     try:
# --> 110         print("<-b/s->",iteam,"<-", get_recomm(iteam), "(RSI>50)", 50 < get_recomm_rsi(iteam), "(CP)", round(get_recomm_CP(iteam),2), "(RSI)", round(get_recomm_rsi(iteam),2),"<CP>R1>", get_recomm_CP(iteam) > get_recomm_R1(iteam),"<CP>PV>", get_recomm_CP(iteam) > get_recomm_PV(iteam),"<CP<S1>", get_recomm_CP(iteam) < get_recomm_S1(iteam),"(R1)", round(get_recomm_R1(iteam),2), "(S1)", round(get_recomm_S1(iteam),2),"(R2)", round(get_recomm_R2(iteam),2), "(S2)", round(get_recomm_S2(iteam),2),
#     111                 "<PV>", round(get_recomm_PV(iteam),2), "<MACD_M>", round(get_recomm_MACD_m(iteam),2), "<MACD_S>", round(get_recomm_MACD_s(iteam),2),  "<SK>", round(get_recomm_SK(iteam),2), "<SD>", round(get_recomm_SD(iteam),2), get_recomm_trec(iteam) )
#     112         # if "BUY" in get_recomm(iteam) and 50 < get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R1(iteam):# and get_recomm_ema10(iteam) > get_recomm_ema20(iteam): # and not last_buy:
#     113         if "BUY" in get_recomm(iteam) and 50 < get_recomm_rsi(iteam) and get_recomm_CP(iteam) > get_recomm_R1(iteam) and get_recomm_SK(iteam)>get_recomm_SD(iteam) and  get_recomm_ema10(iteam) > get_recomm_ema20(iteam) and get_recomm_MACD_m(iteam) > get_recomm_MACD_s(iteam)  :# and get_recomm_ema10(iteam) > get_recomm_ema20(iteam): # and not last_buy:
#
# Cell In[8], line 29, in get_recomm_CP(symbols)
#      27 def get_recomm_CP(symbols):
#      28     output = TA_Handler(symbol=symbols, screener=sr, exchange=ex, interval=Interval.INTERVAL_1_MINUTE, timeout=None)
# ---> 29     return float(output.get_analysis().indicators["close"])
#
# File c:\Users\murug\.conda\envs\BreezeConnect\lib\site-packages\tradingview_ta\main.py:387, in TA_Handler.get_analysis(self)
#     380 def get_analysis(self):
#     381     """Get analysis from TradingView and compute it.
#     382
#     383     Returns:
#     384         Analysis: Contains information about the analysis.
#     385     """
# --> 387     return calculate(indicators=self.get_indicators(), indicators_key=self.indicators, screener=self.screener, symbol=self.symbol, exchange=self.exchange, interval=self.interval)
#
# File c:\Users\murug\.conda\envs\BreezeConnect\lib\site-packages\tradingview_ta\main.py:353, in TA_Handler.get_indicators(self, indicators)
#     351 scan_url = f"{TradingView.scan_url}{self.screener.lower()}/scan"
#     352 headers = {"User-Agent": "tradingview_ta/{}".format(__version__)}
# --> 353 response = requests.post(
#     354     scan_url, json=data, headers=headers, timeout=self.timeout, proxies=self.proxies)
#     356 # Return False if can't get data
#     357 if response.status_code != 200:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File c:\Users\murug\.conda\envs\BreezeConnect\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\murug\.conda\envs\BreezeConnect\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\murug\.conda\envs\BreezeConnect\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File c:\Users\murug\.conda\envs\BreezeConnect\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File c:\Users\murug\.conda\envs\BreezeConnect\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File c:\Users\murug\.conda\envs\BreezeConnect\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File c:\Users\murug\.conda\envs\BreezeConnect\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File c:\Users\murug\.conda\envs\BreezeConnect\lib\ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\murug\.conda\envs\BreezeConnect\lib\ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(buyCallNB.mp3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(buyCallNB.mp3)
#
# NameError: name 'buyCallNB' is not defined

# %%
mytext1 = 'Buy nifty signal buy CALL OPTION  executed'; mytext2 = 'Sell nifty signal buy PUT OPTION executed'
